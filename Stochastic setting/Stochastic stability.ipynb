# %% [markdown]
# # Scenarios generation

# %%
from xpress import *
import numpy as np
np.random.seed(8)  # Set the seed for reproducibility

def scenario_generation(N_scenarios):
    KT_values = {}  # Dictionary to store the generated values of KT
    for scenario in range(1, N_scenarios+1):
        KT_values[scenario] = np.random.poisson(100)  # Generate a Poisson-distributed value with mean 100
    return KT_values

# Accessing the KT values for a specific scenario
scenario_number = 1  # Example scenario number
KT_values = scenario_generation(100)
KT_value = KT_values[scenario_number]
#print(f"KT value for scenario {scenario_number}: {KT_value}")
print(KT_values)
# Out:
# {1: 113, 2: 92, 3: 98, 4: 101, 5: 102, 6: 108, 7: 103, 8: 95, 9: 87, 10: 82, 11: 97, 12: 96, 13: 120, 14: 98, 15: 110, 16: 81, 17: 109, 18: 99, 19: 90, 20: 91, 21: 101, 22: 121, 23: 103, 24: 100, 25: 98, 26: 90, 27: 103, 28: 94, 29: 111, 30: 106, 31: 111, 32: 113, 33: 94, 34: 100, 35: 110, 36: 120, 37: 89, 38: 102, 39: 110, 40: 87, 41: 112, 42: 92, 43: 84, 44: 99, 45: 91, 46: 99, 47: 101, 48: 111, 49: 103, 50: 89, 51: 104, 52: 114, 53: 96, 54: 77, 55: 102, 56: 101, 57: 99, 58: 109, 59: 89, 60: 92, 61: 101, 62: 101, 63: 119, 64: 93, 65: 103, 66: 92, 67: 104, 68: 103, 69: 89, 70: 106, 71: 104, 72: 96, 73: 94, 74: 96, 75: 94, 76: 90, 77: 90, 78: 97, 79: 94, 80: 113, 81: 91, 82: 93, 83: 102, 84: 110, 85: 118, 86: 119, 87: 90, 88: 113, 89: 126, 90: 106, 91: 105, 92: 105, 93: 97, 94: 99, 95: 108, 96: 107, 97: 100, 98: 96, 99: 108, 100: 98}

# %% [markdown]
# # Items generation

# %%
import random

def generate_item_data(num_items):
    volumes = {}
    demand = {}
    costs = {}
    alpha = {}
    beta = {}
    price = {}
    display_min = {}

    for i in range(1, num_items + 1):
        volumes[i] = int(random.uniform(0.01, 10))  # Random volume for item i
        demand[i] = int(random.randint(1, 16))  # Random demand for item i
        costs[i] = int(random.uniform(1.0, 101.0))  # Random cost for item i
        price[i] = 2 * costs[i]
        display_min[i] = int(random.uniform(50,70))

        for j in range(1, num_items + 1):
            if i == j:
                alpha[(j, i)] = 0.0
                beta[(j, i)] = 0.0
            else:
                alpha[(j, i)] = float("{:.2f}".format(random.uniform(0.1, 0.9)))  # Random alpha for item j -> item i
                beta[(j, i)] = float("{:.2f}".format(random.uniform(0.1, 0.9)))  # Random beta for item j -> item i

    return volumes, demand, costs, alpha, beta, price, display_min


# Specify the number of items
num_items = 20

# Generate item data
volumes, demand, costs, alpha, beta,price, display_min = generate_item_data(num_items)

# %% [markdown]
# # Resolution algorithms

# %%
import xpress as xp
import numpy as np
import time

def solution_stability(N_scenarios, num_items):
    # defining the problem
    volumes, demand, costs, alpha, beta, price, display_min = generate_item_data(num_items)
    KT_values = scenario_generation(N_scenarios)

    # Define the set of items
    N = list(range(1, num_items + 1))  # Example set of items
    lim_prod = 7
    # Define the set of scenarios
    Omega = list(range(1, len(KT_values) + 1))  # Example set of scenarios

    w = volumes
    d = demand
    alpha = alpha
    beta = beta
    p = price
    c = costs
    display_min = display_min
    C = 100 * np.dot(np.array(list(d.values())), np.array(list(w.values())))  # Example budget constraint
    M = 1000000000000000000000000  # Example capacity constraint
    delta = 0.7  # Example substitution constraint
    KT = KT_values

    # Define the model
    model = xp.problem(name="Stochastic Assortment Optimization")

    # Define the decision variables
    x = np.array([xp.var(vartype=xp.binary, name=f'x_{i}') for i in N])
    m = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'm_{i}_{omega}') for omega in Omega for i in N}
    u = np.array([xp.var(vartype=xp.integer, lb=0, name=f'u_{i}') for i in N])
    mu = {(i, omega): xp.var(vartype=xp.binary, name=f'mu_{i}_{omega}') for omega in Omega for i in N}
    mu_1 = {(i, omega): xp.var(vartype=xp.binary, name=f'mu_1_{i}_{omega}') for omega in Omega for i in N}
    v_plus = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'v_plus_{i}_{omega}') for omega in Omega for i in N}
    v_minus = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'v_minus_{i}_{omega}') for i in N for omega in Omega}
    q_dict = {(i, j, omega): xp.var(vartype=xp.integer, lb=0, name=f'q_{i}_{j}_{omega}') for i in N for j in N for omega in Omega}
    s_dict = {(i, j, omega): xp.var(vartype=xp.integer, lb=0, name=f's_{i}_{j}_{omega}') for i in N for j in N for omega in Omega}

    model.addVariable(x)
    model.addVariable(m)
    model.addVariable(u)
    model.addVariable(v_plus)
    model.addVariable(v_minus)
    model.addVariable(q_dict)
    model.addVariable(s_dict)
    model.addVariable(mu)
    model.addVariable(mu_1)

    # Define the objective function
    expected_profit = xp.Sum(xp.Sum(m[(i, omega)] * p[i] for i in N) for omega in Omega) / len(Omega)
    assortment_substitution_profit = xp.Sum(
        xp.Sum(xp.Sum(p[i] * delta * alpha[(j, i)] * q_dict[(j, i, omega)] for i in N) for j in N) for omega in Omega
    ) / len(Omega)
    stockout_substitution_profit = xp.Sum(
        xp.Sum(xp.Sum(p[i] * delta * beta[(j, i)] * s_dict[(j, i, omega)] for i in N) for j in N) for omega in Omega
    ) / len(Omega)
    cost_of_storage = xp.Sum(c[i] * u[i - 1] for i in N)

    model.setObjective(
        expected_profit + stockout_substitution_profit + assortment_substitution_profit - cost_of_storage,
        sense=xp.maximize,
    )

    # Define the constraints
    budget_constraint = xp.Sum(w[i] * u[i - 1] for i in N) <= C
    display_constraint = [u[i - 1] >= display_min[i] * x[i - 1] for i in N]
    nbr_prods_constraint = xp.Sum(x[i - 1] for i in N) <= lim_prod

    capacity_constraints = [u[i - 1] <= M * x[i - 1] for i in N]  # Changed to a list comprehension
    nullity_constraints = [x[i - 1] <= u[i - 1] for i in N]

    min_constraints = []
    for i in N:
        for omega in Omega:
            min_constraints.append(m[(i, omega)] == xp.min(u[i - 1], KT[omega] * d[i]))

    assortment_constraints = []
    for omega in Omega:
        for i in N:
            for j in N:
                if j == i:
                    q_dict[j, i, omega] = 0
                if j != i:
                    assortment_constraints.append(q_dict[j, i, omega] <= M * x[i - 1])
                    assortment_constraints.append(q_dict[j, i, omega] <= M * (1 - x[j - 1]))

    lost_sales_constraints = []
    for omega in Omega:
        for i in N:
            lost_sales_constraints.append(
                v_plus[(i, omega)] - v_minus[(i, omega)] == m[(i, omega)] + xp.Sum(
                    q_dict[(j, i, omega)] for j in N if j != i
                ) - u[i - 1]
            )
            lost_sales_constraints.append(v_plus[(i, omega)] <= M * mu[(i, omega)])
            lost_sales_constraints.append(v_minus[(i, omega)] <= M * mu_1[(i, omega)])
            lost_sales_constraints.append(mu[(i, omega)] + mu_1[(i, omega)] == 1)

    stock_out_constraints = []
    for i in N:
        for j in N:
            for omega in Omega:
                if i == j:
                    s_dict[i, j, omega] = 0
                if j != i:
                    stock_out_constraints.append(s_dict[(j, i, omega)] <= M * x[i - 1])
                    stock_out_constraints.append(s_dict[(j, i, omega)] <= M * x[j - 1])

    global_constraints = []
    for omega in Omega:
        for i in N:
            global_constraints.append(
                xp.Sum(
                    m[(i, omega)] + xp.Sum(q_dict[(i, j, omega)] for j in N if j != i) + xp.Sum(
                        s_dict[(i, j, omega)] for j in N if j != i
                    )
                ) == KT[omega] * d[i]
            )

    global_capa_constraints = []
    for omega in Omega:
        for i in N:
            global_capa_constraints.append(
                xp.Sum(
                    m[(i, omega)] + xp.Sum(q_dict[(j, i, omega)] for j in N if j != i) + xp.Sum(
                        s_dict[(j, i, omega)] for j in N if j != i
                    )
                ) <= u[i - 1]
            )

    model.addConstraint(budget_constraint)
    model.addConstraint(capacity_constraints)
    model.addConstraint(nullity_constraints)
    model.addConstraint(assortment_constraints)
    model.addConstraint(min_constraints)
    model.addConstraint(lost_sales_constraints)
    model.addConstraint(stock_out_constraints)
    model.addConstraint(nbr_prods_constraint)
    model.addConstraint(display_constraint)
    model.addConstraint(global_constraints)
    model.addConstraint(global_capa_constraints)

    # Solve the problem
    start_time = time.time()
    model.solve()
    end_time = time.time()
    runtime = end_time - start_time

    # Get the optimal objective value
    optimal_objective_value = model.getObjVal()
    print("Optimal objective:", optimal_objective_value)

    # Get the optimal decision variable values
    optimal_x = {i: model.getSolution(x[i - 1]) for i in N}
    optimal_u = {i: model.getSolution(u[i - 1]) for i in N}
    optimal_s = {(i, j, omega): model.getSolution(s_dict[(i, j, omega)]) for i in N for j in N if j != i for omega in Omega}
    optimal_q = {(i, j, omega): model.getSolution(q_dict[(i, j, omega)]) for i in N for j in N if j != i for omega in Omega}
    optimal_m = {(i, omega): model.getSolution(m[(i, omega)]) for i in N for omega in Omega}
    optimal_v_plus = {(i, omega): model.getSolution(v_plus[(i, omega)]) for i in N for omega in Omega}
    optimal_v_minus = {(i, omega): model.getSolution(v_minus[(i, omega)]) for i in N for omega in Omega}
    optimal_mu = {(i, omega): model.getSolution(mu[(i, omega)]) for i in N for omega in Omega}
    optimal_mu_1 = {(i, omega): model.getSolution(mu_1[(i, omega)]) for i in N for omega in Omega}

    return (optimal_objective_value, optimal_x, optimal_u)

# %%
solutions = []

# %%
input_size = []
N_prod = 20
for i in range (1,501,10):
    input_size.append((i, N_prod))
# Out:
# [(1, 20),
#  (11, 20),
#  (21, 20),
#  (31, 20),
#  (41, 20),
#  (51, 20),
#  (61, 20),
#  (71, 20),
#  (81, 20),
#  (91, 20),
#  (101, 20),
#  (111, 20),
#  (121, 20),
#  (131, 20),
#  (141, 20),
#  (151, 20),
#  (161, 20),
#  (171, 20),
#  (181, 20),
#  (191, 20),
#  (201, 20),
#  (211, 20),
#  (221, 20),
#  (231, 20),
#  (241, 20),
#  (251, 20),
#  (261, 20),
#  (271, 20),
#  (281, 20),
#  (291, 20),
#  (301, 20),
#  (311, 20),
#  (321, 20),
#  (331, 20),
#  (341, 20),
#  (351, 20),
#  (361, 20),
#  (371, 20),
#  (381, 20),
#  (391, 20),
#  (401, 20),
#  (411, 20),
#  (421, 20),
#  (431, 20),
#  (441, 20),
#  (451, 20),
#  (461, 20),
#  (471, 20),
#  (481, 20),
#  (491, 20)]

# %%
updatable_solutions = []
for inp in input_size:
    a = solution_stability(inp[0], inp[1])
    solutions.append(a)
    updatable_solutions.append(a)
# Out:
# Original problem size
#    linear:    1722 rows, 941 columns, 5377 linear coefficients
#    nonlinear: 20 coefficients, 120 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 20 MIN/MAX to optimizer MIP constructs
#    converted 20 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    1722 rows, 961 columns, 5397 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 13:57:12, Jul 15, 2023
# Heap usage: 1511KB (peak 1703KB, 1135KB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#       1722 rows          961 cols         5397 elements       940 entities
#         20 gencons
# Presolved problem has:
#       1299 rows          877 cols         4168 elements       857 entities
#         40 inds
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 2189KB (peak 3298KB, 1152KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  7.41e+04] / [ 1.00e+00,  7.41e+04]
#   Objective      [min,max] : [ 1.54e+00,  1.82e+02] / [ 1.54e+00,  1.82e+02]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 60.7GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,   0s
#             Dual
#     objective   dual inf
#  D  816556.86   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 141 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    141       816556.8573      D      0     0        .000000     0
# Dual solved problem
#   141 simplex iterations in 0.00 seconds at time 0
#
# Final objective                       : 8.165568573017912e+05
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K                724655.1680      0     56      0               23      0
#    2  K                719511.6620      0      8     35               28      0
#    3  K                719511.6620      0      0      6               23      0
#    4  G                719068.7597      0     15      0               23      0
#    5  G                717107.1488      0     10     10               40      0
#    6  G                717023.8791      0      3      9               52      0
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 32
# Cut elements in the matrix : 2750
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 7323KB (peak 10138KB, 1178KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1               715646.7309      0      2      1               51      0
#        2               715646.7309      0      2      3               25      0
#        3               715646.7309      0      3      3               44      0
#        4               715060.7724      0      4      4                1      0
#        5               715060.7724      0      5      4               23      0
#        6               715060.7724      0      6      5                1      0
# *      6  699626.1080  715060.7724      1      7      5    2.16%       0      0
#        7  699626.1080  715060.7724      1      7      5    2.16%       1      0
#       10  699626.1080  715060.7724      1      3      1    2.16%       1      0
#       20  699626.1080  714613.0465      1      2      5    2.10%       1      0
# *     24  714610.2040  714611.1890      2      2      7    0.00%       0      0
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=1.37837e-06).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=1.37837e-06).
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 7.146102039999985e+05
# Final MIP bound                       : 7.146111879999998e+05
#   Solution time / primaldual integral :      0.43s/ 88.255139%
#   Number of solutions found / nodes   :         2 /        26
#   Max primal violation      (abs/rel) : 1.070e+03 / 2.516e-10
#   Max integer violation     (abs    ) : 9.477e-10
# Problem is nonlinear postsolved
# Heap usage: 2267KB (peak 29MB, 407KB system)
# Final MILP objective (global optimum)   : 7.146102039999599e+05
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :                  .439s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 714610.2039999599
# Original problem size
#    linear:    18322 rows, 9941 columns, 57577 linear coefficients
#    nonlinear: 220 coefficients, 1320 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 200 MIN/MAX to optimizer MIP constructs
#    converted 220 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    18322 rows, 10141 columns, 57797 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 13:57:12, Jul 15, 2023
# Heap usage: 10MB (peak 10MB, 5348KB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#      18322 rows        10141 cols        57797 elements      9940 entities
#        200 gencons
# Presolved problem has:
#      13962 rows         9187 cols        44827 elements      8987 entities
#        400 inds
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 15MB (peak 21MB, 5382KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  7.25e+04] / [ 1.00e+00,  7.25e+04]
#   Objective      [min,max] : [ 3.82e-02,  9.70e+01] / [ 3.82e-02,  9.70e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 1, support set: 1554
#  Number of orbits: 777, largest orbit: 2
#  Row orbits: 1197, row support: 2394
# Will try to keep branch and bound tree memory usage below 60.7GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   0s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  751096.22   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 1999 simplex iterations, 0.17s
#    Barrier: 22 barrier and 107 simplex iterations, 0.27s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       751096.2167      P      0     0        .000000     0
# Barrier solved problem
#   22 barrier and 107 simplex iterations in 0.28 seconds at time 0
#
# Final objective                       : 7.510962166832974e+05
#   Max primal violation      (abs/rel) : 2.274e-13 / 2.274e-13
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K                706028.4396      0    332      0               92      2
#    2  K                630729.8189      0    824    194              759      4
#    3  K                592255.2415      0    210    703              594      5
#    4  K                592079.6395      0    815    177              776      5
#    5  K                592058.1794      0     29    791              542      5
#    6  K                592040.7899      0      2     23              538      5
#    7  K                592040.7899      0      0      0              538      5
#    8  G                592022.8900      0     35      0              538      6
#    9  G                592017.2705      0     65     35              668      6
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 389
# Cut elements in the matrix : 8717
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 47MB (peak 63MB, 5631KB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1               591805.7018      0      2      1              562      9
#        2               591076.7285      0      2      3              271      9
#        3               590942.6438      0      3      3              372     10
#        4               590942.6438      0      4      4              271     10
#        5               589997.5209      0      5      4              372     10
#        6               589997.5209      0      5      4               27     10
#        7               589997.5209      0      6      5              466     10
#        8               589997.5209      0      6      4              267     10
#        9               589997.5209      0      7      5               19     10
#       10               589997.5209      0      8      5              268     11
#       20               582010.2430      0     18      6              195     13
#       30               579312.4111      0     26      8              193     14
#       40               579312.4111      0     34      9              205     15
# *     48  511403.8558  578639.3782      1     40     22   11.62%       0     15
#       50  511403.8558  578639.3782      1     40     22   11.62%       1     15
#       63  511403.8558  578639.3782      1     32     15   11.62%       7     15
# *     72  554528.3727  578639.3782      2     33     16    4.17%       0     16
#       74  554528.3727  578639.3782      2     33     16    4.17%       1     16
#       92  554528.3727  578639.3782      2     23      1    4.17%       1     16
# Elapsed time (sec): 16, estimated tree completion: 0.54420
# Heap usage: 481MB (peak 481MB, 6040KB system)
# B&B tree size: 0.9MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      102  554528.3727  578639.3782      2     17     12    4.17%      18     16
# *    120  554866.0565  578639.3782      3      6     16    4.11%       0     16
# *    129  558013.6365  578639.3782      4      3      9    3.56%       0     16
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      1 out of      1708 (ratio: 0.0006)
#    Predicted att. level   : 0.3109
# Uncrunching matrix
# Final MIP objective                   : 5.580136365454521e+05
# Final MIP bound                       : 5.580143876416688e+05
#   Solution time / primaldual integral :     17.05s/ 92.465336%
#   Number of solutions found / nodes   :         4 /       173
#   Max primal violation      (abs/rel) : 8.730e+02 / 1.345e-09
#   Max integer violation     (abs    ) : 1.668e-09
# Problem is nonlinear postsolved
# Heap usage: 15MB (peak 481MB, 548KB system)
# Final MILP objective (global optimum)   : 5.580136365454416e+05
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :                17.140s
#   Time checks (ticks) :        2
# *** Search completed ***
# Optimal objective: 558013.6365454416
# Original problem size
#    linear:    34922 rows, 18941 columns, 109780 linear coefficients
#    nonlinear: 420 coefficients, 2520 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 320 MIN/MAX to optimizer MIP constructs
#    converted 420 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    34922 rows, 19261 columns, 110200 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 13:57:32, Jul 15, 2023
# Heap usage: 19MB (peak 20MB, 10228KB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#      34922 rows        19261 cols       110200 elements     18940 entities
#        320 gencons
# Presolved problem has:
#      26522 rows        17380 cols        85220 elements     17060 entities
#        629 inds
# LP relaxation tightened
# Presolve finished in 0 seconds
# Heap usage: 29MB (peak 39MB, 10MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 3.05e-05,  1.96e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  9.35e+04] / [ 1.00e+00,  4.67e+04]
#   Objective      [min,max] : [ 2.80e-02,  9.80e+01] / [ 2.80e-02,  9.80e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 5, support set: 7020
#  Number of orbits: 3120, largest orbit: 3
#  Row orbits: 4800, row support: 10800
# Will try to keep branch and bound tree memory usage below 60.7GB
#  *** Solution found: -28599.05771   Time:   0.94    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   1s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  796801.11   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 3610 simplex iterations, 0.46s
#    Barrier: 46 barrier and 186 simplex iterations, 1.00s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       796801.1097      P      0     0        .000000     1
# Barrier solved problem
#   46 barrier and 186 simplex iterations in 1.02 seconds at time 1
#
# Final objective                       : 7.968011096997713e+05
#   Max primal violation      (abs/rel) : 2.220e-16 / 1.230e-16
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         400433.3877  599960.7846      2                 33.26%       0      7
# R         470445.7067  599960.7846      3                 21.59%       0      7
#    1  K   470445.7067  599960.7846      3    987      0   21.59%     372      7
#    2  K   470445.7067  548138.9040      3   1099    549   14.17%    1201     11
#    3  K   470445.7067  546540.2892      3    271   1040   13.92%    1041     12
#    4  K   470445.7067  546471.6168      3     24    206   13.91%     518     12
#    5  K   470445.7067  546471.5174      3     66     23   13.91%     584     12
#    6  K   470445.7067  546470.4805      3      7     63   13.91%     663     12
#    7  K   470445.7067  546470.4805      3      0      7   13.91%     496     12
#    8  G   470445.7067  546213.7120      3     50      0   13.87%     496     12
#    9  G   470445.7067  546195.4634      3     63    109   13.87%     592     13
# Heuristic search 'R' started
# R         470607.9767  546195.4634      4                 13.84%       0     13
# R         483365.2729  546195.4634      5                 11.50%       0     13
# R         509499.3805  546195.4634      6                  6.72%       0     13
# Heuristic search 'R' stopped
# M         509867.3491  546195.4634      7                  6.65%       0     13
# M         510232.8885  546195.4634      8                  6.58%       0     13
# M         510594.2465  546195.4634      9                  6.52%       0     13
# M         510951.0771  546195.4634     10                  6.45%       0     14
# M         511305.6065  546195.4634     11                  6.39%       0     14
# M         511658.0025  546195.4634     12                  6.32%       0     14
# M         512004.4791  546195.4634     13                  6.26%       0     14
# M         512347.1925  546195.4634     14                  6.20%       0     14
# M         512687.0431  546195.4634     15                  6.13%       0     14
# M         513022.9425  546195.4634     16                  6.07%       0     14
# M         513357.5745  546195.4634     17                  6.01%       0     15
# M         513686.7431  546195.4634     18                  5.95%       0     15
# M         514013.3165  546195.4634     19                  5.89%       0     15
# M         514336.0051  546195.4634     20                  5.83%       0     15
#
# Cuts in the matrix         : 570
# Cut elements in the matrix : 10854
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 89MB (peak 129MB, 10MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  514336.0051  544823.7161     20      2      1    5.60%     593     17
#        2  514336.0051  544823.7161     20      2      2    5.60%     593     17
# E      3  517668.3288  519519.2902     21      1      3    0.36%       0     18
#        3  517668.3288  519519.2902     21      1      3    0.36%       2     18
#        4  517668.3288  517669.1256     21      1      1    0.00%       1     18
#        5  517668.3288  517669.1256     21      1      3    0.00%       2     18
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=1.53921e-06).
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 5.176683287619039e+05
# Final MIP bound                       : 5.176691255630136e+05
#   Solution time / primaldual integral :     18.89s/ 47.000610%
#   Number of solutions found / nodes   :        21 /         5
#   Max primal violation      (abs/rel) : 6.036e-10 / 6.036e-10
#   Max integer violation     (abs    ) : 6.044e-10
# Problem is nonlinear postsolved
# Heap usage: 29MB (peak 154MB, 812KB system)
# Final MILP objective (global optimum)   : 5.176683287619082e+05
#   Max validation error      (abs/rel) :      .000 /      .000
#   Observed primal integral :  100.000%
#   Total time :                19.088s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 517668.3287619082
# Original problem size
#    linear:    51522 rows, 27941 columns, 161979 linear coefficients
#    nonlinear: 620 coefficients, 3720 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 420 MIN/MAX to optimizer MIP constructs
#    converted 620 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    51522 rows, 28361 columns, 162599 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 13:58:01, Jul 15, 2023
# Heap usage: 29MB (peak 29MB, 14MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#      51522 rows        28361 cols       162599 elements     27940 entities
#        420 gencons
# Presolved problem has:
#      38870 rows        25449 cols       125094 elements     25029 entities
#        828 inds
# LP relaxation tightened
# Presolve finished in 1 seconds
# Heap usage: 43MB (peak 58MB, 14MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  6.37e+04] / [ 1.00e+00,  6.37e+04]
#   Objective      [min,max] : [ 5.96e-02,  9.40e+01] / [ 5.96e-02,  9.40e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 10, support set: 13243
#  Number of orbits: 5453, largest orbit: 4
#  Row orbits: 8393, row support: 20383
# Will try to keep branch and bound tree memory usage below 60.7GB
#  *** Solution found: -80431.22432   Time:   1.77    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   2s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  756914.04   .0000000 |  B -979052.44  4.136E+08
#  D  657447.22   .0000000 |  B  652828.21  670611.70
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 5771 simplex iterations, 1.16s
#    Barrier: 31 barrier and 0 simplex iterations, 1.17s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   5771       655964.0343      P      0     0        .000000     2
# Dual solved problem
#   5771 simplex iterations in 1.18 seconds at time 2
#
# Final objective                       : 6.559640342633402e+05
#   Max primal violation      (abs/rel) : 5.684e-13 / 5.684e-13
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K  -80431.22432  631364.0599      1    375      0  711795      857      8
#    2  K  -80431.22432  459524.4537      1   7255    205  539956     1327     28
#    3  K  -80431.22432  459335.4960      1    396   6733  539767     1640     29
#    4  K  -80431.22432  459305.2507      1    372    361  539736     1625     30
#    5  K  -80431.22432  459238.2267      1    291    346  539669     1869     31
#    6  K  -80431.22432  459213.2655      1    255    285  539644     1787     31
#    7  K  -80431.22432  459213.2655      1    199    250  539644     1604     32
#    8  K  -80431.22432  459213.2655      1    115    193  539644     1599     32
#    9  K  -80431.22432  459213.2655      1    110    112  539644     1594     32
#   10  K  -80431.22432  459213.2655      1    105    106  539644     1589     34
#   11  K  -80431.22432  459213.2655      1    101    101  539644     1585     34
#   12  K  -80431.22432  459213.2655      1     94     97  539644     1581     34
#   13  K  -80431.22432  459213.2655      1     91     91  539644     1578     35
#   14  K  -80431.22432  459213.2655      1     88     87  539644     1576     35
#   15  K  -80431.22432  459213.2655      1     78    161  539644     1573     35
#   16  G  -80431.22432  459005.8291      1     35      0  539437     1571     37
#   17  G  -80431.22432  458999.9444      1    400    385  539431     1775     37
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 847
# Cut elements in the matrix : 20804
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 140MB (peak 167MB, 15MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1 -80431.22432  458714.4356      1      2      1  539146     1875     42
#        2 -80431.22432  458714.4356      1      2      3  539146      753     45
#        3 -80431.22432  458714.4356      1      3      4  539146      696     46
#        4 -80431.22432  458714.4356      1      3      4  539146      648     46
#        5 -80431.22432  458714.4356      1      4      5  539146        6     47
#        6 -80431.22432  458714.4356      1      6      6  539146        5     47
#        7 -80431.22432  458714.4356      1      7      7  539146        4     47
#        8 -80431.22432  458714.4356      1      8      8  539146        3     47
#        9 -80431.22432  458714.4356      1      9      9  539146        2     47
#       10 -80431.22432  449585.5668      1     10     10  530017      558     49
# *     16  449585.5668  449585.5668      2     15     11   -0.00%       0     50
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=-0).
#       29  449585.5668  449585.5668      2      3      1   -0.00%       1     50
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=-0).
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      2 out of       198 (ratio: 0.0101)
#    Predicted att. level   : 0.3299
# Uncrunching matrix
# Final MIP objective                   : 4.495855667741938e+05
# Final MIP bound                       : 4.495855667741938e+05
#   Solution time / primaldual integral :     50.08s/ 99.878286%
#   Number of solutions found / nodes   :         2 /        29
#   Max primal violation      (abs/rel) : 4.040e+02 / 3.445e-11
#   Max integer violation     (abs    ) : 3.456e-11
# Problem is nonlinear postsolved
# Heap usage: 43MB (peak 261MB, 1077KB system)
# Final MILP objective (global optimum)   : 4.495855667741931e+05
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :                50.456s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 449585.5667741931
# Original problem size
#    linear:    68122 rows, 36941 columns, 214178 linear coefficients
#    nonlinear: 820 coefficients, 4920 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 420 MIN/MAX to optimizer MIP constructs
#    converted 820 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    68122 rows, 37361 columns, 214998 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 13:59:12, Jul 15, 2023
# Heap usage: 38MB (peak 38MB, 19MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#      68122 rows        37361 cols       214998 elements     36940 entities
#        420 gencons
# Presolved problem has:
#      50800 rows        33198 cols       163932 elements     32778 entities
#        818 inds
# LP relaxation tightened
# Presolve finished in 2 seconds
# Heap usage: 56MB (peak 77MB, 19MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  6.71e+04] / [ 1.00e+00,  3.35e+04]
#   Objective      [min,max] : [ 3.76e-03,  9.80e+01] / [ 3.76e-03,  9.80e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 20, support set: 25674
#  Number of orbits: 10114, largest orbit: 5
#  Row orbits: 15574, row support: 39534
# Will try to keep branch and bound tree memory usage below 60.7GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   3s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  1221277.6   .0000000 |  B  25847561.  2.216E+09
#  D  1034146.7   .0000000 |  B  578871.95  2053116.7
#  D  930943.09   .0000000 |  B  874012.83  875063.39
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 7525 simplex iterations, 1.74s
#    Barrier: 42 barrier and 319 simplex iterations, 2.13s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       874298.3161      P      0     0        .000000     4
# Barrier solved problem
#   42 barrier and 319 simplex iterations in 2.16 seconds at time 4
#
# Final objective                       : 8.742983160533911e+05
#   Max primal violation      (abs/rel) : 4.547e-13 / 4.547e-13
#   Max dual violation        (abs/rel) : 1.110e-16 / 1.110e-16
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# t        -3103570.084  874298.3161      1               3.98e+06       0      9
#    1  K  -3103570.084  859378.5573      1    425      0 3.96e+06     400     13
#    2  K  -3103570.084  694364.1301      1   5327    146 3.80e+06    1557     40
#    3  K  -3103570.084  694087.8153      1    980   4693 3.80e+06    1855     42
#    4  K  -3103570.084  694030.2506      1     70    948 3.80e+06    1897     43
#    5  K  -3103570.084  694029.2494      1    232     63 3.80e+06    1903     43
#    6  K  -3103570.084  694029.2494      1     16    229 3.80e+06    1899     43
#    7  K  -3103570.084  694029.2494      1     14     15 3.80e+06    1899     44
#    8  K  -3103570.084  694029.2494      1     12     14 3.80e+06    1897     44
#    9  K  -3103570.084  694029.2494      1     11     12 3.80e+06    1896     44
# R        -3103083.201  694029.2494      2               3.80e+06       0     45
# R         132793.3871  694029.2494      3                 80.87%       0     45
#   10  K   132793.3871  694029.2494      3     10     11   80.87%    1895     45
#   11  K   132793.3871  694029.2494      3      9     10   80.87%    1894     45
#   12  K   132793.3871  694029.2494      3      8      9   80.87%    1893     45
#   13  K   132793.3871  694029.2494      3      7      8   80.87%    1892     46
#   14  K   132793.3871  694029.2494      3      6      7   80.87%    1891     46
#   15  K   132793.3871  694029.2494      3      4     10   80.87%    1890     46
#   16  G   132793.3871  693994.1411      3     92      0   80.87%    1890     47
#   17  G   132793.3871  693964.7102      3    118    211   80.86%    1949     48
# Heuristic search 'R' started
# R         134608.8873  693964.7102      4                 80.60%       0     49
# R         135541.4212  693964.7102      5                 80.47%       0     49
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 955
# Cut elements in the matrix : 18214
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 173MB (peak 232MB, 20MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  135541.4212  693834.0576      5      2      1   80.46%    1894     54
#        2  135541.4212  693834.0576      5      2      3   80.46%    1475     63
#        3  135541.4212  691954.8743      5      3      4   80.41%    1603     69
#        4  135541.4212  691954.8743      5      3      3   80.41%    1512     71
#        5  135541.4212  691954.8743      5      4      4   80.41%    1231     72
#        6  135541.4212  691954.8743      5      5      5   80.41%    1000     73
#        7  135541.4212  678290.9288      5      7      5   80.02%    1562     83
#        8  135541.4212  678290.9288      5      8      4   80.02%    1028     84
#        9  135541.4212  678290.9288      5      9      5   80.02%    1180     85
#       10  135541.4212  678290.9288      5      9      5   80.02%     608     85
#       20  135541.4212  678290.9288      5     17      9   80.02%     217     90
# *     29  652326.0946  678290.9288      6     27     18    3.83%       0     90
#       31  652326.0946  678290.9288      6     27     18    3.83%       1     90
#       46  652326.0946  678290.9288      6     11      1    3.83%       1     90
#       57  652326.0946  678290.9288      6     14      6    3.83%    1598     91
# *     58  663728.1469  678290.9288      7     14     14    2.15%       0     91
#       67  663728.1469  678290.9288      7      6      1    2.15%       1     91
#       77  663728.1469  678290.9288      7      3      1    2.15%       1     91
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 6.637281468780447e+05
# Final MIP bound                       : 6.637290211763608e+05
#   Solution time / primaldual integral :     92.00s/ 88.968983%
#   Number of solutions found / nodes   :         7 /        81
#   Max primal violation      (abs/rel) : 1.341e+11 / 4.976e-09
#   Max integer violation     (abs    ) : 5.048e-09
# Problem is nonlinear postsolved
# Heap usage: 56MB (peak 1017MB, 1213KB system)
# Final MILP objective (global optimum)   : 6.637281468780884e+05
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :                92.502s
#   Time checks (ticks) :        2
# *** Search completed ***
# Optimal objective: 663728.1468780884
# Original problem size
#    linear:    84722 rows, 45941 columns, 266379 linear coefficients
#    nonlinear: 1020 coefficients, 6120 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 660 MIN/MAX to optimizer MIP constructs
#    converted 1020 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    84722 rows, 46601 columns, 267399 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 14:01:23, Jul 15, 2023
# Heap usage: 47MB (peak 48MB, 28MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#      84722 rows        46601 cols       267399 elements     45940 entities
#        660 gencons
# Presolved problem has:
#      63799 rows        41749 cols       205420 elements     41089 entities
#       1301 inds
# LP relaxation tightened
# Presolve finished in 3 seconds
# Heap usage: 70MB (peak 95MB, 28MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  9.03e+04] / [ 1.00e+00,  4.52e+04]
#   Objective      [min,max] : [ 2.64e-02,  9.90e+01] / [ 2.64e-02,  9.90e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 18, support set: 24149
#  Number of orbits: 10127, largest orbit: 3
#  Row orbits: 15587, row support: 37169
# Will try to keep branch and bound tree memory usage below 60.7GB
#  *** Solution found: -41021.02871   Time:   4.18    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   4s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  1332726.2   .0000000 |  B  23626552.  2.753E+09
#  D  1040484.0   .0000000 |  B  507074.33  2500361.1
#  D  930494.48   .0000000 |  B  779354.23  796389.47
#  D  867441.38   .0000000 |  B  781885.98  782238.47
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 8989 simplex iterations, 3.29s
#    Barrier: 47 barrier and 612 simplex iterations, 3.27s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       781951.9022      P      0     0        .000000     7
# Barrier solved problem
#   47 barrier and 612 simplex iterations in 3.34 seconds at time 7
#
# Final objective                       : 7.819519021900195e+05
#   Max primal violation      (abs/rel) : 4.547e-13 / 4.547e-13
#   Max dual violation        (abs/rel) : 2.776e-17 / 2.776e-17
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K  -41021.02871  756723.2630      1    851      0  797744     1395     24
#    2  K  -41021.02871  616121.4866      1  10000    415  657143     2484     73
#    3  K  -41021.02871  585480.6322      1  10000   9330  626502     2715     92
#    4  K  -41021.02871  585343.1175      1    534   9858  626364     2118     93
#    5  K  -41021.02871  585343.1175      1    234    505  626364     2108     94
#    6  K  -41021.02871  585343.1175      1    246    226  626364     2106     94
#    7  K  -41021.02871  585343.1175      1    242    236  626364     2106     95
#    8  K  -41021.02871  585343.1175      1    217    234  626364     2104     95
#    9  K  -41021.02871  585343.1175      1    251    212  626364     2101     96
#   10  K  -41021.02871  585343.1175      1    235    248  626364     2098     97
#   11  K  -41021.02871  585343.1175      1    243    231  626364     2095     98
#   12  K  -41021.02871  585343.1175      1    229    242  626364     2092     98
#   13  K  -41021.02871  585343.1175      1    231    228  626364     2090     99
#   14  K  -41021.02871  585343.1175      1    156    230  626364     2088     99
#   15  K  -41021.02871  585343.1175      1    298    454  626364     2087     99
#   16  G  -41021.02871  585160.9306      1     49      0  626182     2086    101
#   17  G  -41021.02871  585157.2031      1      9     54  626178     2108    102
# Heuristic search 'R' started
# R         526260.1918  585157.2031      2                 10.07%       0    104
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 1322
# Cut elements in the matrix : 36375
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 232MB (peak 297MB, 29MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  526260.1918  584935.2406      2      2      1   10.03%    2100    114
#        2  526260.1918  584935.2406      2      2      3   10.03%    1324    120
#        3  526260.1918  584935.2406      2      3      4   10.03%    1014    123
#        4  526260.1918  584935.2406      2      3      4   10.03%    1114    126
#        5  526260.1918  584935.2406      2      4      5   10.03%    1008    127
#        6  526260.1918  584935.2406      2      5      6   10.03%     186    128
#        7  526260.1918  584935.2406      2      6      7   10.03%     177    129
#        8  526260.1918  577079.8689      2      7      3    8.81%    1740    136
#        9  526260.1918  576778.8262      2      8      7    8.76%     179    136
#       10  526260.1918  576778.8262      2      7      4    8.76%    1310    137
#       20  526260.1918  576778.8262      2     16     12    8.76%       9    156
# *     25  548843.3517  576778.8262      3     22     17    4.84%       0    156
#       35  548843.3517  576778.8262      3     13      1    4.84%       1    156
#       45  548843.3517  576778.8262      3      6      8    4.84%     551    158
#       55  548843.3517  576778.8262      3      6     14    4.84%       3    159
# *     61  559049.1810  576778.8262      4     12     16    3.07%       0    160
#       65  559049.1810  576778.8262      4     11      1    3.07%       1    160
#       75  559049.1810  576778.8262      4      9     13    3.07%     115    160
#       85  559049.1810  576778.8262      4     10      1    3.07%       1    160
# Elapsed time (sec): 160, estimated tree completion: 0.44343
# Heap usage: 2049MB (peak 2049MB, 29MB system)
# B&B tree size: 3.0MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#       95  559049.1810  576778.8262      4      8      1    3.07%       1    160
#      106  559049.1810  576778.8262      4      5     16    3.07%     131    160
# E    117  564301.4444  576778.8262      5      3      9    2.16%       0    161
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=1.3857e-06).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=1.3857e-06).
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      5 out of      1107 (ratio: 0.0045)
#    Predicted att. level   : 0.3177
# Uncrunching matrix
# Final MIP objective                   : 5.643014443921534e+05
# Final MIP bound                       : 5.643022263440556e+05
#   Solution time / primaldual integral :    162.24s/ 67.488383%
#   Number of solutions found / nodes   :         5 /       120
#   Max primal violation      (abs/rel) : 1.961e-09 / 1.961e-09
#   Max integer violation     (abs    ) : 3.657e-09
# Problem is nonlinear postsolved
# Heap usage: 70MB (peak 2049MB, 1478KB system)
# Final MILP objective (global optimum)   : 5.643014443921504e+05
#   Max validation error      (abs/rel) :      .000 /      .000
#   Observed primal integral :  100.000%
#   Total time :               163.164s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 564301.4443921504
# Original problem size
#    linear:    101322 rows, 54941 columns, 318579 linear coefficients
#    nonlinear: 1220 coefficients, 7320 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 580 MIN/MAX to optimizer MIP constructs
#    converted 1220 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    101322 rows, 55521 columns, 319799 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 14:05:03, Jul 15, 2023
# Heap usage: 56MB (peak 57MB, 28MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     101322 rows        55521 cols       319799 elements     54940 entities
#        580 gencons
# Presolved problem has:
#      75473 rows        49299 cols       243612 elements     48719 entities
#       1144 inds
# LP relaxation tightened
# Presolve finished in 4 seconds
# Heap usage: 84MB (peak 114MB, 28MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  8.05e+04] / [ 1.00e+00,  8.05e+04]
#   Objective      [min,max] : [ 1.77e-02,  9.80e+01] / [ 1.77e-02,  9.80e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 32, support set: 38171
#  Number of orbits: 13243, largest orbit: 5
#  Row orbits: 20383, row support: 58751
# Will try to keep branch and bound tree memory usage below 60.7GB
#  *** Solution found: -86260.42715   Time:   5.09    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   5s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  1341110.4   .0000000 |  B  94837656.  4.530E+09
#  D  1109855.3   .0000000 |  B  653717.60  4630654.8
#  D  1017453.5   .0000000 |  B  920528.74  937052.34
#  D  980574.23   .0000000 |  B  923208.08  924021.83
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 9417 simplex iterations, 3.78s
#    Barrier: 42 barrier and 700 simplex iterations, 3.77s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       923401.2012      P      0     0        .000000     8
# Barrier solved problem
#   42 barrier and 700 simplex iterations in 3.83 seconds at time 8
#
# Final objective                       : 9.234012011656257e+05
#   Max primal violation      (abs/rel) : 1.110e-16 / 8.074e-17
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         87766.15711  683170.6518      2                 87.15%       0     98
# R         87783.62154  683170.6518      3                 87.15%       0     99
# R         479413.2040  683170.6518      4                 29.83%       0    100
# R         500999.3153  683170.6518      5                 26.67%       0    100
# R         501250.9571  683170.6518      6                 26.63%       0    102
# R         501515.0451  683170.6518      7                 26.59%       0    102
# R         501761.6548  683170.6518      8                 26.55%       0    102
# R         502005.5988  683170.6518      9                 26.52%       0    102
# R         524938.3185  683170.6518     10                 23.16%       0    103
#    1  K   524938.3185  683170.6518     10  10000      0   23.16%    1080    103
#    2  K   524938.3185  625785.3478     10  10000   9149   16.12%    5082    143
#    3  K   524938.3185  623717.1329     10   6116   9936   15.84%    4653    156
#    4  K   524938.3185  623573.8618     10    462   5870   15.82%    3618    161
#    5  K   524938.3185  623572.2224     10    202    388   15.82%    3758    163
#    6  K   524938.3185  623572.0757     10    206    188   15.82%    3548    163
#    7  K   524938.3185  623572.0757     10     82    203   15.82%    3546    164
#    8  K   524938.3185  623572.0757     10     76     80   15.82%    3545    165
#    9  K   524938.3185  623572.0757     10     65     74   15.82%    3545    165
# R         537218.9150  623572.0757     11                 13.85%       0    167
# R         543139.4821  623572.0757     12                 12.90%       0    167
#   10  K   543139.4821  623572.0757     12     62     63   12.90%    3545    167
#   11  K   543139.4821  623572.0757     12     55     60   12.90%    3545    168
#   12  K   543139.4821  623569.4961     12     32     53   12.90%    3545    169
#   13  K   543139.4821  623568.0948     12     32     31   12.90%    3544    170
#   14  K   543139.4821  623567.8997     12     17     32   12.90%    3545    171
#   15  K   543139.4821  623567.8997     12     13     26   12.90%    3542    172
#   16  G   543139.4821  623567.3388     12      8      0   12.90%    3542    173
#   17  G   543139.4821  623544.8634     12     31      7   12.89%    3540    174
#   18  G   543139.4821  623544.3003     12    111    124   12.89%    3547    175
# Heuristic search 'R' started
# R         543561.6377  623544.3003     13                 12.83%       0    176
# Heuristic search 'R' stopped
# M         544362.4563  623544.3003     14                 12.70%       0    177
# M         545155.2443  623544.3003     15                 12.57%       0    178
# M         545940.0901  623544.3003     16                 12.45%       0    180
# M         546717.0539  623544.3003     17                 12.32%       0    185
# M         547486.2465  623544.3003     18                 12.20%       0    187
# M         548247.7434  623544.3003     19                 12.08%       0    188
#
# Cuts in the matrix         : 1286
# Cut elements in the matrix : 27424
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 293MB (peak 374MB, 30MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  548247.7434  623388.6598     19      2      1   12.05%    3554    197
#        2  548247.7434  612796.0642     19      2      3   10.53%    2712    211
#        3  548247.7434  612796.0642     19      2      3   10.53%    2862    214
# ...
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#     15       867995.3903      P      0     0        .000000   126
# Barrier solved problem
#   96 barrier and 4833 simplex iterations in 82.17 seconds at time 126
#
# Final objective                       : 8.679953903411152e+05
#   Max primal violation      (abs/rel) : 3.695e-13 / 3.695e-13
#   Max dual violation        (abs/rel) : 1.041e-17 / 1.041e-17
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# Heuristic s running ( 20742 LP iterations in    3.5 seconds)
# Heuristic s running ( 40897 LP iterations in   11.8 seconds)
# Heuristic t running ( 25812 LP iterations in    3.2 seconds)
# Heuristic t running ( 47195 LP iterations in   26.7 seconds)
#    1  K                640572.7959      0  10000      0             4933   3419
#    2  K                592020.3420      0  10000   5789            14343   6383
#    3  K                586103.9767      0  10000  10161            21542   6922
#    4  K                585841.2902      0   1707   9262            11695   6964
#    5  K                585498.2127      0    974   1627            11580   6997
#    6  K                585164.9273      0   1213    906            11730   7035
#    7  K                584990.3079      0    709   1142            11710   7053
#    8  K                584979.0227      0    331    620            11771   7081
#    9  K                584975.5849      0    348    327            11699   7095
# R         96856.96388  584975.3061      1                 83.44%       0   7123
# R         545023.2455  584975.3061      2                  6.83%       0   7125
#   10  K   545023.2455  584975.3061      2    249    343    6.83%   11704   7125
#   11  K   545023.2455  584974.8699      2    111    246    6.83%   11702   7133
#   12  K   545023.2455  584974.4302      2     83    108    6.83%   11702   7141
#   13  K   545023.2455  584921.3990      2     44     81    6.82%   11701   7159
#   14  K   545023.2455  584879.8173      2     57     43    6.81%   11742   7171
#   15  K   545023.2455  584874.5191      2    139    189    6.81%   11708   7181
#   16  G   545023.2455  584874.0313      2    128      1    6.81%   11732   7183
#   17  G   545023.2455  584873.8543      2     45    171    6.81%   11734   7186
# Heuristic search 'R' started
# R         545144.4463  584873.8543      3                  6.79%       0   7218
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 5122
# Cut elements in the matrix : 103642
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 1924MB (peak 2589MB, 239MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  545144.4463  584477.6546      3      2      1    6.73%   11736   7376
#        2  545144.4463  584477.6546      3      2      2    6.73%   11736   7585
#        3  545144.4463  555376.2669      3      1      3    1.84%     158   8221
# Will try to keep branch and bound tree memory usage below 50.9GB
#        4  545144.4463  548372.0502      3      2      3    0.59%     158   8227
#        5  545144.4463  548333.9243      3      1      4    0.58%      41   8252
# E      5  548066.9436  548333.9243      4      1      4    0.05%       0   8257
#        6  548066.9436  548080.6418      4      1      1    0.00%       1   8258
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=2.49932e-05).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=2.49932e-05).
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      4 out of       139 (ratio: 0.0288)
# Uncrunching matrix
# Final MIP objective                   : 5.480669435716174e+05
# Final MIP bound                       : 5.480806418461554e+05
#   Solution time / primaldual integral :   8258.75s/ 86.988369%
#   Number of solutions found / nodes   :         4 /         6
#   Max primal violation      (abs/rel) : 2.602e+12 / 8.151e-09
#   Max integer violation     (abs    ) : 1.227e-08
# Problem is nonlinear postsolved
# Heap usage: 654MB (peak 3303MB, 12MB system)
# Final MILP objective (global optimum)   : 5.480669435719140e+05
#   Max validation error      (abs/rel) :      .000 /      .000
#   Observed primal integral :  100.000%
#   Total time :              8271.647s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 548066.943571914
# Original problem size
#    linear:    815122 rows, 441941 columns, 2563179 linear coefficients
#    nonlinear: 9820 coefficients, 58920 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 1020 MIN/MAX to optimizer MIP constructs
#    converted 9820 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    815122 rows, 442961 columns, 2572999 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 4:34:49, Jul 21, 2023
# Heap usage: 450MB (peak 459MB, 229MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     815122 rows       442961 cols      2572999 elements    441940 entities
#       1020 gencons
# Presolved problem has:
#     592781 rows       385589 cols      1924086 elements    384569 entities
#       2015 inds
# LP relaxation tightened
# Presolve finished in 35 seconds
# Heap usage: 666MB (peak 911MB, 229MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.05e+05] / [ 1.00e+00,  2.62e+04]
#   Objective      [min,max] : [ 1.14e-03,  8.60e+01] / [ 1.14e-03,  8.60e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 57.5GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  47s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  1540077.8   .0000000 |           factorize
#  D  1379782.5   .0000000 |  B  2.780E+08  4.005E+10
#  D  1319045.8   .0000000 |  B  1.491E+08  3.107E+10
#  D  1257966.7   .0000000 |  B  43885227.  2.964E+10
#  D  1223679.7   .0000000 |  B  12392848.  1.161E+10
#  D  1204138.0   .0000000 |  B -626746.60  1.046E+10
#  D  1178004.1   .0000000 |  B -1171230.9  2.172E+09
#  D  1164574.6   .0000000 |  B -722860.68  2.207E+08
#  D  1143194.1   .0000000 |  B -473767.80  71096348.
#  D  1128878.4   .0000000 |  B -400485.68  37840914.
#  D  1108231.5   .0000000 |  B -364731.16  36883047.
#  D  1087912.6   .0000000 |  B -255816.85  19534500.
#  D  1077191.1   .0000000 |  B -136315.53  10744777.
#  D  1063745.5   .0000000 |  B  281220.36  3457752.6
#  D  1054060.7   .0000000 |  B  378623.49  2433060.5
#  D  1047435.8   .0000000 |  B  523481.54  1485481.6
#  D  1042107.1   .0000000 |  B  567467.74  1188400.5
#  D  1026011.0   .0000000 |  B  628340.01  933925.06
#  D  968415.14   .0000000 |  B  647576.07  868861.74
#  D  952769.87   .0000000 |  B  659768.60  824673.52
#
#               Concurrent-Solve,  70s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  951617.28   .0000000 |  B  681161.39  780990.08
#  D  950546.04   .0000000 |  B  680166.14  780766.40
#  D  945849.44   .0000000 |  B  693344.20  751308.33
#  D  937568.17   .0000000 |  B  695169.45  748385.39
#  D  934036.27   .0000000 |  B  699079.19  734482.13
#  D  928640.11   .0000000 |  B  701033.57  730729.28
#  D  923617.09   .0000000 |  B  703504.90  723956.45
#  D  917056.88   .0000000 |  B  703875.92  723220.62
#  D  913114.05   .0000000 |  B  705085.43  718481.27
#  D  910906.77   .0000000 |  B  705264.33  717733.03
#  D  908025.52   .0000000 |  B  705662.25  715049.64
#  D  905451.75   .0000000 |  B  705718.96  714903.88
#  D  902864.41   .0000000 |  B  705865.74  714618.18
#  D  900661.04   .0000000 |  B  705923.35  713899.57
#  D  898849.82   .0000000 |  B  705971.87  713864.01
#  D  897109.30   .0000000 |  B  706127.66  712772.32
#  D  891831.55   .0000000 |  B  706336.22  712429.96
#  D  884055.25   .0000000 |  B  706561.78  711718.82
#  D  877455.54   .0000000 |  B  706677.00  711348.99
#  D  873095.50   .0000000 |  B  706857.04  710548.85
#
#               Concurrent-Solve,  94s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  868962.86   .0000000 |  B  706872.52  710317.83
#  D  863249.52   .0000000 |  B  706958.02  709686.24
#  D  860339.57   .0000000 |  B  706989.86  709010.50
#  D  856671.31   .0000000 |  B  707017.77  708773.07
#  D  850866.29   .0000000 |  B  707018.05  708769.49
#  D  845033.12   .0000000 |  B  707019.22  708726.14
#  D  841884.05   .0000000 |  B  707085.91  708578.30
#  D  839850.92   .0000000 |  B  707102.02  708311.76
#  D  838186.52   .0000000 |  B  707135.71  708059.96
#  D  835921.95   .0000000 |  B  707146.71  707609.60
#  D  833900.58   .0000000 |  B  707164.59  707483.16
#  D  832365.63   .0000000 |  B  707168.68  707465.55
#  D  829421.49   .0000000 |  B  707184.22  707315.92
#  D  826889.77   .0000000 |  B  707189.65  707306.59
#  D  825123.15   .0000000 |  B  707209.71  707276.40
#  D  823589.42   .0000000 |  B  707215.84  707236.71
#  D  820421.58   .0000000 |  B  707222.88  707225.35
#  D  816490.97   .0000000 |  B  707223.50  707223.56
#  D  813810.61   .0000000 |  B  707223.55  707223.55
#  D  810535.82   .0000000 |  P  707223.55   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 54597 simplex iterations, 73.46s
#    Barrier: 83 barrier and 4026 simplex iterations, 73.32s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#     51       707223.5473      P      0     0        .000000   120
# Barrier solved problem
#   83 barrier and 4026 simplex iterations in 73.98 seconds at time 120
#
# Final objective                       : 7.072235472641875e+05
#   Max primal violation      (abs/rel) : 1.620e-12 / 1.620e-12
#   Max dual violation        (abs/rel) : 1.388e-17 / 1.388e-17
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# Heuristic s running ( 20036 LP iterations in    3.8 seconds)
# Heuristic s running ( 40792 LP iterations in   11.1 seconds)
# Heuristic s running ( 61382 LP iterations in   65.3 seconds)
# Heuristic t running ( 25174 LP iterations in    3.6 seconds)
# Heuristic t running ( 45786 LP iterations in   23.1 seconds)
#    1  K                597376.6589      0  10000      0             9877   4224
#    2  K                566449.5258      0  10000   7997            28946   7562
#    3  K                561373.3847      0  10000  10198            31516   9027
#    4  K                560756.2271      0  10000   9138            28474   9764
#    5  K                559153.0973      0  10000   9720            27413  10550
#    6  K                558100.5065      0  10000   9431            27423  10807
#    7  K                558044.4322      0    203   9392            15964  10834
#    8  K                557986.3523      0    128    220            15917  10859
#    9  K                557942.6826      0     69    128            16048  10886
# R         503770.2389  557909.3266      1                  9.70%       0  11208
#   10  K   503770.2389  557909.3266      1     64     71    9.70%   15985  11436
#   11  K   503770.2389  557866.3936      1    322     70    9.70%   15807  11474
#   12  K   503770.2389  557859.9493      1     94    293    9.70%   15824  11488
#   13  K   503770.2389  557854.8893      1    116     90    9.70%   15990  11501
#   14  K   503770.2389  557854.8751      1    170    116    9.70%   15777  11510
#   15  K   503770.2389  557854.8751      1     86    247    9.70%   15729  11519
#   16  G   503770.2389  557795.0014      1     12      0    9.69%   15731  11543
#   17  G   503770.2389  557725.1332      1   5277     21    9.67%   16031  11576
#   18  G   503770.2389  557719.9186      1     58   5332    9.67%   16058  11580
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 4135
# Cut elements in the matrix : 69501
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 1981MB (peak 2641MB, 240MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  503770.2389  557666.0306      1      2      1    9.66%   16011  11740
#        2  503770.2389  557523.7871      1      2      3    9.64%   10745  12138
# Will try to keep branch and bound tree memory usage below 50.6GB
#        3  503770.2389  557523.7871      1      3      4    9.64%    5986  12430
#        4  503770.2389  557523.7871      1      4      5    9.64%    1749  12484
#        5  503770.2389  557523.7871      1      5      6    9.64%    1749  12489
#        6  503770.2389  557523.7871      1      6      7    9.64%    1744  12493
#        7  503770.2389  557523.7871      1      7      7    9.64%    3234  12503
#        8  503770.2389  557523.7871      1      8      8    9.64%    3234  12507
#        9  503770.2389  557523.7871      1      9      9    9.64%    3230  12511
#       10  503770.2389  557523.7871      1     10      8    9.64%      27  12516
#       20  503770.2389  557523.7871      1     19     15    9.64%    1726  12554
# *     28  530645.5578  557523.7871      2     28     23    4.82%       0  12564
#       30  530645.5578  557523.7871      2     28     23    4.82%       1  12564
#       54  530645.5578  557523.7871      2      3      1    4.82%       1  12564
# Will try to keep branch and bound tree memory usage below 48.0GB
# Will try to keep branch and bound tree memory usage below 44.3GB
#       64  530645.5578  557523.7871      2      6     11    4.82%      52  12640
#       74  530645.5578  557523.7871      2     15     12    4.82%      61  12652
#       84  530645.5578  557523.7871      2     25     15    4.82%      53  12661
#       94  530645.5578  557523.7871      2     35     24    4.82%      25  12668
#      104  530645.5578  557523.7871      2     45     20    4.82%      45  12672
# Elapsed time (sec): 12677, estimated tree completion: 0.34624
# Heap usage: 9577MB (peak 9577MB, 240MB system)
# B&B tree size: 31MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# *    110  536341.1996  557523.7871      3     52     23    3.80%       0  12677
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      5 out of      1184 (ratio: 0.0042)
#    Predicted att. level   : 0.2986
# Uncrunching matrix
# Final MIP objective                   : 5.363411995682254e+05
# Final MIP bound                       : 5.363419067917727e+05
#   Solution time / primaldual integral :  15628.37s/ 73.223232%
#   Number of solutions found / nodes   :         3 /       175
#   Max primal violation      (abs/rel) : 9.170e+02 / 1.006e-10
#   Max integer violation     (abs    ) : 1.040e-10
# Problem is nonlinear postsolved
# Heap usage: 667MB (peak 9577MB, 12MB system)
# Final MILP objective (global optimum)   : 5.363411995682190e+05
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :              15641.45s
#   Time checks (ticks) :        2
# *** Search completed ***
# Optimal objective: 536341.199568219

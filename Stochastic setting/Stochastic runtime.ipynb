# %% [markdown]
# # Random sample generation

# %%
from xpress import *
import numpy as np
np.random.seed(8)  # Set the seed for reproducibility

N_scenarios =  5 # Number of scenarios to generate
def scenario_generation(N_scenarios):
    KT_values = {}  # Dictionary to store the generated values of KT
    for scenario in range(1, N_scenarios+1):
        KT_values[scenario] = np.random.poisson(100)  # Generate a Poisson-distributed value with mean 100
    return KT_values

# Accessing the KT values for a specific scenario
scenario_number = 1  # Example scenario number
KT_values = scenario_generation(20)
KT_value = KT_values[scenario_number]
#print(f"KT value for scenario {scenario_number}: {KT_value}")
print(KT_values)
# Out:
# {1: 113, 2: 92, 3: 98, 4: 101, 5: 102, 6: 108, 7: 103, 8: 95, 9: 87, 10: 82, 11: 97, 12: 96, 13: 120, 14: 98, 15: 110, 16: 81, 17: 109, 18: 99, 19: 90, 20: 91}

# %% [markdown]
# # Items generation

# %%
import random

def generate_item_data(num_items):
    volumes = {}
    demand = {}
    costs = {}
    alpha = {}
    beta = {}
    price = {}
    display_min = {}

    for i in range(1, num_items + 1):
        volumes[i] = int(random.uniform(0.01, 10))  # Random volume for item i
        demand[i] = int(random.randint(1, 16))  # Random demand for item i
        costs[i] = int(random.uniform(1.0, 101.0))  # Random cost for item i
        price[i] = 2 * costs[i]
        display_min[i] = int(random.uniform(50,70))

        for j in range(1, num_items + 1):
            if i == j:
                alpha[(j, i)] = 0.0
                beta[(j, i)] = 0.0
            else:
                alpha[(j, i)] = float("{:.2f}".format(random.uniform(0.1, 0.9)))  # Random alpha for item j -> item i
                beta[(j, i)] = float("{:.2f}".format(random.uniform(0.1, 0.9)))  # Random beta for item j -> item i

    return volumes, demand, costs, alpha, beta, price, display_min


# Specify the number of items
num_items = 20

# Generate item data
volumes, demand, costs, alpha, beta,price, display_min = generate_item_data(num_items)

# %% [markdown]
# # Stochastic program

# %%
import xpress as xp
import numpy as np

#defining the problem
num_items = 50
volumes, demand, costs, alpha, beta,price, display_min = generate_item_data(num_items)
N_scenarios = 10
KT_values = scenario_generation(N_scenarios)



# Define the set of items
N = list(range(1, num_items + 1))  # Example set of items
lim_prod = 30
# Define the set of scenarios
Omega = list(range(1, len(KT_values) + 1))  # Example set of scenarios

w = volumes
d = demand
alpha = alpha
beta = beta
p = price
c = costs
display_min = display_min
C = 100 * np.dot(np.array(list(d.values())), np.array(list(w.values())))  # Example budget constraint
M = 1000000000000000000000000  # Example capacity constraint
delta = 0.7  # Example substitution constraint
KT = KT_values

# Define the model
model = xp.problem(name="Stochastic Assortment Optimization")


# Define the decision variables
x = np.array([xp.var(vartype=xp.binary, name=f'x_{i}') for i in N])
m = {(i,omega): xp.var(vartype=xp.integer, lb=0, name=f'm_{i}_{omega}')for omega in Omega for i in N}
u = np.array([xp.var(vartype=xp.integer, lb=0, name=f'u_{i}') for i in N])
mu = {(i,omega): xp.var(vartype=xp.binary, name=f'mu_{i}_{omega}')for omega in Omega for i in N}
mu_1 = {(i,omega): xp.var(vartype=xp.binary, name=f'mu_1_{i}_{omega}')for omega in Omega for i in N}
v_plus = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'v_plus_{i}_{omega}') for omega in Omega for i in N}
v_minus = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'v_minus_{i}_{omega}') for i in N for omega in Omega}
q_dict = {
    (i, j, omega): xp.var(vartype=xp.integer, lb=0, name=f'q_{i}_{j}_{omega}')
    for i in N for j in N for omega in Omega
}
s_dict = {
    (i, j, omega): xp.var(vartype=xp.integer, lb=0, name=f's_{i}_{j}_{omega}')
    for i in N for j in N  for omega in Omega
}
#model.addVariables(x, m, u, v_plus, v_minus, q_dict, s_dict, mu, mu_1)
model.addVariable(x)
model.addVariable(m)
model.addVariable(u)
model.addVariable(v_plus)
model.addVariable(v_minus)
model.addVariable(q_dict)
model.addVariable(s_dict)
model.addVariable(mu)
model.addVariable(mu_1)


# Define the objective function
expected_profit = xp.Sum(
    xp.Sum(m[(i,omega)] * p[i]  for i in N) for omega in Omega
) / len(Omega)

assortment_substitution_profit = xp.Sum(xp.Sum(xp.Sum(
    p[i] * delta * alpha[(j, i)] * q_dict[(j,i,omega)] for i in N) for j in N )
     for omega in Omega) / len(Omega)
stockout_substitution_profit = xp.Sum(xp.Sum(xp.Sum(
    p[i] * delta * beta[(j, i)] * s_dict[(j,i,omega)] for i in N) for j in N)
     for omega in Omega) / len(Omega)
cost_of_storage = xp.Sum(c[i] * u[i-1] for i in N)

#obj_constraint = xp.Sum(xp.Sum(10000000*(KT[omega]*d[j]-m[(j,omega)]-xp.Sum(delta * beta[(j,i)] * s_dict[(j,i,omega)] for i in N)+KT[omega] * d[j]-xp.Sum(delta * alpha[(j,i)]* q_dict[(j,i,omega)] for i in N)) for j in N)for omega in Omega)


model.setObjective(
    expected_profit + stockout_substitution_profit + assortment_substitution_profit - cost_of_storage,
    sense=xp.maximize,
)

# Define the constraints
budget_constraint = xp.Sum(w[i] * u[i-1] for i in N) <= C
display_constraint = [u[i-1] >= display_min[i]*x[i-1] for i in N]
nbr_prods_constraint = xp.Sum(x[i-1] for i in N)<=lim_prod

capacity_constraints = [u[i-1] <= M * x[i-1] for i in N]  # Changed to a list comprehension
nullity_constraints = [x[i-1]<=u[i-1] for i in N]

min_constraints = []
for i in N:
    for omega in Omega:
        min_constraints.append(m[(i,omega)] == xp.min(u[i-1],KT[omega]*d[i]))
        #min_constraints.append(m[(i,omega)] <= KT[omega]*d[i])
        #min_constraints.append(m[(i,omega)] <= u[i-1])


assortment_constraints = []
for omega in Omega:
    for i in N:
        for j in N:
            if j == i:
                q_dict[j,i,omega] = 0
            if j != i:
                assortment_constraints.append(q_dict[j,i,omega] <= M*x[i-1])
                assortment_constraints.append(q_dict[j,i,omega] <= M*(1-x[j-1]))
        '''assortment_constraints.append(xp.Sum(q_dict[(j,i,omega)] for j in N if j!= i) <= u[i-1] - m[(i,omega)])
    for j in N:
        assortment_constraints.append(xp.Sum(delta * alpha[(j,i)]*q_dict[(j,i,omega)] for i in N if i != j) <= KT[omega]*d[j])'''

        
lost_sales_constraints = []

for omega in Omega:
    for i in N:
        lost_sales_constraints.append(v_plus[(i,omega)]-v_minus[(i,omega)] == m[(i,omega)] +xp.Sum(q_dict[(j,i,omega)] for j in N if j != i) -u[i-1])
        lost_sales_constraints.append(v_plus[(i,omega)] <= M * mu[(i,omega)])
        lost_sales_constraints.append(v_minus[(i,omega)] <= M * mu_1[(i,omega)])
        lost_sales_constraints.append(mu[(i,omega)] + mu_1[(i,omega)] == 1)

stock_out_constraints = []
for i in N:
    for j in N:
        for omega in Omega:
            if i == j:
                s_dict[i,j,omega] = 0
            if j != i:
                stock_out_constraints.append(s_dict[(j, i, omega)] <= M * x[i-1])
                stock_out_constraints.append(s_dict[(j, i, omega)] <= M * x[j-1])
                
'''for omega in Omega:
    for i in N:
        stock_out_constraints.append(xp.Sum(delta * beta[(j,i)] * s_dict[(j,i,omega)] for j in N if j != i) <= v_minus[(i,omega)])
    for j in N:
        stock_out_constraints.append(xp.Sum(delta * beta[(j,i)] *  s_dict[(j,i,omega)] for i in N if i != j) <= KT[omega] * d[j] - m[(j,omega)])'''
global_constraints = []
for omega in Omega:
    for i in N:
        global_constraints.append(xp.Sum(m[(i,omega)] + xp.Sum(q_dict[(i,j,omega)] for j in N if j != i)
                                         + xp.Sum(s_dict[(i,j,omega)] for j in N if j != i)) == KT[omega] * d[i])
        
global_capa_constraints = []
for omega in Omega:
    for i in N:
        global_capa_constraints.append(xp.Sum(m[(i,omega)] + xp.Sum(q_dict[(j,i,omega)] for j in N if j != i)
                                             + xp.Sum(s_dict[(j,i,omega)] for j in N if j != i)) <= u[i-1])
        


model.addConstraint(budget_constraint)
model.addConstraint(capacity_constraints)  
model.addConstraint(nullity_constraints)
model.addConstraint(assortment_constraints)
model.addConstraint(min_constraints)
model.addConstraint(lost_sales_constraints)
model.addConstraint(stock_out_constraints)
model.addConstraint(nbr_prods_constraint)
model.addConstraint(display_constraint)
model.addConstraint(global_constraints)
model.addConstraint(global_capa_constraints)


# Solve the problem

model.solve()
# Get the optimal objective value
optimal_objective_value = model.getObjVal()
print("optimal objective",optimal_objective_value)

# Get the optimal decision variable values
optimal_x = {i: model.getSolution(x[i-1]) for i in N}
optimal_u = {i: model.getSolution(u[i-1]) for i in N}
optimal_s = {(i, j, omega): model.getSolution(s_dict[(i, j, omega)]) for i in N for j in N if j != i for omega in Omega}
optimal_q = {(i, j, omega): model.getSolution(q_dict[(i, j, omega)]) for i in N for j in N if j != i for omega in Omega}
optimal_m = {(i,omega): model.getSolution(m[(i, omega)]) for i in N for omega in Omega}
optimal_v_plus = {(i,omega):model.getSolution(v_plus[(i,omega)]) for i in N for omega in Omega}
optimal_v_minus = {(i,omega):model.getSolution(v_minus[(i,omega)]) for i in N for omega in Omega}
optimal_mu = {(i,omega):model.getSolution(mu[(i,omega)]) for i in N for omega in Omega}
optimal_mu_1 = {(i,omega):model.getSolution(mu_1[(i,omega)]) for i in N for omega in Omega}
# Out:
# Original problem size
#    linear:    101652 rows, 52601 columns, 325896 linear coefficients
#    nonlinear: 500 coefficients, 3000 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 400 MIN/MAX to optimizer MIP constructs
#    converted 500 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    101652 rows, 53001 columns, 326396 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 19:42:57, Jul 14, 2023
# Heap usage: 57MB (peak 58MB, 28MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     101652 rows        53001 cols       326396 elements     52600 entities
#        400 gencons
# Presolved problem has:
#      76316 rows        50720 cols       250960 elements     50320 entities
#        796 inds
# LP relaxation tightened
# Presolve finished in 2 seconds
# Heap usage: 84MB (peak 115MB, 28MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.94e+05] / [ 1.00e+00,  1.94e+05]
#   Objective      [min,max] : [ 8.40e-02,  9.70e+01] / [ 8.40e-02,  9.70e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 2, support set: 19768
#  Number of orbits: 9884, largest orbit: 2
#  Row orbits: 14984, row support: 29968
# Will try to keep branch and bound tree memory usage below 60.7GB
#  *** Solution found: -109411.8200   Time:   2.97    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,   3s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  3156448.2   .0000000 |  B  1.359E+09  7.108E+09
#  D  2505089.4   .0000000 |  B -767851.41  19077811.
#  D  2328673.3   .0000000 |  B  2227477.2  2281847.4
#  D  2282987.4   .0000000 |  B  2250027.4  2250032.5
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 6429 simplex iterations, 2.37s
#    Barrier: 27 barrier and 200 simplex iterations, 2.36s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       2250029.422      P      0     0        .000000     5
# Barrier solved problem
#   27 barrier and 200 simplex iterations in 2.42 seconds at time 5
#
# Final objective                       : 2.250029421767545e+06
#   Max primal violation      (abs/rel) : 1.388e-17 / 8.399e-18
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         1969845.830  2245046.178      2                 12.26%       0      9
#    1  K   1969845.830  2245046.178      2    352      0   12.26%     339      9
#    2  K   1969845.830  2209226.810      2   1209    213   10.84%     588     16
#    3  K   1969845.830  2185915.934      2   1743   1071    9.88%     833     22
#    4  K   1969845.830  2176697.127      2    543   1676    9.50%     851     25
#    5  K   1969845.830  2172598.179      2    477    489    9.33%     773     29
#    6  K   1969845.830  2170124.453      2    382    447    9.23%     776     33
#    7  K   1969845.830  2167610.126      2    849    342    9.12%     871     36
#    8  K   1969845.830  2166656.437      2    480    827    9.08%     784     38
#    9  K   1969845.830  2166325.228      2    557    475    9.07%     748     39
# R         1971433.419  2166282.264      3                  8.99%       0     40
# R         2091472.715  2166282.264      4                  3.45%       0     40
# R         2091636.941  2166282.264      5                  3.45%       0     40
# R         2091802.119  2166282.264      6                  3.44%       0     40
# R         2092002.512  2166282.264      7                  3.43%       0     40
# R         2092326.704  2166282.264      8                  3.41%       0     41
# R         2093094.622  2166282.264      9                  3.38%       0     42
# R         2098363.380  2166282.264     10                  3.14%       0     42
#   10  K   2098363.380  2166282.264     10     39    536    3.14%     722     42
#   11  K   2098363.380  2166276.189     10     21     32    3.14%     632     42
#   12  K   2098363.380  2166275.805     10      5     15    3.13%     641     42
#   13  K   2098363.380  2166275.230     10      2      3    3.13%     632     43
#   14  K   2098363.380  2166274.855     10      9      1    3.13%     642     43
#   15  K   2098363.380  2166274.855     10      0      8    3.13%     635     43
#   16  G   2098363.380  2166261.931     10     36      0    3.13%     635     44
#   17  G   2098363.380  2166252.376     10     33     63    3.13%     636     45
# Heuristic search 'R' started
# R         2099407.246  2166252.376     11                  3.09%       0     46
# R         2099426.094  2166252.376     12                  3.08%       0     46
# R         2100794.823  2166252.376     13                  3.02%       0     46
# R         2139271.163  2166252.376     14                  1.25%       0     47
# Heuristic search 'R' stopped
# M         2139592.509  2166252.376     15                  1.23%       0     48
# M         2139913.688  2166252.376     16                  1.22%       0     50
# M         2140181.811  2166252.376     17                  1.20%       0     52
# M         2140445.172  2166252.376     18                  1.19%       0     53
# M         2140707.686  2166252.376     19                  1.18%       0     56
# M         2140965.655  2166252.376     20                  1.17%       0     59
# M         2141220.924  2166252.376     21                  1.16%       0     64
#
# Cuts in the matrix         : 539
# Cut elements in the matrix : 15484
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 231MB (peak 359MB, 29MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  2141220.924  2165794.021     21      2      1    1.13%     608     82
#        2  2141220.924  2165794.021     21      2      3    1.13%     482     86
#        3  2141220.924  2165794.021     21      3      3    1.13%     482     86
#        4  2141220.924  2163172.720     21      2      4    1.01%     308     87
#        5  2141220.924  2163172.720     21      3      4    1.01%     308     87
#        6  2141220.924  2163172.720     21      2      5    1.01%     239     87
#        7  2141220.924  2163172.720     21      3      6    1.01%     130     88
#        8  2141220.924  2163172.720     21      4      6    1.01%     157     88
#        9  2141220.924  2163172.720     21      5      7    1.01%     146     89
#       10  2141220.924  2163172.720     21      6      8    1.01%       5     89
#       20  2141220.924  2163172.720     21     13      8    1.01%     153     90
#       30  2141220.924  2163172.720     21     20     11    1.01%      26     91
#       40  2141220.924  2163172.720     21     30     16    1.01%      45     92
# E     42  2143663.258  2163172.720     22     33     17    0.90%       0     92
#       68  2143663.258  2163172.720     22      8      1    0.90%       1     92
#       79  2143663.258  2163172.720     22      4     23    0.90%      46     92
#       89  2143663.258  2160756.026     22      4      5    0.79%     562    101
#       99  2143663.258  2160756.026     22      4      6    0.79%     455    105
#      109  2143663.258  2160756.026     22      4      8    0.79%     389    109
# Elapsed time (sec): 115, estimated tree completion: 0.72616
# Heap usage: 3104MB (peak 3104MB, 30MB system)
# B&B tree size: 12MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# E    153  2147067.866  2151766.614     23     22     13    0.22%       0    115
# E    169  2147505.478  2151766.614     24     21     15    0.20%       0    115
# E    208  2147787.539  2150051.197     25      5     16    0.11%       0    116
#      210  2147787.539  2150051.197     25      5     16    0.11%      82    116
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=6.43288e-05).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=6.43288e-05).
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      3 out of      2402 (ratio: 0.0012)
#    Predicted att. level   : 0.3862
# Uncrunching matrix
# Final MIP objective                   : 2.147787538799986e+06
# Final MIP bound                       : 2.147925712241121e+06
#   Solution time / primaldual integral :    116.82s/ 11.768158%
#   Number of solutions found / nodes   :        25 /       212
#   Max primal violation      (abs/rel) : 9.270e+02 / 7.545e-09
#   Max integer violation     (abs    ) : 7.546e-09
# Problem is nonlinear postsolved
# Heap usage: 84MB (peak 3104MB, 1418KB system)
# Final MILP objective (global optimum)   : 2.147787538799995e+06
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :               117.561s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# optimal objective 2147787.538799995

# %% [markdown]
# # Display non negative results

# %%
non_zero_s = {key: value for key, value in optimal_s.items() if value != 0.0}
non_zero_q = {key: value for key, value in optimal_q.items() if value != 0.0}
non_zero_u = {key: value for key, value in optimal_u.items() if value != 0.0}
non_zero_m = {key: value for key, value in optimal_m.items() if value != 0.0}
non_zero_x = {key: value for key, value in optimal_x.items() if value != 0.0}
print("s_dict",non_zero_s)
print("q_dict",non_zero_q)
print("u_val",non_zero_u)
print("m_val",non_zero_m)
print("x_val",non_zero_x)
# Out:
# s_dict {(8, 35, 8): 31.999999999999545, (12, 9, 8): 22.0, (22, 5, 8): 21.999999999999897, (23, 35, 8): 21.999999999999545, (41, 35, 8): 32.00000000000023, (42, 40, 8): 28.0}
# q_dict {(1, 27, 1): 134.9999999999999, (1, 27, 2): 180.0, (1, 27, 3): 90.00000000000011, (1, 27, 4): 170.9999999999998, (1, 27, 5): 17.999999999999886, (1, 27, 6): 63.00000000000034, (1, 27, 7): 17.999999999999886, (1, 27, 9): 170.9999999999999, (1, 27, 10): 117.00000000000011, (1, 49, 1): 61.000000000000114, (1, 49, 3): 115.99999999999989, (1, 49, 4): 17.0000000000002, (1, 49, 5): 204.0000000000001, (1, 49, 6): 148.99999999999966, (1, 49, 7): 204.0000000000001, (1, 49, 8): 226.0, (1, 49, 9): 17.000000000000114, (1, 49, 10): 82.99999999999989, (2, 23, 1): 120.00000000000045, (2, 23, 3): 88.00000000000045, (2, 23, 6): 55.000000000000455, (2, 23, 10): 121.00000000000045, (2, 27, 2): 27.000000000001705, (2, 35, 3): 164.99999999999955, (2, 35, 5): 333.0, (2, 35, 6): 228.0000000075449, (2, 35, 7): 333.0, (2, 35, 8): 339.0, (2, 37, 2): 147.0, (2, 37, 3): 56.0, (2, 37, 4): 10.0, (2, 37, 6): 35.0, (2, 37, 9): 10.0, (2, 37, 10): 77.0, (2, 41, 1): 173.99999999999955, (2, 41, 2): 95.9999999999983, (2, 41, 4): 272.0, (2, 41, 9): 272.0, (2, 41, 10): 101.99999999999955, (3, 14, 8): 12.0, (4, 35, 5): 194.00000000000045, (4, 35, 7): 194.00000000142535, (4, 35, 8): 318.0000000000007, (4, 42, 3): 112.0, (4, 42, 6): 70.0, (4, 42, 10): 154.0, (4, 49, 1): 1372.0, (4, 49, 2): 1260.0000000000014, (4, 49, 3): 1330.0, (4, 49, 4): 1316.0, (4, 49, 5): 1341.9999999999995, (4, 49, 6): 1414.0, (4, 49, 7): 1341.9999999999995, (4, 49, 8): 1263.9999999999993, (4, 49, 9): 1316.0, (4, 49, 10): 1246.0, (4, 50, 5): 18.0, (4, 50, 7): 17.999999998575106, (6, 7, 3): 90.0, (6, 12, 2): 74.99999999999773, (6, 14, 1): 1284.9999999999995, (6, 14, 2): 978.0000000000023, (6, 14, 3): 1272.0000000000007, (6, 14, 4): 1145.0, (6, 14, 5): 980.0000000014265, (6, 14, 6): 1260.0000000000007, (6, 14, 7): 980.0000000014265, (6, 14, 8): 830.000000000001, (6, 14, 9): 1145.0, (6, 14, 10): 1284.0000000000007, (6, 35, 5): 573.9999999985735, (6, 35, 6): 160.99999999997559, (6, 35, 7): 573.9999999985735, (6, 35, 8): 751.999999999999, (6, 50, 1): 87.00000000000057, (6, 50, 2): 207.0, (6, 50, 3): 79.99999999999932, (6, 50, 4): 171.0, (6, 50, 6): 63.0, (6, 50, 9): 171.0, (6, 50, 10): 115.99999999999932, (10, 9, 1): 351.0000000000007, (10, 9, 2): 360.0, (10, 9, 3): 412.0, (10, 9, 4): 376.0, (10, 9, 5): 444.0, (10, 9, 6): 424.0, (10, 9, 7): 444.0, (10, 9, 8): 452.0, (10, 9, 9): 376.0, (10, 9, 10): 380.0000000000007, (10, 31, 1): 40.99999999999932, (10, 31, 10): 19.999999999999318, (11, 9, 1): 1146.9999999999998, (11, 9, 2): 1164.9999999999995, (11, 9, 3): 790.0000000000002, (11, 9, 4): 1032.0, (11, 9, 5): 358.0, (11, 9, 6): 628.0, (11, 9, 7): 358.0, (11, 9, 8): 260.0, (11, 9, 9): 1032.0, (11, 9, 10): 944.9999999999995, (11, 15, 1): 225.00000000000023, (11, 15, 3): 66.00000000000045, (11, 15, 4): 284.0, (11, 15, 9): 284.0, (11, 15, 10): 195.0, (11, 33, 2): 95.00000000000045, (11, 33, 3): 104.0, (11, 33, 6): 65.0, (11, 33, 10): 260.00000000000045, (11, 35, 3): 481.9999999999993, (11, 35, 5): 1196.0, (11, 35, 6): 791.0, (11, 35, 7): 1196.0, (11, 35, 8): 1322.0, (13, 22, 1): 143.0, (13, 22, 3): 88.0, (13, 22, 4): 49.000000000000114, (13, 22, 6): 55.0, (13, 22, 9): 48.99999999999977, (13, 22, 10): 121.0, (13, 35, 3): 351.00000000000057, (13, 35, 5): 777.0, (13, 35, 6): 597.0, (13, 35, 7): 777.0, (13, 35, 8): 791.0, (13, 36, 1): 543.0, (13, 36, 2): 629.0000000000002, (13, 36, 3): 281.99999999999943, (13, 36, 4): 609.0000000000002, (13, 36, 6): 90.00000000000011, (13, 36, 9): 609.0000000000002, (13, 36, 10): 579.0000000000003, (13, 46, 2): 0.9999999999998863, (18, 25, 1): 240.0, (18, 25, 2): 368.0, (18, 25, 3): 160.0, (18, 25, 4): 304.0, (18, 25, 5): 32.0, (18, 25, 6): 112.0, (18, 25, 7): 32.0, (18, 25, 9): 304.0, (18, 25, 10): 208.00000000000023, (18, 44, 1): 838.0, (18, 44, 2): 622.0, (18, 44, 3): 973.0, (18, 44, 4): 730.0, (18, 44, 5): 1189.0, (18, 44, 6): 1054.0, (18, 44, 7): 1189.0, (18, 44, 8): 1243.0, (18, 44, 9): 730.0, (18, 44, 10): 891.9999999999998, (20, 8, 1): 208.00000000000045, (20, 8, 3 ...
# u_val {3: 666.0, 5: 1916.0, 7: 1017.0, 8: 1776.0000000000005, 9: 3075.0, 12: 1221.0, 14: 1684.0000000000007, 15: 1695.0, 16: 1032.9999999999977, 17: 1581.9999999999998, 19: 565.0, 20: 574.0, 22: 1221.0, 23: 1221.0000000000005, 24: 618.0, 25: 1808.0, 26: 1017.0, 27: 1016.9999999999999, 31: 1443.0, 33: 1443.0, 35: 7737.0, 36: 1079.0000000000002, 37: 777.0, 38: 1925.9999999999995, 39: 926.9999999999999, 40: 1642.9999999999989, 41: 1776.0, 42: 1554.0, 43: 1242.9999999999998, 44: 1949.0000000000005, 46: 1202.0000000000027, 49: 2557.999999999999, 50: 1017.0}
# m_val {(3, 1): 588.0, (3, 2): 540.0, (3, 3): 618.0, (3, 4): 563.9999999999999, (3, 5): 666.0, (3, 6): 636.0, (3, 7): 666.0, (3, 8): 666.0, (3, 9): 563.9999999999999, (3, 10): 600.0, (5, 1): 1568.0, (5, 2): 1440.0, (5, 3): 1648.0, (5, 4): 1504.0, (5, 5): 1776.0, (5, 6): 1696.0, (5, 7): 1776.0, (5, 8): 1808.0, (5, 9): 1504.0, (5, 10): 1600.0, (7, 1): 882.0, (7, 2): 810.0, (7, 3): 927.0, (7, 4): 846.0, (7, 5): 999.0, (7, 6): 954.0, (7, 7): 999.0, (7, 8): 1017.0, (7, 9): 846.0, (7, 10): 900.0, (8, 1): 1568.0, (8, 2): 1440.0000000000018, (8, 3): 1648.0000000000002, (8, 4): 1504.0, (8, 5): 1776.0000000000005, (8, 6): 1696.0000000000005, (8, 7): 1776.0000000000005, (8, 8): 1776.0000000000005, (8, 9): 1504.0, (8, 10): 1600.0000000000002, (9, 1): 1568.0, (9, 2): 1440.0, (9, 3): 1648.0, (9, 4): 1504.0, (9, 5): 1776.0, (9, 6): 1696.0, (9, 7): 1776.0, (9, 8): 1808.0, (9, 9): 1504.0, (9, 10): 1600.0, (12, 1): 1078.0, (12, 2): 990.0, (12, 3): 1133.0, (12, 4): 1034.0, (12, 5): 1221.0, (12, 6): 1166.0, (12, 7): 1221.0, (12, 8): 1221.0, (12, 9): 1034.0, (12, 10): 1100.0, (14, 1): 392.0, (14, 2): 360.0, (14, 3): 412.0, (14, 4): 376.0, (14, 5): 444.0, (14, 6): 424.0, (14, 7): 444.0, (14, 8): 452.0, (14, 9): 376.0, (14, 10): 400.0, (15, 1): 1469.9999999999998, (15, 2): 1350.0, (15, 3): 1545.0, (15, 4): 1410.0, (15, 5): 1665.0, (15, 6): 1590.0, (15, 7): 1665.0, (15, 8): 1695.0, (15, 9): 1410.0, (15, 10): 1500.0, (16, 1): 882.0, (16, 2): 810.0, (16, 3): 927.0, (16, 4): 846.0, (16, 5): 999.0, (16, 6): 954.0, (16, 7): 999.0, (16, 8): 1016.9999999999999, (16, 9): 846.0, (16, 10): 900.0, (17, 1): 1372.0, (17, 2): 1260.0, (17, 3): 1442.0, (17, 4): 1316.0, (17, 5): 1554.0, (17, 6): 1484.0, (17, 7): 1554.0, (17, 8): 1581.9999999999998, (17, 9): 1316.0, (17, 10): 1400.0, (19, 1): 490.0, (19, 2): 450.0, (19, 3): 515.0, (19, 4): 470.0, (19, 5): 555.0, (19, 6): 530.0, (19, 7): 555.0, (19, 8): 565.0, (19, 9): 470.0, (19, 10): 500.0, (20, 1): 574.0, (20, 2): 574.0, (20, 3): 574.0, (20, 4): 574.0, (20, 5): 574.0, (20, 6): 574.0, (20, 7): 574.0, (20, 8): 574.0, (20, 9): 574.0, (20, 10): 574.0, (22, 1): 1078.0, (22, 2): 990.0, (22, 3): 1133.0, (22, 4): 1034.0, (22, 5): 1221.0, (22, 6): 1166.0, (22, 7): 1221.0, (22, 8): 1221.0, (22, 9): 1034.0, (22, 10): 1100.0, (23, 1): 1078.0, (23, 2): 990.0, (23, 3): 1133.0, (23, 4): 1034.0, (23, 5): 1221.0, (23, 6): 1166.0, (23, 7): 1221.0, (23, 8): 1221.0000000000005, (23, 9): 1034.0, (23, 10): 1100.0, (24, 1): 588.0, (24, 2): 540.0, (24, 3): 618.0, (24, 4): 564.0, (24, 5): 618.0, (24, 6): 618.0, (24, 7): 618.0, (24, 8): 618.0, (24, 9): 564.0, (24, 10): 600.0, (25, 1): 1568.0, (25, 2): 1440.0, (25, 3): 1648.0, (25, 4): 1504.0, (25, 5): 1776.0, (25, 6): 1696.0, (25, 7): 1776.0, (25, 8): 1808.0, (25, 9): 1504.0, (25, 10): 1599.9999999999998, (26, 1): 882.0, (26, 2): 810.0, (26, 3): 927.0, (26, 4): 846.0, (26, 5): 999.0, (26, 6): 954.0, (26, 7): 999.0, (26, 8): 1017.0, (26, 9): 846.0, (26, 10): 900.0, (27, 1): 882.0, (27, 2): 810.0, (27, 3): 927.0, (27, 4): 846.0, (27, 5): 999.0, (27, 6): 954.0, (27, 7): 999.0, (27, 8): 1016.9999999999999, (27, 9): 846.0, (27, 10): 900.0, (31, 1): 1273.9999999999993, (31, 2): 1169.9999999999998, (31, 3): 1338.9999999999995, (31, 4): 1222.0000000000014, (31, 5): 1443.0, (31, 6): 1378.0, (31, 7): 1443.0, (31, 8): 1443.0, (31, 9): 1222.0000000000014, (31, 10): 1299.9999999999998, (33, 1): 489.99999999999994, (33, 2): 450.0, (33, 3): 515.0, (33, 4): 470.0, (33, 5): 555.0, (33, 6): 530.0, (33, 7): 555.0, (33, 8): 565.0, (33, 9): 470.0, (33, 10): 500.0, (35, 1): 196.0, (35, 2): 180.0, (35, 3): 206.0, (35, 4): 188.0, (35, 5): 222.0, (35, 6): 212.0, (35, 7): 222.0, (35, 8): 226.0, (35, 9): 188.0, (35, 10): 200.0, (36, 1): 490.0, (36, 2): 450.0, (36, 3): 515.0, (36, 4): 470.0, (36, 5): 555.0, (36, 6): 530.0, (36, 7): 555.0, (36, 8): 565.0, (36, 9): 470.0, (36, 10): 499.9999999999999, (37, 1): 686.0, (37, 2): 630.0, (37, 3): 721.0, (37, 4): 658.0, (37, 5): 777.0, (37, 6): 742.0, (37, 7): 777.0, (37, 8): 77 ...
# x_val {3: 1.0, 5: 1.0, 7: 1.0, 8: 1.0, 9: 1.0, 12: 1.0, 14: 1.0, 15: 1.0, 16: 1.0, 17: 1.0, 19: 1.0, 22: 1.0, 23: 1.0, 25: 1.0, 26: 1.0, 27: 1.0, 31: 0.9999999999999996, 33: 1.0, 35: 1.0, 36: 1.0, 37: 1.0, 38: 1.0, 40: 1.0000000000000002, 41: 1.0, 42: 1.0, 43: 1.0, 44: 1.0, 46: 1.0, 49: 1.0, 50: 1.0}

# %% [markdown]
# # Printing demand

# %%
print([((j,omega), KT[omega]*d[j]) for j in N for omega in Omega])
# Out:
# [((1, 1), 500), ((1, 2), 550), ((2, 1), 100), ((2, 2), 110), ((3, 1), 800), ((3, 2), 880), ((4, 1), 800), ((4, 2), 880), ((5, 1), 500), ((5, 2), 550)]

# %%
optimal_u
# Out:
# {1: 565.0, 2: 1808.0, 3: 1017.0, 4: 904.0, 5: 678.0}

# %% [markdown]
# # Measuring runtime

# %%
import xpress as xp
import numpy as np
import time

def measure_runtime(N_scenarios, num_items):
    # defining the problem
    volumes, demand, costs, alpha, beta, price, display_min = generate_item_data(num_items)
    KT_values = scenario_generation(N_scenarios)

    # Define the set of items
    N = list(range(1, num_items + 1))  # Example set of items
    lim_prod = 7
    # Define the set of scenarios
    Omega = list(range(1, len(KT_values) + 1))  # Example set of scenarios

    w = volumes
    d = demand
    alpha = alpha
    beta = beta
    p = price
    c = costs
    display_min = display_min
    C = 100 * np.dot(np.array(list(d.values())), np.array(list(w.values())))  # Example budget constraint
    M = 1000000000000000000000000  # Example capacity constraint
    delta = 0.7  # Example substitution constraint
    KT = KT_values

    # Define the model
    model = xp.problem(name="Stochastic Assortment Optimization")

    # Define the decision variables
    x = np.array([xp.var(vartype=xp.binary, name=f'x_{i}') for i in N])
    m = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'm_{i}_{omega}') for omega in Omega for i in N}
    u = np.array([xp.var(vartype=xp.integer, lb=0, name=f'u_{i}') for i in N])
    mu = {(i, omega): xp.var(vartype=xp.binary, name=f'mu_{i}_{omega}') for omega in Omega for i in N}
    mu_1 = {(i, omega): xp.var(vartype=xp.binary, name=f'mu_1_{i}_{omega}') for omega in Omega for i in N}
    v_plus = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'v_plus_{i}_{omega}') for omega in Omega for i in N}
    v_minus = {(i, omega): xp.var(vartype=xp.integer, lb=0, name=f'v_minus_{i}_{omega}') for i in N for omega in Omega}
    q_dict = {(i, j, omega): xp.var(vartype=xp.integer, lb=0, name=f'q_{i}_{j}_{omega}') for i in N for j in N for omega in Omega}
    s_dict = {(i, j, omega): xp.var(vartype=xp.integer, lb=0, name=f's_{i}_{j}_{omega}') for i in N for j in N for omega in Omega}

    model.addVariable(x)
    model.addVariable(m)
    model.addVariable(u)
    model.addVariable(v_plus)
    model.addVariable(v_minus)
    model.addVariable(q_dict)
    model.addVariable(s_dict)
    model.addVariable(mu)
    model.addVariable(mu_1)

    # Define the objective function
    expected_profit = xp.Sum(xp.Sum(m[(i, omega)] * p[i] for i in N) for omega in Omega) / len(Omega)
    assortment_substitution_profit = xp.Sum(
        xp.Sum(xp.Sum(p[i] * delta * alpha[(j, i)] * q_dict[(j, i, omega)] for i in N) for j in N) for omega in Omega
    ) / len(Omega)
    stockout_substitution_profit = xp.Sum(
        xp.Sum(xp.Sum(p[i] * delta * beta[(j, i)] * s_dict[(j, i, omega)] for i in N) for j in N) for omega in Omega
    ) / len(Omega)
    cost_of_storage = xp.Sum(c[i] * u[i - 1] for i in N)

    model.setObjective(
        expected_profit + stockout_substitution_profit + assortment_substitution_profit - cost_of_storage,
        sense=xp.maximize,
    )

    # Define the constraints
    budget_constraint = xp.Sum(w[i] * u[i - 1] for i in N) <= C
    display_constraint = [u[i - 1] >= display_min[i] * x[i - 1] for i in N]
    nbr_prods_constraint = xp.Sum(x[i - 1] for i in N) <= lim_prod

    capacity_constraints = [u[i - 1] <= M * x[i - 1] for i in N]  # Changed to a list comprehension
    nullity_constraints = [x[i - 1] <= u[i - 1] for i in N]

    min_constraints = []
    for i in N:
        for omega in Omega:
            min_constraints.append(m[(i, omega)] == xp.min(u[i - 1], KT[omega] * d[i]))

    assortment_constraints = []
    for omega in Omega:
        for i in N:
            for j in N:
                if j == i:
                    q_dict[j, i, omega] = 0
                if j != i:
                    assortment_constraints.append(q_dict[j, i, omega] <= M * x[i - 1])
                    assortment_constraints.append(q_dict[j, i, omega] <= M * (1 - x[j - 1]))

    lost_sales_constraints = []
    for omega in Omega:
        for i in N:
            lost_sales_constraints.append(
                v_plus[(i, omega)] - v_minus[(i, omega)] == m[(i, omega)] + xp.Sum(
                    q_dict[(j, i, omega)] for j in N if j != i
                ) - u[i - 1]
            )
            lost_sales_constraints.append(v_plus[(i, omega)] <= M * mu[(i, omega)])
            lost_sales_constraints.append(v_minus[(i, omega)] <= M * mu_1[(i, omega)])
            lost_sales_constraints.append(mu[(i, omega)] + mu_1[(i, omega)] == 1)

    stock_out_constraints = []
    for i in N:
        for j in N:
            for omega in Omega:
                if i == j:
                    s_dict[i, j, omega] = 0
                if j != i:
                    stock_out_constraints.append(s_dict[(j, i, omega)] <= M * x[i - 1])
                    stock_out_constraints.append(s_dict[(j, i, omega)] <= M * x[j - 1])

    global_constraints = []
    for omega in Omega:
        for i in N:
            global_constraints.append(
                xp.Sum(
                    m[(i, omega)] + xp.Sum(q_dict[(i, j, omega)] for j in N if j != i) + xp.Sum(
                        s_dict[(i, j, omega)] for j in N if j != i
                    )
                ) == KT[omega] * d[i]
            )

    global_capa_constraints = []
    for omega in Omega:
        for i in N:
            global_capa_constraints.append(
                xp.Sum(
                    m[(i, omega)] + xp.Sum(q_dict[(j, i, omega)] for j in N if j != i) + xp.Sum(
                        s_dict[(j, i, omega)] for j in N if j != i
                    )
                ) <= u[i - 1]
            )

    model.addConstraint(budget_constraint)
    model.addConstraint(capacity_constraints)
    model.addConstraint(nullity_constraints)
    model.addConstraint(assortment_constraints)
    model.addConstraint(min_constraints)
    model.addConstraint(lost_sales_constraints)
    model.addConstraint(stock_out_constraints)
    model.addConstraint(nbr_prods_constraint)
    model.addConstraint(display_constraint)
    model.addConstraint(global_constraints)
    model.addConstraint(global_capa_constraints)

    # Solve the problem
    start_time = time.time()
    model.solve()
    end_time = time.time()
    runtime = end_time - start_time

    # Get the optimal objective value
    optimal_objective_value = model.getObjVal()
    print("Optimal objective:", optimal_objective_value)

    # Get the optimal decision variable values
    optimal_x = {i: model.getSolution(x[i - 1]) for i in N}
    optimal_u = {i: model.getSolution(u[i - 1]) for i in N}
    optimal_s = {(i, j, omega): model.getSolution(s_dict[(i, j, omega)]) for i in N for j in N if j != i for omega in Omega}
    optimal_q = {(i, j, omega): model.getSolution(q_dict[(i, j, omega)]) for i in N for j in N if j != i for omega in Omega}
    optimal_m = {(i, omega): model.getSolution(m[(i, omega)]) for i in N for omega in Omega}
    optimal_v_plus = {(i, omega): model.getSolution(v_plus[(i, omega)]) for i in N for omega in Omega}
    optimal_v_minus = {(i, omega): model.getSolution(v_minus[(i, omega)]) for i in N for omega in Omega}
    optimal_mu = {(i, omega): model.getSolution(mu[(i, omega)]) for i in N for omega in Omega}
    optimal_mu_1 = {(i, omega): model.getSolution(mu_1[(i, omega)]) for i in N for omega in Omega}

    return runtime

# %%
runtimes = []
input_sample = []

# %%
updatable_input = []
N_scen = 60
N_prod = 60
for i in range (45,N_scen + 1,5):
    for j in range(45,N_prod + 1,5):
        input_sample.append((i,j))
        updatable_input.append((i,j))
# Out:
# 32 16

# %%
updatable_runtimes = []
for ele in updatable_input:
    a = measure_runtime(ele[0],ele[1])
    runtimes.append(a)
    updatable_runtimes.append(a)
# Out:
# Original problem size
#    linear:    370712 rows, 192466 columns, 1187007 linear coefficients
#    nonlinear: 2025 coefficients, 12150 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 1080 MIN/MAX to optimizer MIP constructs
#    converted 2025 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    370712 rows, 193546 columns, 1189032 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 11:30:34, Jul 15, 2023
# Heap usage: 205MB (peak 210MB, 114MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     370712 rows       193546 cols      1189032 elements    192465 entities
#       1080 gencons
# Presolved problem has:
#     277259 rows       183240 cols       910968 elements    182160 entities
#       2118 inds
# LP relaxation tightened
# Presolve finished in 26 seconds
# Heap usage: 304MB (peak 413MB, 114MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.82e+05] / [ 1.00e+00,  1.82e+05]
#   Objective      [min,max] : [ 1.37e-02,  1.00e+02] / [ 1.37e-02,  1.00e+02]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 4, support set: 27986 (partial detection)
#  Number of orbits: 11994, largest orbit: 3
#  Row orbits: 18204, row support: 42476
# Will try to keep branch and bound tree memory usage below 59.4GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  30s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  3704158.1   .0000000 |           factorize
#  D  2938849.0   .0000000 |  B  5.564E+08  2.036E+10
#  D  2531859.5   .0000000 |  B -3675838.1  1.770E+09
#  D  2355574.6   .0000000 |  B -1007787.4  40154157.
#  D  2259531.0   .0000000 |  B  116239.09  12545542.
#  D  2164004.1   .0000000 |  B  1225535.0  5186113.2
#  D  2086054.1   .0000000 |  B  1641987.6  2316849.1
#  D  2025730.3   .0000000 |  B  1710128.4  2033215.6
#  D  1976832.3   .0000000 |  B  1730622.2  1953184.6
#  D  1944872.7   .0000000 |  B  1741227.1  1916553.6
#  D  1903193.4   .0000000 |  B  1751352.1  1874423.1
#  D  1877593.9   .0000000 |  B  1757465.8  1846175.6
#  D  1866468.0   .0000000 |  B  1762278.8  1822621.4
#  D  1854302.0   .0000000 |  B  1766967.3  1811473.5
#  D  1841256.6   .0000000 |  B  1770491.2  1798213.4
#  D  1830456.3   .0000000 |  B  1773242.8  1792529.2
#  D  1825915.1   .0000000 |  B  1775638.5  1788985.4
#  D  1821997.9   .0000000 |  B  1776311.4  1788017.0
#  D  1818711.6   .0000000 |  B  1777008.6  1787046.5
#  D  1813127.7   .0000000 |  B  1777439.4  1785164.3
#
#               Concurrent-Solve,  47s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  1810605.8   .0000000 |  B  1777948.1  1784204.8
#  D  1807806.9   .0000000 |  B  1778144.9  1783110.4
#  D  1805963.5   .0000000 |  B  1778302.7  1781834.5
#  D  1802621.2   .0000000 |  B  1778442.8  1780883.0
#  D  1799198.2   .0000000 |  B  1778553.9  1779678.6
#  D  1797331.0   .0000000 |  B  1778660.1  1779368.6
#  D  1792122.0   .0000000 |  B  1778716.8  1778894.3
#  D  1791431.7   .0000000 |  B  1778760.5  1778777.1
#  D  1790412.2   .0000000 |  B  1778763.8  1778764.0
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 23442 simplex iterations, 24.77s
#    Barrier: 80 barrier and 1011 simplex iterations, 24.72s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       1778763.841      P      0     0        .000000    54
# Barrier solved problem
#   80 barrier and 1011 simplex iterations in 24.99 seconds at time 54
#
# Final objective                       : 1.778763841083942e+06
#   Max primal violation      (abs/rel) : 1.364e-12 / 1.364e-12
#   Max dual violation        (abs/rel) : 6.661e-16 / 6.661e-16
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K                1023017.082      0   3601      0             2876    794
#    2  K                1014531.659      0   3690   1623             5936    978
#    3  K                1013617.017      0    679   3627             5268   1465
#    4  K                1013106.621      0    179   1094             4795   1486
#    5  K                1012782.335      0    229    177             4787   1532
#    6  K                1012777.783      0    142    227             4815   1537
#    7  K                1012724.485      0     58    133             4806   1540
#    8  K                1012724.348      0    143     47             4814   1542
#    9  K                1012724.130      0     50    137             4814   1544
#   10  K                1012723.953      0     48     47             4815   1565
#   11  K                1012723.953      0     35     45             4816   1567
#   12  K                1012723.953      0     30     32             4817   1569
#   13  K                1012723.953      0     27     27             4818   1571
#   14  K                1012723.953      0     24     24             4819   1573
#   15  K                1012723.953      0     22     40             4820   1574
#   16  G                1012686.567      0    117      0             4821   1580
#   17  G                1012684.300      0     45    154             4837   1587
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 1685
# Cut elements in the matrix : 53637
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 814MB (peak 1275MB, 119MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1               1012629.333      0      2      1             4854   1703
#        2               1012629.333      0      2      3             4973   1860
#        3               1008771.500      0      3      4             4382   2098
#        4               1008351.857      0      3      4             3354   2411
#        5               1008351.857      0      3      3             3465   2609
# Will try to keep branch and bound tree memory usage below 56.0GB
#        6               1008351.857      0      4      5             3108   2691
#        7               1008024.258      0      7      6             2831   3132
#        8               1008024.258      0      7      5             3994   3359
#        9               1008024.258      0      7      5             3469   3502
#       10               1008024.258      0      9      4             4721   5012
#       20               1008024.258      0     16      6             4028   9064
#       30               1008024.258      0     25     11             1454  14037
#       40               1008024.258      0     35     21              103  14074
#       50               1008024.258      0     45     31              101  14087
#       60               1008024.258      0     55     41               99  14098
#       70               1008024.258      0     65     51              165  14106
#       80               1008024.258      0     75     61              167  14112
# *     85  945185.8338  1008024.258      1     81     66    6.23%       0  14115
#      157  945185.8338  1008024.258      1     10      1    6.23%       1  14115
# Will try to keep branch and bound tree memory usage below 52.8GB
# Elapsed time (sec): 20725, estimated tree completion: 0.68109
# Heap usage: 5373MB (peak 5373MB, 119MB system)
# B&B tree size: 6.0MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# E    187  947988.2322  948283.2493      2      7     15    0.03%       0  20725
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=2.45113e-05).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=2.45113e-05).
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     78 out of      2932 (ratio: 0.0266)
#    Predicted att. level   : 0.3527
# Uncrunching matrix
# Final MIP objective                   : 9.479882322222213e+05
# Final MIP bound                       : 9.480114692592534e+05
#   Solution time / primaldual integral :  20727.69s/ 69.418858%
#   Number of solutions found / nodes   :         2 /       195
#   Max primal violation      (abs/rel) : 1.144e+03 / 3.989e-10
#   Max integer violation     (abs    ) : 3.989e-10
# Problem is nonlinear postsolved
# Heap usage: 305MB (peak 5373MB, 7103KB system)
# Final MILP objective (global optimum)   : 9.479882322222174e+05
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :              20732.99s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 947988.2322222174
# Original problem size
#    linear:    456902 rows, 236351 columns, 1465145 linear coefficients
#    nonlinear: 2250 coefficients, 13500 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 1200 MIN/MAX to optimizer MIP constructs
#    converted 2250 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    456902 rows, 237551 columns, 1467395 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 17:58:29, Jul 15, 2023
# Heap usage: 253MB (peak 259MB, 116MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     456902 rows       237551 cols      1467395 elements    236350 entities
#       1200 gencons
# Presolved problem has:
#     341657 rows       226000 cols      1124315 elements    224800 entities
#       2355 inds
# LP relaxation tightened
# Presolve finished in 41 seconds
# Heap usage: 375MB (peak 511MB, 116MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.65e+05] / [ 1.00e+00,  1.65e+05]
#   Objective      [min,max] : [ 3.42e-03,  1.00e+02] / [ 3.42e-03,  1.00e+02]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 1, support set: 9880 (partial detection)
#  Number of orbits: 4940, largest orbit: 2
#  Row orbits: 7490, row support: 14980
# Will try to keep branch and bound tree memory usage below 59.1GB
#  *** Solution found: -128726.3986   Time:  45.42    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  46s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  3719065.6   .0000000 |           factorize
#  D  2958742.0   .0000000 |  B  5.943E+08  2.169E+10
#  D  2745750.4   .0000000 |  B  8068521.8  8.412E+09
#  D  2582022.1   .0000000 |  B -3331705.8  1.379E+09
#  D  2469240.3   .0000000 |  B -795853.02  31078783.
#  D  2358399.3   .0000000 |  B  112267.28  18708181.
#  D  2286041.7   .0000000 |  B  1257679.0  5655855.1
#  D  2232279.4   .0000000 |  B  1654481.4  3329873.5
#  D  2199432.9   .0000000 |  B  1843095.7  2380924.4
#  D  2160202.3   .0000000 |  B  1909047.0  2124339.9
#  D  2122834.2   .0000000 |  B  1921780.2  2069279.6
#  D  2090009.6   .0000000 |  B  1934549.3  2049411.8
#  D  2067962.1   .0000000 |  B  1940486.7  2016525.9
#  D  2051575.4   .0000000 |  B  1940974.1  2006158.9
#  D  2040789.3   .0000000 |  B  1944437.4  1993799.1
#  D  2021264.2   .0000000 |  B  1947945.1  1984541.1
#  D  2013656.8   .0000000 |  B  1949800.7  1977190.1
#  D  2008615.6   .0000000 |  B  1951221.0  1969977.6
#  D  2004155.8   .0000000 |  B  1952369.5  1966106.8
#  D  1997663.9   .0000000 |  B  1953040.9  1964761.1
#
#               Concurrent-Solve,  67s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  1993718.8   .0000000 |  B  1954028.3  1961369.0
#  D  1989999.5   .0000000 |  B  1954454.8  1960416.3
#  D  1986072.4   .0000000 |  B  1954583.6  1960190.0
#  D  1983832.5   .0000000 |  B  1954803.7  1959423.1
#  D  1980681.7   .0000000 |  B  1954924.5  1959000.1
#  D  1979141.0   .0000000 |  B  1955052.6  1957159.2
#  D  1977920.4   .0000000 |  B  1955102.1  1956712.3
#  D  1977016.3   .0000000 |  B  1955180.5  1956186.9
#  D  1975128.5   .0000000 |  B  1955215.9  1955992.3
#  D  1973628.2   .0000000 |  B  1955251.5  1955822.1
#  D  1972575.0   .0000000 |  B  1955279.1  1955636.2
#  D  1971748.1   .0000000 |  B  1955305.4  1955519.5
#  D  1970823.4   .0000000 |  B  1955323.6  1955494.3
#  D  1969469.1   .0000000 |  B  1955327.6  1955458.1
#  D  1968829.3   .0000000 |  B  1955343.3  1955411.9
#  D  1968325.7   .0000000 |  B  1955353.6  1955359.2
#  D  1968118.3   .0000000 |  B  1955354.0  1955354.8
#  D  1967793.7   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 24579 simplex iterations, 39.99s
#    Barrier: 85 barrier and 1474 simplex iterations, 39.92s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      3       1955354.108      P      0     0        .000000    85
# Barrier solved problem
#   85 barrier and 1474 simplex iterations in 40.24 seconds at time 85
#
# Final objective                       : 1.955354107560536e+06
#   Max primal violation      (abs/rel) : 1.231e-11 / 1.231e-11
#   Max dual violation        (abs/rel) : 1.137e-13 / 6.259e-14
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R        -68902.85858  1262554.101      2               1.33e+06       0   1939
# R         1073816.202  1262554.101      3                 14.95%       0   1941
# R         1079653.903  1262554.101      4                 14.49%       0   1942
# R         1140609.045  1262554.101      5                  9.66%       0   1943
# R         1141260.062  1262554.101      6                  9.61%       0   1945
# R         1141849.747  1262554.101      7                  9.56%       0   1946
# R         1141896.809  1262554.101      8                  9.56%       0   1947
# R         1142111.274  1262554.101      9                  9.54%       0   1949
# R         1142323.645  1262554.101     10                  9.52%       0   1950
# R         1142533.839  1262554.101     11                  9.51%       0   1951
# R         1142741.944  1262554.101     12                  9.49%       0   1952
# R         1142947.991  1262554.101     13                  9.47%       0   1953
# R         1143152.001  1262554.101     14                  9.46%       0   1955
# R         1143353.994  1262554.101     15                  9.44%       0   1956
# R         1143553.899  1262554.101     16                  9.43%       0   1957
# R         1149894.193  1262554.101     17                  8.92%       0   1958
# R         1151059.274  1262554.101     18                  8.83%       0   1959
# R         1153444.347  1262554.101     19                  8.64%       0   1961
#    1  K   1153444.347  1262554.101     19  10000      0    8.64%    5006   1961
#    2  K   1153444.347  1245041.404     19  10000   8191    7.36%    8546   3089
#    3  K   1153444.347  1243897.099     19   5233   9997    7.27%    9397   3337
#    4  K   1153444.347  1243716.419     19    305   4957    7.26%    7103   3382
#    5  K   1153444.347  1243625.852     19    360    281    7.25%    7085   3439
#    6  K   1153444.347  1243621.008     19    282    351    7.25%    7137   3449
#    7  K   1153444.347  1243615.876     19    245    266    7.25%    7126   3455
#    8  K   1153444.347  1243609.202     19    226    237    7.25%    7147   3473
#    9  K   1153444.347  1243605.683     19    271    226    7.25%    7184   3482
# R         1171774.453  1243604.660     20                  5.78%       0   3498
# R         1175504.982  1243604.660     21                  5.48%       0   3499
# R         1175523.168  1243604.660     22                  5.47%       0   3500
# R         1175543.855  1243604.660     23                  5.47%       0   3501
# R         1176735.003  1243604.660     24                  5.38%       0   3502
#   10  K   1176735.003  1243604.660     24    213    263    5.38%    7145   3503
#   11  K   1176735.003  1243602.423     24    184    209    5.38%    7157   3514
#   12  K   1176735.003  1243601.420     24    187    176    5.38%    7152   3519
#   13  K   1176735.003  1243600.284     24    142    183    5.38%    7160   3523
#   14  K   1176735.003  1243599.126     24    148    137    5.38%    7159   4283
#   15  K   1176735.003  1243597.612     24    213    768    5.38%    7159   4287
#   16  G   1176735.003  1243597.612     24      0      6    5.38%    7156   4292
# Heuristic search 'R' started
# R         1180374.231  1243597.612     25                  5.08%       0   4298
# Heuristic search 'R' stopped
# M         1181008.404  1243597.612     26                  5.03%       0   4302
# M         1181636.327  1243597.612     27                  4.98%       0   4306
# M         1182257.916  1243597.612     28                  4.93%       0   4313
# M         1182873.804  1243597.612     29                  4.88%       0   4316
# M         1183482.987  1243597.612     30                  4.83%       0   4318
# M         1184086.070  1243597.612     31                  4.79%       0   4333
# M         1185342.545  1243597.612     32                  4.68%       0   4340
# M         1185927.079  1243597.612     33                  4.64%       0   4348
# M         1186505.726  1243597.612     34                  4.59%       0   4360
#
# Cuts in the matrix         : 1761
# Cut elements in the matrix : 61083
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 1069MB (peak 1573MB, 122MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1186505.726  1243579.605     34      2      1    4.59%    7180   4401
#        2  1186505.726  1243579.605     34      2      3    4.59%    3654   5889
# Will try to keep branch and bound tree memory usage below 55.3GB
#        3  1186505.726  1243579.605     34      3      3    4.59%    3654   5928
#        4  1186505.726  1243579.605     34      2      4    4.59%    2876   5935
#        5  1186505.726  1243579.605     34      3      5    4.59%    2424   6259
#        6  1186505.726  1243579.605     34      3      5    4.59%    2293   6336
#        7  1186505.726  1243579.605     34      4      5    4.59%    2293   6354
#        8  1186505.726  1243579.605     34      3      6    4.59%     241   6356
#        9  1186505.726  1243579.605     34      4      7    4.59%     240   6364
#       10  1186505.726  1243579.605     34      6      6    4.59%     241   6523
# E     15  1220791.902  1243579.605     35      6      9    1.83%       0   6577
#       20  1220791.902  1243579.605     35      4      7    1.83%     351   6577
# E     23  1221045.851  1221046.124     36      1      9    0.00%       0   6580
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=2.24143e-07).
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     24 out of       558 (ratio: 0.0430)
#    Predicted att. level   : 0.3588
# Uncrunching matrix
# Final MIP objective                   : 1.221045850622219e+06
# Final MIP bound                       : 1.221046124311113e+06
#   Solution time / primaldual integral :   6580.55s/ 33.717007%
#   Number of solutions found / nodes   :        36 /        25
#   Max primal violation      (abs/rel) : 1.485e+03 / 2.157e-10
#   Max integer violation     (abs    ) : 2.437e-10
# Problem is nonlinear postsolved
# Heap usage: 376MB (peak 2090MB, 8280KB system)
# Final MILP objective (global optimum)   : 1.221045850622222e+06
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :              6588.982s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 1221045.850622222
# Original problem size
#    linear:    552092 rows, 284736 columns, 1772535 linear coefficients
#    nonlinear: 2475 coefficients, 14850 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 1650 MIN/MAX to optimizer MIP constructs
#    converted 2475 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    552092 rows, 286386 columns, 1775010 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 20:52:47, Jul 15, 2023
# Heap usage: 306MB (peak 314MB, 119MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     552092 rows       286386 cols      1775010 elements    284735 entities
#       1650 gencons
# Presolved problem has:
#     414108 rows       274295 cols      1363382 elements    272645 entities
#       3202 inds
# LP relaxation tightened
# Presolve finished in 59 seconds
# Heap usage: 455MB (peak 623MB, 119MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.94e+05] / [ 1.00e+00,  1.94e+05]
#   Objective      [min,max] : [ 3.42e-03,  9.80e+01] / [ 3.42e-03,  9.80e+01]
# Autoscaling applied standard scaling
#
# Symmetric problem: generators: 3, support set: 35898 (partial detection)
#  Number of orbits: 17949, largest orbit: 2
#  Row orbits: 27189, row support: 54378
# Will try to keep branch and bound tree memory usage below 58.8GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  67s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  3936252.5   .0000000 |           factorize
#  D  3229840.2   .0000000 |  B  9.245E+08  3.043E+10
#  D  3049182.0   .0000000 |  B  1.684E+08  1.924E+10
#  D  2890833.9   .0000000 |  B -2349624.6  4.343E+09
#  D  2814295.9   .0000000 |  B -1720317.6  1.454E+08
#  D  2685479.9   .0000000 |  B -810955.53  33538477.
#  D  2608902.9   .0000000 |  B -261009.23  20062257.
#  D  2528351.8   .0000000 |  B  748579.72  9865491.4
#  D  2482565.1   .0000000 |  B  1569651.4  5102044.3
#  D  2451910.6   .0000000 |  B  1778499.9  3931451.8
#  D  2410250.4   .0000000 |  B  1971000.4  2677539.8
#  D  2375470.4   .0000000 |  B  2049718.0  2590402.0
#  D  2343757.5   .0000000 |  B  2093584.1  2429059.0
#  D  2326831.6   .0000000 |  B  2116553.6  2369788.6
#  D  2309902.8   .0000000 |  B  2128279.6  2340267.0
#  D  2287458.1   .0000000 |  B  2140074.1  2309571.5
#  D  2274619.3   .0000000 |  B  2147413.7  2278403.6
#  D  2255785.8   .0000000 |  B  2150656.9  2256591.8
#  D  2243781.5   .0000000 |  B  2156043.1  2227555.3
#  D  2234274.7   .0000000 |  B  2159610.5  2212006.7
#
#               Concurrent-Solve,  90s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  2225374.3   .0000000 |  B  2161577.9  2204572.9
#  D  2222152.7   .0000000 |  B  2163621.7  2196528.4
#  D  2218711.8   .0000000 |  B  2164888.2  2190430.6
#  D  2214312.1   .0000000 |  B  2165582.4  2186204.5
#  D  2210873.9   .0000000 |  B  2166520.3  2183883.0
#  D  2207487.3   .0000000 |  B  2167180.5  2181929.1
#  D  2200830.3   .0000000 |  B  2167392.6  2179198.4
#  D  2198575.1   .0000000 |  B  2167788.0  2177979.3
#  D  2196497.1   .0000000 |  B  2168211.4  2175807.8
#  D  2194175.5   .0000000 |  B  2168447.7  2175421.6
#  D  2192882.6   .0000000 |  B  2168620.5  2174974.6
#  D  2189986.4   .0000000 |  B  2168826.0  2173831.7
#  D  2188681.0   .0000000 |  B  2168957.5  2172711.3
#  D  2187331.2   .0000000 |  B  2168977.7  2172624.6
#  D  2185851.6   .0000000 |  B  2169070.3  2172008.2
#  D  2185180.1   .0000000 |  B  2169137.0  2171180.0
#  D  2183942.6   .0000000 |  B  2169232.0  2170683.2
#  D  2183038.2   .0000000 |  B  2169285.3  2170314.8
#  D  2182468.1   .0000000 |  B  2169339.4  2169870.2
#  D  2182087.4   .0000000 |  B  2169371.3  2169699.6
#
#               Concurrent-Solve, 113s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  2181404.2   .0000000 |  B  2169409.3  2169546.5
#  D  2180659.5   .0000000 |  B  2169414.1  2169515.0
#  D  2180194.3   .0000000 |  B  2169420.3  2169484.3
#  D  2179878.9   .0000000 |  B  2169422.9  2169458.4
#  D  2179540.5   .0000000 |  B  2169430.0  2169437.0
#  D  2179305.2   .0000000 |  B  2169434.3  2169435.9
#  D  2179027.9   .0000000 |  B  2169434.6  2169434.8
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 29555 simplex iterations, 55.53s
#    Barrier: 88 barrier and 1779 simplex iterations, 55.45s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       2169434.762      P      0     0        .000000   122
# Barrier solved problem
#   88 barrier and 1779 simplex iterations in 55.88 seconds at time 122
#
# Final objective                       : 2.169434761683312e+06
#   Max primal violation      (abs/rel) : 1.000e-11 / 1.000e-11
#   Max dual violation        (abs/rel) : 1.110e-16 / 1.110e-16
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# Heuristic s running ( 20052 LP iterations in    3.3 seconds)
# Heuristic s running ( 40509 LP iterations in   21.1 seconds)
# Heuristic R running (50002 LP iterations in  101.1 seconds)
# Heuristic R running (100002 LP iterations in  227.1 seconds)
#    1  K                1294026.740      0   3535      0             4962   3622
#    2  K                1245809.036      0  10000   1253            12073   5112
#    3  K                1240181.238      0  10000   9902            10947   6580
#    4  K                1231146.367      0   4885   9902            10560   7299
#    5  K                1230848.900      0    504   4718             7430   7346
#    6  K                1230746.447      0    228    497             7423   7377
#    7  K                1230694.412      0    298    215             7433   7400
#    8  K                1230691.248      0    156    286             7460   7414
#    9  K                1230684.004      0    189    146             7467   7431
#   10  K                1230683.556      0    123    186             7467   7443
#   11  K                1230538.329      0    183    118             7463   7485
#   12  K                1230537.636      0     89    169             7461   7491
#   13  K                1230537.525      0     65     85             7461   7496
#   14  K                1230537.488      0     62     62             7461   7503
#   15  K                1230537.419      0     60    115             7461   7508
#   16  G                1230537.419      0      0      1             7461   7514
# Heuristic s running ( 20783 LP iterations in    5.8 seconds)
# Heuristic s running ( 41035 LP iterations in   52.6 seconds)
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 2722
# Cut elements in the matrix : 96537
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 1296MB (peak 1889MB, 126MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1               1230525.128      0      2      1             7498   7683
#        2               1230514.337      0      2      3             6957   8578
# Will try to keep branch and bound tree memory usage below 55.0GB
#        3               1230514.337      0      3      4             7501   9373
#        4               1224166.137      0      4      3             7079  10482
#        5               1224166.137      0      4      5             6581  10652
# Will try to keep branch and bound tree memory usage below 52.0GB
#        6               1217418.722      0      6      4             7036  12299
#        7               1217374.061      0      6      4             8566  12468
#        8               1217374.061      0      6      6             5988  12512
#        9               1217374.061      0      7      7             5054  13275
#       10               1217374.061      0      8      4             7680  13400
#       20               1213584.072      0     16      7             1720  22883
#       30               1212788.354      0     26     15             1881  24808
#       40               1212788.354      0     36     25              162  24841
#       50               1212788.354      0     46     35              132  24858
#       60               1212788.354      0     56     45              128  24876
#       70               1212788.354      0     66     55              169  24889
#       80               1212788.354      0     76     65              140  24898
#       90               1212788.354      0     86     75                6  24904
# *     97  1071905.781  1212788.354      1     94     82   11.62%       0  24909
# Elapsed time (sec): 24916, estimated tree completion: 0.00324
# Heap usage: 6261MB (peak 6261MB, 126MB system)
# B&B tree size: 30MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      100  1071905.781  1212788.354      1     93      6   11.62%    2531  24916
# E    113  1150212.897  1212788.354      2     93     17    5.16%       0  25432
# Will try to keep branch and bound tree memory usage below 44.7GB
# E    164  1179617.308  1212788.354      3     88     32    2.74%       0  25458
# Will try to keep branch and bound tree memory usage below 34.4GB
#      200  1179617.308  1212788.354      3     74     42    2.74%     169  25466
# *    248  1179684.800  1212788.354      4     74     81    2.73%       0  25474
# *    262  1179704.017  1212788.354      5     72     75    2.73%       0  25474
#      314  1179704.017  1212788.354      5     56      1    2.73%       1  25475
#      414  1179704.017  1212788.354      5     25     50    2.73%     171  25476
#      514  1179704.017  1212788.354      5     24     30    2.73%     199  25495
#      616  1179704.017  1212788.354      5     25     35    2.73%     247  25510
#      716  1179704.017  1212788.354      5     31     32    2.73%     448  25526
#      817  1179704.017  1212788.354      5     25     33    2.73%     224  25543
#      917  1179704.017  1201808.608      5      4     46    1.84%     179  31078
# E   1003  1184059.461  1201808.608      6      4    132    1.48%       0  31137
#     1090  1184059.461  1201808.608      6     35      1    1.48%       1  31137
#     1190  1184059.461  1190742.029      6     42     28    0.56%     262  31171
# *   1236  1184071.245  1190742.029      7     52     26    0.56%       0  31182
#     1290  1184071.245  1190742.029      7     59     39    0.56%      10  31190
#     1391  1184071.245  1190742.029      7     82     20    0.56%      11  31214
#     1491  1184071.245  1190742.029      7    103     41    0.56%     239  31240
# Elapsed time (sec): 31291, estimated tree completion: 0.96290
# Heap usage: 16GB (peak 16GB, 127MB system)
# B&B tree size: 174MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     1591  1184071.245  1190742.029      7    151     30    0.56%       6  31291
#     1693  1184071.245  1190742.029      7    184     27    0.56%       9  31311
#     1793  1184071.245  1190742.029      7    216     30    0.56%     161  31332
#     1893  1184071.245  1190742.029      7    255     27    0.56%     276  31353
#     1993  1184071.245  1190742.029      7    283     41    0.56%     148  31373
#     2093  1184071.245  1190742.029      7    343     36    0.56%     538  31392
#     2194  1184071.245  1190742.029      7    348     32    0.56%       8  31415
#     2294  1184071.245  1190742.029      7    369     37    0.56%     140  31434
#     2395  1184071.245  1190742.029      7    427     31    0.56%     224  31454
#     2495  1184071.245  1190742.029      7    444     30    0.56%     136  31474
#     2595  1184071.245  1190742.029      7    455     42    0.56%     272  31492
#     2695  1184071.245  1190742.029      7    454     45    0.56%     144  31505
#     2795  1184071.245  1190742.029      7    551     28    0.56%     144  31518
#     2896  1184071.245  1190742.029      7    571     49    0.56%     142  31535
#     2996  1184071.245  1190742.029      7    570     35    0.56%     160  31550
#     3097  1184071.245  1189488.680      7    627     28    0.46%     427  31565
#     3197  1184071.245  1189488.680      7    627     99    0.46%     152  31581
#     3297  1184071.245  1189488.680      7    759     47    0.46%     281  31596
#     3398  1184071.245  1189488.680      7    824     44    0.46%       5  31608
#     3498  1184071.245  1189488.680      7    850     33    0.46%     157  31621
# Elapsed time (sec): 31634, estimated tree completion: 0.96757
# Heap usage: 17GB (peak 17GB, 127MB system)
# B&B tree size: 407MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     3598  1184071.245  1189488.680      7    850     37    0.46%     136  31634
#     3698  1184071.245  1189488.680      7    878     41    0.46%     151  31645
#     3798  1184071.245  1189488.680      7    878     62    0.46%     142  31658
#     3898  1184071.245  1189488.680      7    905     51    0.46%     421  31669
#     3998  1184071.245  1189488.680      7   1026     62    0.46%     140  31681
#     4098  1184071.245  1189488.680      7   1051     43    0.46%     385  31695
#     4198  1184071.245  1189488.680      7   1159     37    0.46%     246  31709
#     4298  1184071.245  1189488.680      7   1160     86    0.46%     146  31721
#     4398  1184071.245  1189488.680      7   1361     74    0.46%     417  31731
#     4498  1184071.245  1189488.680      7   1447     32    0.46%     220  31744
#     4599  1184071.245  1189488.680      7   1447     76    0.46%     144  31755
#     4699  1184071.245  1189488.680      7   1447     29    0.46%     146  31767
#     4799  1184071.245  1189488.680      7   1447     41    0.46%     210  31779
#     4899  1184071.245  1189488.680      7   1542     29    0.46%     153  31791
#     4999  1184071.245  1189488.680      7   1543     64    0.46%     158  31814
# R   5074  1185268.385  1189488.680      8   1575     14    0.35%       0  31836
#     6565  1185268.385  1189488.680      8    116      1    0.35%       1  31837
#     6673  1185268.385  1189488.680      8     97     71    0.35%     152  31838
#     6815  1185268.385  1189488.680      8     79      1    0.35%       1  31838
#     6931  1185268.385  1189488.680      8     70      1    0.35%       1  31838
# Elapsed time (sec): 31838, estimated tree completion: 0.97381
# Heap usage: 16GB (peak 17GB, 127MB system)
# B&B tree size: 160MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     7058  1185268.385  1189488.680      8     52      1    0.35%       1  31838
#     7173  1185268.385  1189488.680      8     32      1    0.35%       1  31838
# R   7214  1186657.160  1189488.680      9     23     15    0.24%       0  31840
# R   7225  1186699.464  1189488.680     10     14     16    0.23%       0  31850
# R   7227  1186702.606  1189488.680     11     15     16    0.23%       0  31855
#     7273  1186702.606  1189326.607     11     10     21    0.22%     244  34337
# R   7286  1189115.657  1189326.607     12     21     22    0.02%       0  34348
# R   7328  1189125.708  1189326.605     13     53     22    0.02%       0  34357
# R   7347  1189250.044  1189326.605     14     69     23    0.01%       0  34361
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=6.43733e-05).
# STOPPING - MIPRELSTOP target reached (MIPRELSTOP=0.0001  gap=6.43733e-05).
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :    170 out of     34374 (ratio: 0.0049)
#    Predicted att. level   : 0.3375
# Uncrunching matrix
# Final MIP objective                   : 1.189250043644837e+06
# Final MIP bound                       : 1.189326604568874e+06
#   Solution time / primaldual integral :  34363.71s/ 73.141079%
#   Number of solutions found / nodes   :        14 /      7347
#   Max primal violation      (abs/rel) : 1.428e+03 / 3.426e-07
#   Max integer violation     (abs    ) : 3.426e-07
# Problem is nonlinear postsolved
# Heap usage: 455MB (peak 17GB, 9593KB system)
# Final MILP objective (global optimum)   : 1.189250043644934e+06
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :              34376.28s
#   Time checks (ticks) :        2
# *** MIP gap is less than MIPABSSTOP/MIPRELSTOP ***
# Optimal objective: 1189250.0436449337
# Original problem size
#    linear:    656282 rows, 337621 columns, 2109177 linear coefficients
#    nonlinear: 2700 coefficients, 16200 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 1500 MIN/MAX to optimizer MIP constructs
#    converted 2700 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    656282 rows, 339121 columns, 2111877 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 7:56:00, Jul 16, 2023
# Heap usage: 364MB (peak 373MB, 224MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     656282 rows       339121 cols      2111877 elements    337620 entities
#       1500 gencons
# Presolved problem has:
#     491013 rows       325290 cols      1619289 elements    323790 entities
#       2955 inds
# LP relaxation tightened
# Presolve finished in 68 seconds
# Heap usage: 541MB (peak 734MB, 224MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.26e+05] / [ 1.00e+00,  2.26e+05]
#   Objective      [min,max] : [ 3.11e-03,  9.60e+01] / [ 3.11e-03,  9.60e+01]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 57.5GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  75s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  5604243.7   .0000000 |           factorize
#  D  3720248.8   .0000000 |  B  1.615E+09  3.504E+10
#  D  3426577.8   .0000000 |  B  1.382E+09  3.242E+10
#  D  3290774.3   .0000000 |  B  93017926.  1.567E+10
#  D  3226749.0   .0000000 |  B -1181.8799  1.791E+09
#  D  3174513.2   .0000000 |  B -637836.61  5.696E+08
#  D  3136517.8   .0000000 |  B -934838.73  1.176E+08
#  D  3014722.2   .0000000 |  B -725378.74  34295339.
#  D  2966846.4   .0000000 |  B -713365.59  32120719.
#  D  2900372.8   .0000000 |  B -175051.84  20705649.
#  D  2829693.7   .0000000 |  B  1017333.1  11698409.
#  D  2781614.1   .0000000 |  B  1352603.7  7715201.1
#  D  2742462.0   .0000000 |  B  1878287.5  4569180.7
#  D  2691618.3   .0000000 |  B  2140014.3  3096954.7
#  D  2642031.7   .0000000 |  B  2217669.5  2869269.4
#  D  2612116.6   .0000000 |  B  2270168.5  2711890.1
#  D  2588065.2   .0000000 |  B  2301961.0  2584477.0
#  D  2569516.9   .0000000 |  B  2322953.9  2520263.1
#  D  2553786.6   .0000000 |  B  2326531.0  2491087.7
#  D  2543683.0   .0000000 |  B  2335062.1  2452804.1
#
#               Concurrent-Solve,  94s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  2515625.8   .0000000 |  B  2340182.2  2430368.6
#  D  2491903.9   .0000000 |  B  2342910.9  2424441.7
#  D  2480582.2   .0000000 |  B  2347155.1  2413754.6
#  D  2464499.2   .0000000 |  B  2350216.9  2407564.2
#  D  2454551.3   .0000000 |  B  2351177.1  2405074.1
#  D  2442752.8   .0000000 |  B  2353067.2  2396326.8
#  D  2430436.2   .0000000 |  B  2353921.4  2392161.2
#  D  2426689.8   .0000000 |  B  2354018.7  2390316.6
#  D  2423300.9   .0000000 |  B  2355026.4  2386164.7
#  D  2417512.0   .0000000 |  B  2356881.3  2382877.0
#  D  2411728.5   .0000000 |  B  2357264.3  2381488.7
#  D  2408758.1   .0000000 |  B  2358701.5  2379014.7
#  D  2406924.8   .0000000 |  B  2359920.7  2376201.8
#  D  2403094.9   .0000000 |  B  2360435.2  2375711.4
#  D  2401542.5   .0000000 |  B  2360934.6  2373835.0
#  D  2400341.2   .0000000 |  B  2361520.4  2371499.3
#  D  2399576.7   .0000000 |  B  2362175.8  2370070.3
#  D  2398807.5   .0000000 |  B  2362254.6  2369732.9
#  D  2397752.6   .0000000 |  B  2362548.5  2368750.4
#  D  2396082.8   .0000000 |  B  2362994.7  2368007.9
#
#               Concurrent-Solve, 113s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  2395100.9   .0000000 |  B  2363098.4  2367855.8
#  D  2394025.4   .0000000 |  B  2363320.2  2366926.1
#  D  2393277.6   .0000000 |  B  2363445.4  2366188.4
#  D  2392841.2   .0000000 |  B  2363490.5  2365921.4
#  D  2391747.5   .0000000 |  B  2363582.5  2365408.4
#  D  2390858.6   .0000000 |  B  2363688.3  2364818.1
#  D  2390491.4   .0000000 |  B  2363765.8  2364684.8
#  D  2390074.4   .0000000 |  B  2363897.5  2364340.5
#  D  2389621.7   .0000000 |  B  2363919.8  2364229.2
#  D  2389057.0   .0000000 |  B  2363925.2  2364122.9
#  D  2388127.4   .0000000 |  B  2363945.1  2364033.4
#  D  2387572.8   .0000000 |  B  2363957.2  2364011.4
#  D  2386998.2   .0000000 |  B  2363959.1  2363992.5
#  D  2386306.0   .0000000 |  B  2363963.0  2363979.5
#  D  2385677.5   .0000000 |  B  2363963.9  2363968.9
#  D  2385262.1   .0000000 |  B  2363964.5  2363965.4
#  D  2384434.3   .0000000 |  B  2363964.7  2363964.8
#  D  2383945.3   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 32273 simplex iterations, 56.57s
#    Barrier: 93 barrier and 2064 simplex iterations, 56.48s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       2363964.701      P      0     0        .000000   131
# Barrier solved problem
#   93 barrier and 2064 simplex iterations in 56.96 seconds at time 131
#
# Final objective                       : 2.363964701025586e+06
#   Max primal violation      (abs/rel) : 9.095e-13 / 9.095e-13
#   Max dual violation        (abs/rel) : 6.661e-16 / 6.661e-16
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# Heuristic s running ( 20657 LP iterations in    3.9 seconds)
# Heuristic s running ( 40746 LP iterations in   16.4 seconds)
# Heuristic t running ( 20818 LP iterations in    4.9 seconds)
#    1  K                1194970.181      0  10000      0             6282   4167
#    2  K                1187699.183      0  10000   7629            10330   6227
#    3  K                1187461.771      0  10000   9947            10543   6575
#    4  K                1187326.065      0    862   9932             9022   6685
#    5  K                1187322.596      0    655    773             8994   6704
#    6  K                1187322.554      0    587    631             9017   6710
#    7  K                1187322.554      0    581    574             9028   6716
#    8  K                1187295.635      0    593    567             9040   6738
#    9  K                1187295.496      0    529    572             9051   7302
#   10  K                1187295.496      0    531    904             9053   7318
#   11  K                1187295.496      0    460    528             9054   7325
#   12  K                1187295.496      0    419    458             9054   7331
#   13  K                1187295.496      0    415    417             9054   7337
#   14  K                1187295.496      0    407    413             9054   7344
#   15  K                1187295.496      0    397    800             9054   7350
#   16  G                1187284.362      0      1      0             9054   7406
#   17  G                1187279.762      0     61     62             9089   7432
# Heuristic s running ( 20056 LP iterations in    7.0 seconds)
# Heuristic s running ( 40133 LP iterations in  314.8 seconds)
# Heuristic t running ( 20091 LP iterations in    4.9 seconds)
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 2291
# Cut elements in the matrix : 108117
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 1454MB (peak 2235MB, 233MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1               1187270.462      0      2      1             9112   9096
#        2               1187269.348      0      2      3             7647  13428
#        3               1179848.738      0      2      3            10278  14721
# Will try to keep branch and bound tree memory usage below 53.0GB
#        4               1179764.221      0      3      4             9156  17685
#        5               1174597.666      0      4      4             5137  22319
# Will try to keep branch and bound tree memory usage below 49.8GB
#        6               1174597.666      0      5      5             8670  22693
#        7               1174597.666      0      6      5             6470  23915
#        8               1174597.666      0      6      5             5603  24124
#        9               1174597.666      0      6      1                1  24124
#       10               1174597.666      0      6      6             5603  24217
#       20               1174372.286      0     15      9             2070  39655
# *     27  990944.6939  1164742.139      1     22     14   14.92%       0  44080
#       35  990944.6939  1164742.139      1     15      1   14.92%       1  44080
#       45  990944.6939  1164742.139      1     18     14   14.92%       8  45542
# g     48  1036079.994  1164742.139      2     22     17   11.05%       0  45545
#       59  1036079.994  1164742.139      2     12      1   11.05%       1  45545
# Will try to keep branch and bound tree memory usage below 46.4GB
# E     67  1117902.338  1164742.139      3     12      9    4.02%       0  48637
#       69  1117902.338  1164742.139      3     12      9    4.02%    2332  48637
#       79  1117902.338  1164742.139      3      5     12    4.02%    2045  48647
# Elapsed time (sec): 48681, estimated tree completion: 0.64274
# Heap usage: 9409MB (peak 9409MB, 233MB system)
# B&B tree size: 12MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# ...
#   Total time :              39950.26s
#   Time checks (ticks) :        2
# *** Search completed ***
# Optimal objective: 966415.8165333285
# Original problem size
#    linear:    874982 rows, 450121 columns, 2812073 linear coefficients
#    nonlinear: 3600 coefficients, 21600 tokens
# Nonlinear presolve
#    checking equivalence to general constraints ABS/MIN/MAX and PWL reformulations
#    converted 1740 MIN/MAX to optimizer MIP constructs
#    converted 3600 formulas to linear constraints
#    problem is equivalent, reformulated as a MIP problem
# Presolved problem size
#    linear:    874982 rows, 451861 columns, 2815673 linear coefficients
# Problem is nonlinear presolved
# Maximizing problem using Xpress-Optimizer
# FICO Xpress v9.0.0, Hyper, solve started 7:20:43, Jul 22, 2023
# Heap usage: 485MB (peak 497MB, 231MB system)
# Maximizing MILP Stochastic Assortment Optimization using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# IFCHECKCONVEXITY = 0
# Original problem has:
#     874982 rows       451861 cols      2815673 elements    450120 entities
#       1740 gencons
# Presolved problem has:
#     653206 rows       432600 cols      2155450 elements    430860 entities
#       3432 inds
# LP relaxation tightened
# Presolve finished in 90 seconds
# Heap usage: 719MB (peak 980MB, 232MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+24] / [ 1.08e-19,  1.08e+05]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.20e+05] / [ 1.00e+00,  2.20e+05]
#   Objective      [min,max] : [ 2.57e-03,  1.00e+02] / [ 2.57e-03,  1.00e+02]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 56.8GB
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve, 101s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  5635458.4   .0000000 |           factorize
#  D  3685804.7   .0000000 |           factorize
#  D  3341565.7   .0000000 |  B  1.038E+09  4.098E+10
#  D  3274000.5   .0000000 |  B  2.303E+08  3.144E+10
#  D  3222603.0   .0000000 |  B  92809352.  2.424E+10
#  D  3164750.0   .0000000 |  B  26214912.  1.181E+10
#  D  3106284.2   .0000000 |  B -5328022.1  3.043E+09
#  D  3063429.5   .0000000 |  B -2485106.9  3.629E+08
#  D  3006718.8   .0000000 |  B -1396659.4  1.085E+08
#  D  2946582.9   .0000000 |  B -977089.33  55777980.
#  D  2874646.8   .0000000 |  B -605825.82  30520691.
#  D  2831497.8   .0000000 |  B -126472.92  23804050.
#  D  2789708.5   .0000000 |  B  188797.87  21128205.
#  D  2763947.0   .0000000 |  B  685371.45  18721857.
#  D  2747756.0   .0000000 |  B  1647267.6  6792240.8
#  D  2723514.0   .0000000 |  B  1887000.9  4773653.2
#  D  2704803.3   .0000000 |  B  2007616.1  3543447.4
#  D  2689540.3   .0000000 |  B  2083293.5  2920324.3
#  D  2666199.8   .0000000 |  B  2177923.3  2442715.9
#  D  2645993.3   .0000000 |  B  2197005.6  2379783.7
#
#               Concurrent-Solve, 121s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  2625356.3   .0000000 |  B  2206953.7  2348505.0
#  D  2599764.7   .0000000 |  B  2216129.7  2330704.4
#  D  2585216.0   .0000000 |  B  2223866.4  2311784.9
#  D  2557047.7   .0000000 |  B  2224736.7  2304560.0
#  D  2535696.5   .0000000 |  B  2228079.6  2299733.1
#  D  2525343.0   .0000000 |  B  2228450.0  2296795.8
#  D  2513829.7   .0000000 |  B  2232729.5  2288603.0
#  D  2488726.4   .0000000 |  B  2234175.9  2284732.3
#  D  2474865.3   .0000000 |  B  2236221.9  2280408.3
#  D  2466354.1   .0000000 |  B  2237684.3  2277225.1
#  D  2453354.8   .0000000 |  B  2240227.2  2272231.8
#  D  2434240.7   .0000000 |  B  2241699.7  2270882.3
#  D  2416143.4   .0000000 |  B  2242296.2  2270484.0
#  D  2402839.2   .0000000 |  B  2243398.8  2268527.3
#  D  2389481.8   .0000000 |  B  2244243.5  2266012.6
#  D  2378881.0   .0000000 |  B  2244522.9  2264486.1
#  D  2370823.6   .0000000 |  B  2245100.1  2262130.8
#  D  2362759.8   .0000000 |  B  2245392.5  2261318.2
#  D  2352322.4   .0000000 |  B  2246208.2  2259349.2
#  D  2349102.4   .0000000 |  B  2246407.0  2258732.8
#
#               Concurrent-Solve, 141s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  2345667.3   .0000000 |  B  2246717.7  2257736.6
#  D  2342758.9   .0000000 |  B  2246832.3  2257264.3
#  D  2338164.5   .0000000 |  B  2247320.5  2255572.5
#  D  2335869.6   .0000000 |  B  2247425.5  2255320.2
#  D  2334714.6   .0000000 |  B  2247518.4  2255200.9
#  D  2332601.4   .0000000 |  B  2247646.0  2254837.6
#  D  2329176.5   .0000000 |  B  2247928.4  2253478.6
#  D  2327116.1   .0000000 |  B  2247997.0  2253281.1
#  D  2325316.0   .0000000 |  B  2248104.8  2252342.0
#  D  2323172.3   .0000000 |  B  2248202.4  2251943.2
#  D  2322132.4   .0000000 |  B  2248259.4  2251333.0
#  D  2319216.5   .0000000 |  B  2248315.2  2251109.7
#  D  2317609.0   .0000000 |  B  2248375.4  2250773.6
#  D  2314354.0   .0000000 |  B  2248394.8  2250654.5
#  D  2313410.3   .0000000 |  B  2248457.0  2250257.9
#  D  2312326.3   .0000000 |  B  2248479.0  2249948.5
#  D  2311542.8   .0000000 |  B  2248518.1  2249539.9
#  D  2310635.5   .0000000 |  B  2248526.7  2249452.4
#  D  2309688.2   .0000000 |  B  2248558.5  2249074.0
#  D  2308711.6   .0000000 |  B  2248586.8  2249019.5
#
#               Concurrent-Solve, 161s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  2308204.7   .0000000 |  B  2248598.7  2248967.1
#  D  2307675.8   .0000000 |  B  2248611.2  2248944.4
#  D  2307098.4   .0000000 |  B  2248625.8  2248838.2
#  D  2279462.7   .0000000 |  B  2248628.3  2248785.6
#  D  2279124.9   .0000000 |  B  2248643.8  2248764.2
#  D  2278917.9   .0000000 |  B  2248651.9  2248740.9
#  D  2278656.4   .0000000 |  B  2248656.9  2248698.1
#  D  2278074.7   .0000000 |  B  2248658.9  2248694.0
#  D  2277734.8   .0000000 |  B  2248662.3  2248677.4
#  D  2277576.9   .0000000 |  B  2248666.1  2248672.7
#  D  2277137.4   .0000000 |  B  2248667.3  2248667.3
#  D  2276754.8   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 42164 simplex iterations, 74.84s
#    Barrier: 86 barrier and 2609 simplex iterations, 74.73s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      8       2248667.265      P      0     0        .000000   175
# Barrier solved problem
#   86 barrier and 2609 simplex iterations in 75.39 seconds at time 175
#
# Final objective                       : 2.248667265071337e+06
#   Max primal violation      (abs/rel) : 2.977e-12 / 2.977e-12
#   Max dual violation        (abs/rel) : 1.137e-13 / 9.783e-14
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
# High attention level predicted from matrix features
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# Heuristic s running ( 20984 LP iterations in    3.5 seconds)
# Heuristic s running ( 41171 LP iterations in   24.0 seconds)
# Heuristic s running ( 61181 LP iterations in   73.4 seconds)
#    1  K                1273898.972      0  10000      0             8157  18592
#    2  K                1264533.708      0  10000   7678            22680  20928
#    3  K                1264319.821      0    764   9412            14267  21124
#    4  K                1264125.487      0    650    662            14333  21307
#    5  K                1264057.716      0   1002    597            14198  21383
#    6  K                1263974.685      0    826    965            14291  21476
#    7  K                1263970.694      0    912    812            14250  21510
#    8  K                1263970.298      0    689    871            14273  21526
#    9  K                1263969.733      0    764    670            14274  21537
#   10  K                1263969.258      0    517    749            14278  23289
#   11  K                1263969.064      0    446    513            14271  23300
#   12  K                1263969.039      0    526    442            14271  23310
#   13  K                1263968.459      0    352    520            14275  23323
#   14  K                1263968.407      0    428    350            14279  23334
#   15  K                1263968.090      0    269    684            14275  23344
#   16  G                1263968.087      0     23      5            14277  23350
#   17  G                1263968.083      0      6     23            14277  23357
#   18  G                1263968.081      0      5     11            14277  23365
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 3215
# Cut elements in the matrix : 145212
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 1946MB (peak 2985MB, 243MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1               1263962.968      0      2      1            14353  23463
#        2               1259714.314      0      2      3            15514  29664
#        3               1259714.314      0      2      3            13835  30509
# Will try to keep branch and bound tree memory usage below 50.9GB
#        4               1259714.314      0      3      4            15127  32330
#        5               1259631.174      0      4      4            16566  33751
#        6               1259631.174      0      4      4            13046  35539
# Will try to keep branch and bound tree memory usage below 46.7GB
#        7               1253256.446      0      5      4            12731  38480
#        8               1249330.678      0      6      5            10924  42955
#        9               1249330.678      0      7      5            15036  45728
#       10               1249330.678      0      8      6            15027  45764
#       20               1246606.472      0     16      8            16180  92178
#       30               1241573.564      0     26     10            12282 128808
#       40               1241467.482      0     33     13             5228 148529
#       50               1241467.482      0     33     23               16 148965
# *     53  847580.1875  1241467.482      1     33     26   31.73%       0 148973
#       60  847580.1875  1241467.482      1     33     32   31.73%     424 148985
#       70  847580.1875  1241467.482      1     33     42   31.73%     223 149004
#       80  847580.1875  1241467.482      1     33     52   31.73%     217 149016
#       90  847580.1875  1241467.482      1     33     62   31.73%     221 149028
# Elapsed time (sec): 149038, estimated tree completion: 0.00070
# Heap usage: 8295MB (peak 8295MB, 243MB system)
# B&B tree size: 52MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      100  847580.1875  1241467.482      1     33     72   31.73%     217 149038
#      200  847580.1875  1241467.482      1     33    172   31.73%     248 149132
#      301  847580.1875  1241467.482      1     33    273   31.73%     249 149213
# *    313  1169703.297  1241467.482      2     33    285    5.78%       0 149222
#      583  1169703.297  1241467.482      2     37      1    5.78%       1 149222
# Heuristic R running (50000 LP iterations in   91.0 seconds)
# Heuristic R running (100000 LP iterations in 1815.3 seconds)
# Heuristic R running (150000 LP iterations in 2177.0 seconds)
# Heuristic R running (200000 LP iterations in 2558.0 seconds)
# Heuristic R running (250000 LP iterations in 2962.6 seconds)
# Heuristic R running (300000 LP iterations in 3178.5 seconds)
# Heuristic R running (350000 LP iterations in 3469.6 seconds)
# Heuristic R running (400000 LP iterations in 3797.5 seconds)
# Heuristic R running (450000 LP iterations in 4157.6 seconds)
# Heuristic R running (500000 LP iterations in 4583.7 seconds)
# Heuristic R running (550000 LP iterations in 5057.7 seconds)
# Heuristic R running (600000 LP iterations in 5559.5 seconds)
# Heuristic R running (650000 LP iterations in 5907.0 seconds)
# Heuristic R running (700000 LP iterations in 6214.0 seconds)
# Heuristic R running (750000 LP iterations in 6528.7 seconds)
# Heuristic R running (800000 LP iterations in 6920.7 seconds)
# Heuristic R running (850000 LP iterations in 7282.3 seconds)
# Will try to keep branch and bound tree memory usage below 40.0GB
# Will try to keep branch and bound tree memory usage below 21.4GB
#      683  1169703.297  1241467.482      2     54     69    5.78%     198 180200
#      783  1169703.297  1241467.482      2     90     92    5.78%     204 180517
#      883  1169703.297  1241467.482      2    232     66    5.78%     262 180700
#      983  1169703.297  1241467.482      2    313     37    5.78%     249 180888
# *   1029  1170741.630  1241467.482      3    342     39    5.70%       0 180981
#     1083  1170741.630  1241467.482      3    327     37    5.70%     328 181017
# *   1083  1170798.988  1241467.482      4    327     37    5.69%       0 181017
# *   1087  1170823.371  1241467.482      5    327     39    5.69%       0 181021
#     1183  1170823.371  1241467.482      5    273     32    5.69%     246 181061
#     1283  1170823.371  1241467.482      5    273    130    5.69%     438 181170
#     1383  1170823.371  1241467.482      5    410    101    5.69%     205 181288
# R   1409  1170933.767  1241467.482      6    495     22    5.68%       0 181324
# Heuristic R running (50000 LP iterations in  257.2 seconds)
#     1870  1170933.767  1241467.482      6     34      1    5.68%       1 181946
# Heuristic R running (100000 LP iterations in  832.9 seconds)
# Heuristic R running (150000 LP iterations in 1240.4 seconds)
# *   1941  1173920.052  1241467.482      7     25     54    5.44%       0 185631
#     1974  1173920.052  1241467.482      7     32      1    5.44%       1 185631
# Elapsed time (sec): 194050, estimated tree completion: 0.47685
# Heap usage: 25GB (peak 25GB, 244MB system)
# B&B tree size: 48MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# E   2065  1174306.172  1241467.482      8     21     33    5.41%       0 194050
#     2078  1174306.172  1241467.482      8     21      1    5.41%       1 194050
# *   2130  1174666.581  1241467.482      9     19     64    5.38%       0 194753
#     2178  1174666.581  1241467.482      9     17     12    5.38%   17626 195920
#     2278  1174666.581  1233425.614      9      9     20    4.76%     492 222075
# E   2352  1176235.220  1233425.614     10      9     92    4.64%       0 222203
#     2422  1176235.220  1233425.614     10     24      1    4.64%       1 222203
# *   2479  1179315.447  1233425.614     11      9     42    4.39%       0 222899
#     2522  1179315.447  1233425.614     11      7     10    4.39%    8455 224000
# E   2537  1190533.322  1232519.279     12      5     23    3.41%       0 224619
# *   2554  1190538.698  1226168.280     13      4     22    2.91%       0 224636
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :    434 out of     18003 (ratio: 0.0241)
#    Singular bases   :      2 out of    166777 (ratio: 0.0000)
#    Predicted att. level   : 0.3185
# Uncrunching matrix
# Final MIP objective                   : 1.190538697899944e+06
# Final MIP bound                       : 1.190540946567209e+06
#   Solution time / primaldual integral : 252235.50s/ 60.999998%
#   Number of solutions found / nodes   :        13 /      2573
#   Max primal violation      (abs/rel) : 1.600e+03 / 2.619e-08
#   Max integer violation     (abs    ) : 3.586e-08
# Problem is nonlinear postsolved
# Heap usage: 720MB (peak 25GB, 14MB system)
# Final MILP objective (global optimum)   : 1.190538697899855e+06
#   Max validation error      (abs/rel) :      .000 /     1.000
#   Observed primal integral :  100.000%
#   Total time :              252248.4s
#   Time checks (ticks) :        2
# *** Search completed ***
# Optimal objective: 1190538.6978998552

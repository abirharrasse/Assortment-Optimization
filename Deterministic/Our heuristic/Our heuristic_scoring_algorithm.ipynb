# %% [markdown]
# # Our heuristic: generation, comparison and scoring functions

# %%
import random
import numpy as np
import xpress as xp
from collections import defaultdict

def elements_gen(N_items):
    volumes = defaultdict(dict)
    demand = defaultdict(dict)
    costs = defaultdict(dict)
    alphas = defaultdict(dict)
    price = defaultdict(dict)

    for i in range(1, N_items + 1):
        volumes[i] = float("{:.2f}".format(random.uniform(0.1, 10)))  # Random volume for item i
        demand[i] = int(random.randint(1, 16))  # Random demand for item i
        costs[i] = int(random.uniform(1.0, 101.0))  # Random cost for item i
        price[i] = 1.5 * costs[i]

        for j in range(1, N_items + 1):
            if i == j:
                alphas[(j, i)] = 0.0
            else:
                alphas[(j, i)] = float("{:.2f}".format(random.uniform(0, 0.9)))  # Random alpha for item j -> item i

    return volumes, demand, costs, alphas, price



def optimization_model(set_items):

    volumes = set_items[0]
    demand = set_items[1]
    costs = set_items[2]
    alpha_m = set_items[3]
    price = set_items[4]

    keys_list = list(volumes.keys())
    
    # Create the problem
    prob = xp.problem()
    # Decision variables

    max_row = max(list(demand.keys()))
    print(max_row)
    key_ind = list(range(max_row+1))


    x = np.array([xp.var(vartype=xp.binary, name=f'x_{i}') for i in key_ind])
    u = np.array([xp.var(vartype=xp.integer, lb=0, name=f'u_{i}') for i in key_ind])
    z = np.array([[xp.var(vartype=xp.binary, name=f'z_{i}_{j}') for j in key_ind] for i in key_ind])

    prob.addVariable(x, u, z)

   
    d = np.zeros(max_row+1)
    test = np.zeros(max_row+1)
    w = np.zeros(max_row+1)
    c = np.zeros(max_row+1)
    alpha = np.zeros((max_row+1, max_row+1))

    for i, value in demand.items():
        d[i] = value
        test[i] = 1
    for i, value in volumes.items():
        w[i] = value
    for i, value in costs.items():
        c[i] = value

    for (i, j), value in alpha_m.items():
        alpha[i, j] = value
    p = 1.5 * c

    C = 100* np.dot(w, d)  
    M = 1000000000
    K_T = 100
    delta = 0.7
    
    key_index = [x for x in key_ind if test[x] != 0]
    print(key_index)
        # Objective function
    prob.setObjective(xp.Sum(K_T * p[i] * d[i] * x[i] for i in key_index) +xp.Sum(K_T * p[i] * xp.Sum(
    delta*alpha[j, i] * d[j] * (x[i] - z[i, j]) for j in key_index if j != i)for i in key_index)
    - xp.Sum(c[i] * u[i] for i in key_index),sense=xp.maximize)
    print('passed')

    # Constraints
    prob.addConstraint(xp.Sum(w[i] * u[i] for i in key_index) <= C)
    for i in key_index:
        prob.addConstraint(u[i] <= M * x[i])
        prob.addConstraint(
            u[i]>= K_T * d[i] * x[i]+ K_T*xp.Sum(delta*alpha[j, i] * d[j] * (x[i] - z[i, j]) for j in key_index if j != i) )
        for j in key_index:
            if j != i:
                prob.addConstraint(z[i, j] <= x[i])
                prob.addConstraint(z[i, j] <= x[j])
                prob.addConstraint(z[i, j] >= x[i] + x[j] - 1)
                prob.addConstraint(z[j, i] == z[i, j]) 
    prob.addConstraint(xp.Sum(u[i] for i in key_index) == K_T * xp.Sum(d[i] for i in key_index))

    # Solve the problem
    prob.solve()

    optimal_x = {i: prob.getSolution(x[i]) for i in key_index}
    optimal_u = {i: prob.getSolution(u[i]) for i in key_index}
    non_zero_optimal_x = {i: value for i, value in optimal_x.items() if value != 0}
    non_zero_optimal_u = {i: value for i, value in optimal_u.items() if value != 0}

    optimal_objective_value = prob.getObjVal()
    return(optimal_objective_value, optimal_x, optimal_u)



def divide_set_1000(initial_set):


    divided_sets= []
    divided = []
    for i in range(len(initial_set)):
        if i != 3:
            divided_dicts = []
            my_dict = initial_set[i]
            items = list(my_dict.items())
        
            # Calculate the number of elements in each smaller dictionary
            elements_per_dict = len(my_dict) // 10

            # Iterate through the range of 0 to 10 (exclusive) with a step of 100
            for i in range(0, len(my_dict), elements_per_dict):
                # Extract a slice of elements from the main list and convert it back to a dictionary
                divided_dict = dict(items[i: i + elements_per_dict])
                divided_dicts.append(divided_dict)
            divided.append(divided_dicts)
        else:
            my_dict = initial_set[3]
            divided_alphas = []
            for ele in divided[0]:
                indices_ephem = list(ele.keys())
                dict_alpha = {}
                for j in indices_ephem:
                    for k in indices_ephem:
                        dict_alpha[(j,k)] = my_dict[(j,k)]
                divided_alphas.append(dict_alpha)
            divided.append(divided_alphas)

    
    for i in range(len(divided[0])):
        helper = []
        for ele in divided:
            helper.append(ele[i])
        divided_sets.append(helper)
    return(divided_sets)



def divide_sets_100(seti_items):
    # Initialize two dictionaries to hold the elements
    first_set_50 = []
    second_set_50 = []

    # Iterate through the dictionary items and split them into dictionaries

    for i in range(len(seti_items)):
        if i != 3:
            count = 0
            first_dict = {}
            second_dict = {}
            for key, value in seti_items[i].items():
                if count < 50:
                    first_dict[key] = value
                else:
                    second_dict[key] = value
                count += 1
            first_set_50.append(first_dict)
            second_set_50.append(second_dict)
        else: 
            keys_alp_1 = list(first_set_50[0].keys())
            keys_alp_2 = list(second_set_50[0].keys())
            first_alp = {}
            second_alp = {}
            for j in keys_alp_1:
                for k in keys_alp_1:
                    first_alp[(j,k)] = seti_items[3][(j,k)]
            for j in keys_alp_2:
                for k in keys_alp_2:
                    second_alp[(j,k)] = seti_items[3][(j,k)]  
            first_set_50.append(first_alp)
            second_set_50.append(second_alp)                             

    return(first_set_50, second_set_50)



def calculate_score(seti_items):
    u = optimization_model(seti_items)[2]
    max_u = max(list(u.values()))
    calculated_scores = {i: u[i] / max_u for i in list(u.keys())}
    # Sort the dictionary items by values in descending order
    sorted_scores = sorted(calculated_scores.items(), key=lambda x: x[1], reverse=True)
    return {k: v for k, v in sorted_scores}



def divide_set_by_scores(ranked_set_items, N_by_set):
    # Initialize two dictionaries to hold the elements
    first_set_N = []
    second_set_N = []

    # Iterate through the dictionary items and split them into dictionaries

    for i in range(len(ranked_set_items)):
        if i != 3:
            count = 0
            first_dict = {}
            second_dict = {}
            for key, value in ranked_set_items[i].items():
                if count < N_by_set:
                    first_dict[key] = value
                else:
                    second_dict[key] = value
                count += 1
            first_set_N.append(first_dict)
            second_set_N.append(second_dict)
        else:
            keys_N_alp_1 = list(first_set_N[0].keys())
            keys_N_alp_2 = list(second_set_N[0].keys())
            first_N_alp = {}
            second_N_alp = {}
            for j in keys_N_alp_1:
                for k in keys_N_alp_1:
                    first_N_alp[(j,k)] = ranked_set_items[3][(j,k)]
            for j in keys_N_alp_2:
                for k in keys_N_alp_2:
                    second_N_alp[(j,k)] = ranked_set_items[3][(j,k)]  
            first_set_N.append(first_N_alp)
            second_set_N.append(second_N_alp)           
    return(first_set_N, second_set_N)

# %% [markdown]
# # Data generation

# %%
N_elements = 3000
volumes, demand, costs, alpha, price = elements_gen(N_elements)
random_index = random.sample(range(1, N_elements + 1), 1000)
volumes_selec = {}
demand_selec = {}
costs_selec = {}
alpha_selec = {}
price_selec = {}
index = []
for i in random_index:
    volumes_selec[i] = volumes[i]
    demand_selec[i] = demand[i]
    costs_selec[i] = costs[i]
    for j in random_index:
        index.append((i,j))
        alpha_selec[(i,j)] = alpha[(i,j)]
    price_selec[i] = price[i]
set_items = [volumes_selec, demand_selec, costs_selec, alpha_selec, price_selec]

# %% [markdown]
# # Saving data

# %%
import pandas as pd

# Define an empty DataFrame with column names
df_initial = pd.DataFrame(columns=['Product', 'Volumes', 'Demand', 'Costs', 'Alphas', 'Price'])
ind = list(range(1, 3001))
product_index = ind.copy()

df_initial['Product'] = product_index
df_initial['Volumes'] = volumes.values()
df_initial['Demand'] = demand.values()
df_initial['Costs'] = costs.values()
df_initial['Price'] = price.values()

alpha_li = []
for i in range(1, len(volumes)+1):
    alpha_i = []
    for j in range(1, len(volumes)+1):
        alpha_i.append(alpha[(i,j)])
    alpha_li.append(alpha_i)
df_initial['Alphas'] = alpha_li
df_initial.to_csv('data_scoring_initial.csv', index=False)

# %%
# Define an empty DataFrame with column names
df_scoring = pd.DataFrame(columns=['Product_scoring', 'Volumes_scoring', 'Demand_scoring', 'Costs_scoring', 'Alphas_scoring', 'Price_scoring'])
ind = list(range(1, 1001))

df_scoring['Product_scoring'] = random_index
df_scoring['Volumes_scoring'] = volumes_selec
df_scoring['Demand_scoring'] = demand_selec
df_scoring['Costs_scoring'] = costs_selec
df_scoring['Price_scoring'] = price_selec

alpha_li = []
for i in range(1, len(volumes_selec)+1):
    alpha_i = []
    for j in range(1, len(volumes_selec)+1):
        alpha_i.append(alpha[(i,j)])
    alpha_li.append(alpha_i)
df_scoring['Alphas'] = alpha_li
df_scoring.to_csv('data_scoring_1000.csv', index=False)

# %% [markdown]
# # The scoring algorithm: dividing into subsets

# %%
Set_100 = divide_set_1000(set_items)

# %%
scores_f = []
Set_100 = divide_set_1000(set_items)
Sets_50 = []
Sets_50_sorted = []

for st in Set_100:
    a = divide_sets_100(st)
    Sets_50.append(a)

for ele in Sets_50:
    medi = []
    scr = []
    for st_50 in ele:
        a = calculate_score(st_50)
        scr.append(a)
        d = {}
        w = {}
        p = {}
        c = {}
        alphas = {}
        my_set_hp = []
        for ind in a.keys():
            d[ind] = set_items[1][ind]
            w[ind] = set_items[0][ind]
            c[ind] = set_items[2][ind]
            for j in a.keys():
                alphas[(ind,j)] = set_items[3][(ind,j)]
            p[ind] = set_items[4][ind]
        my_set_hp.append(w)
        my_set_hp.append(d)
        my_set_hp.append(c)
        my_set_hp.append(alphas)
        my_set_hp.append(p)
        medi.append(divide_set_by_scores(my_set_hp, 25))
    scores_f.append(scr)
    Sets_50_sorted.append(medi)
# Out:
# Using the license file found in your Xpress installation. If you want to use this license and no longer want to see this message, use the following code before using the xpress module:
#   xpress.init('C:/xpressmp/bin/xpauth.xpr')
# 2992
# [5, 35, 53, 238, 341, 347, 451, 473, 485, 586, 734, 756, 766, 782, 868, 898, 919, 1030, 1058, 1150, 1278, 1300, 1642, 1652, 1725, 1807, 1813, 1896, 1911, 1961, 2004, 2125, 2249, 2290, 2372, 2458, 2472, 2496, 2513, 2552, 2621, 2629, 2644, 2675, 2700, 2736, 2788, 2791, 2827, 2992]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:38:23, Jul 28, 2023
# Heap usage: 2212MB (peak 2212MB, 99MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8964035 cols        24790 elements   8964035 entities
# Presolved problem has:
#       3777 rows         1325 cols        11315 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3361MB (peak 5809MB, 99MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 2.20e-01,  1.00e+09] / [ 3.05e-05,  1.98e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.33e+05] / [ 1.00e+00,  4.38e+04]
#   Objective      [min,max] : [ 8.00e+00,  2.40e+06] / [ 8.00e+00,  2.40e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.6GB
#  *** Solution found: -606584.7000   Time:  12.55    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  2175994.5   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1376 simplex iterations, 0.12s
#    Barrier: 14 barrier and 1669 simplex iterations, 0.54s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1376       2175994.490      P      0     0        .000000    13
# Dual solved problem
#   1376 simplex iterations in 0.85 seconds at time 13
#
# Final objective                       : 2.175994490042254e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 3.160e-11 / 3.160e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1204158.100  2175994.490      2                 44.66%       0     13
# k         1217152.100  2172861.433      3                 43.98%       0     14
# R         1663387.600  2172861.433      4                 23.45%       0     15
#    1  K   1663387.600  2172861.433      4      2      0   23.45%      11     15
#    2  K   1663387.600  2171596.073      4      3      0   23.40%      17     15
#    3  K   1663387.600  2170188.377      4      6      2   23.35%      19     15
#    4  K   1663387.600  2168570.132      4      3      7   23.30%      19     15
#    5  K   1663387.600  2167983.904      4      8      3   23.27%      22     16
#    6  K   1663387.600  2167977.222      4      5      6   23.27%      21     16
#    7  K   1663387.600  2167976.633      4      1      3   23.27%      26     16
#    8  K   1663387.600  2167976.362      4      1      0   23.27%      27     16
#    9  K   1663387.600  2167975.469      4      3      0   23.27%      28     16
# R         1757487.750  2167975.402      5                 18.93%       0     16
# R         1847850.650  2167975.402      6                 14.77%       0     16
#   10  K   1847850.650  2167975.402      6      2      1   14.77%      28     16
#   11  K   1847850.650  2167975.402      6      0      1   14.77%      28     16
# Heuristic search 'R' started
# R         1987092.600  2167975.402      7                  8.34%       0     17
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 11
# Cut elements in the matrix : 4178
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3439MB (peak 5809MB, 167MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1987092.600  2167914.620      7      2      1    8.34%      28     17
#        2  1987092.600  2167913.281      7      2      3    8.34%      28     18
#        3  1987092.600  2167828.383      7      3      4    8.34%      19     18
#        4  1987092.600  2167828.383      7      3      3    8.34%      17     18
#        5  1987092.600  2167828.383      7      4      4    8.34%      14     19
#        6  1987092.600  2167828.383      7      5      4    8.34%       8     19
#        7  1987092.600  2167828.383      7      6      5    8.34%      20     19
#        8  1987092.600  2167828.383      7      7      6    8.34%      19     19
#       10  1987092.600  2167828.383      7      8      5    8.34%       8     19
#       21  1987092.600  2167827.598      7     11      6    8.34%      13     19
#       31  1987092.600  2167827.598      7     17     14    8.34%       8     20
# Will try to keep branch and bound tree memory usage below 48.7GB
#       42  1987092.600  2167827.598      7     26     18    8.34%      15     20
#       52  1987092.600  2167827.598      7     29      7    8.34%      15     21
#       62  1987092.600  2166652.145      7     32      8    8.29%       8     21
#       72  1987092.600  2166652.145      7     34     11    8.29%      18     22
#       82  1987092.600  2166652.145      7     33     10    8.29%       8     22
#       92  1987092.600  2166652.145      7     24      5    8.29%      20     22
#      102  1987092.600  2166652.145      7     18     10    8.29%      11     23
# Will try to keep branch and bound tree memory usage below 44.2GB
# q    164  2001811.550  2166652.145      8     12      8    7.61%       0     24
# Elapsed time (sec): 25, estimated tree completion: 0.78786
# Heap usage: 8409MB (peak 8409MB, 167MB system)
# B&B tree size: 146k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      202  2001811.550  2163051.444      8      5      7    7.45%       8     25
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      2 out of      1382 (ratio: 0.0014)
# Uncrunching matrix
# Final MIP objective                   : 2.001811550000001e+06
# Final MIP bound                       : 2.001813725994491e+06
#   Solution time / primaldual integral :     28.93s/ 53.793075%
#   Number of solutions found / nodes   :         8 /       273
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2958
# [8, 47, 71, 100, 136, 181, 186, 334, 421, 428, 440, 525, 585, 589, 610, 899, 1100, 1122, 1124, 1161, 1288, 1362, 1440, 1469, 1495, 1694, 1718, 1761, 1883, 2122, 2156, 2196, 2234, 2244, 2288, 2289, 2339, 2522, 2525, 2576, 2596, 2694, 2757, 2790, 2830, 2865, 2871, 2875, 2948, 2958]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:40:41, Jul 28, 2023
# Heap usage: 2110MB (peak 2140MB, 97MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8761599 cols        24785 elements   8761599 entities
# Presolved problem has:
#       3777 rows         1325 cols        11310 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3181MB (peak 5716MB, 97MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.40e-01,  1.00e+09] / [ 3.05e-05,  1.96e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.02e+05] / [ 1.00e+00,  3.94e+04]
#   Objective      [min,max] : [ 2.00e+00,  2.03e+06] / [ 2.00e+00,  2.03e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.7GB
#  *** Solution found: -563328.5000   Time:  12.28    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  12s
#             Dual                      Barrier
#     objective   sum inf
#  P  1841199.8   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 731 simplex iterations, 0.04s
#    Barrier: 12 barrier and 485 simplex iterations, 0.48s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    731       1841199.765      P      0     0        .000000    13
# Dual solved problem
#   731 simplex iterations in 0.73 seconds at time 13
#
# Final objective                       : 1.841199764877643e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 2.328e-10 / 2.328e-10
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a        -375560.8500  1841199.765      2               2.22e+06       0     13
# q         1262427.700  1841199.765      3                 31.43%       0     13
# R         1272783.700  1837763.213      4                 30.74%       0     14
# R         1292884.450  1837763.213      5                 29.65%       0     14
# R         1536726.650  1837763.213      6                 16.38%       0     14
#    1  K   1536726.650  1837763.213      6      3      0   16.38%      11     14
#    2  K   1536726.650  1833005.150      6      4      2   16.16%      14     16
#    3  K   1536726.650  1831618.750      6      2      4   16.10%      11     16
#    4  K   1536726.650  1830890.657      6      5      0   16.07%      26     16
#    5  K   1536726.650  1830114.696      6      5      4   16.03%      33     16
#    6  K   1536726.650  1830114.696      6      0      6   16.03%      28     16
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 3
# Cut elements in the matrix : 2879
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3257MB (peak 5716MB, 163MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1536726.650  1830042.882      6      2      1   16.03%      28     17
#        2  1536726.650  1829668.404      6      2      3   16.01%      27     18
#        3  1536726.650  1828666.386      6      3      3   15.96%      14     18
#        4  1536726.650  1828666.386      6      4      4   15.96%      13     19
#        5  1536726.650  1828666.386      6      4      4   15.96%      26     19
#        6  1536726.650  1827798.496      6      5      4   15.92%      13     19
#        7  1536726.650  1827798.496      6      6      5   15.92%      18     19
#        8  1536726.650  1827798.496      6      8      6   15.92%      13     19
#        9  1536726.650  1827798.496      6      9      4   15.92%       8     19
#       10  1536726.650  1827798.496      6     10      5   15.92%      18     20
#       20  1536726.650  1827553.497      6     17      6   15.91%       8     20
#       31  1536726.650  1826635.143      6     23     13   15.87%       8     21
#       41  1536726.650  1826635.143      6     33     10   15.87%      26     21
#       51  1536726.650  1826635.143      6     38      9   15.87%      27     21
#       62  1536726.650  1826635.143      6     40     21   15.87%      38     22
#       72  1536726.650  1826635.143      6     43     26   15.87%       8     22
#       83  1536726.650  1826635.143      6     53     14   15.87%       8     23
#       93  1536726.650  1826635.143      6     56     10   15.87%      26     23
#      103  1536726.650  1824616.850      6     63      8   15.78%      14     23
# Will try to keep branch and bound tree memory usage below 46.9GB
# Elapsed time (sec): 25, estimated tree completion: 0.12037
# Heap usage: 7220MB (peak 7220MB, 163MB system)
# B&B tree size: 0.7MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      203  1536726.650  1808787.483      6     98     20   15.04%       8     25
# q    247  1547112.800  1808787.483      7    108     14   14.47%       0     26
# q    280  1566450.800  1808787.483      8    136     19   13.40%       0     27
#      304  1566450.800  1808787.483      8    140      8   13.40%      13     27
# *    388  1668754.900  1808787.483      9    159     16    7.74%       0     28
#      404  1668754.900  1808787.483      9    151     11    7.74%       8     28
#      504  1668754.900  1808781.555      9    114     10    7.74%       8     30
#      605  1668754.900  1792945.896      9     45     14    6.93%       8     31
#      707  1668754.900  1778343.685      9      8     16    6.16%      20     33
# b    716  1685881.800  1777699.837     10      7      9    5.16%       0     34
# q    723  1690313.800  1777699.837     11      6     11    4.92%       0     34
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     10 out of      2961 (ratio: 0.0034)
# Uncrunching matrix
# Final MIP objective                   : 1.690313799999997e+06
# Final MIP bound                       : 1.690315641199762e+06
#   Solution time / primaldual integral :     36.70s/ 45.189065%
#   Number of solutions found / nodes   :        11 /       733
#   Max primal violation      (abs/rel) : 2.483e-11 / 9.506e-13
#   Max integer violation     (abs    ) : 9.506e-13
# 2974
# [28, 56, 78, 90, 94, 118, 135, 320, 354, 594, 671, 768, 825, 827, 852, 932, 954, 959, 1004, 1225, 1259, 1325, 1493, 1513, 1518, 1540, 1542, 1732, 1777, 1783, 1864, 2020, 2108, 2205, 2208, 2318, 2364, 2373, 2465, 2514, 2563, 2579, 2617, 2686, 2705, 2712, 2765, 2844, 2850, 2974]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:43:07, Jul 28, 2023
# Heap usage: 2189MB (peak 2189MB, 98MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8856575 cols        24786 elements   8856575 entities
# Presolved problem has:
#       3777 rows         1325 cols        11311 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3328MB (peak 5751MB, 98MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+09] / [ 3.05e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.92e+05] / [ 1.00e+00,  4.04e+04]
#   Objective      [min,max] : [ 2.00e+00,  2.13e+06] / [ 2.00e+00,  2.13e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.5GB
#  *** Solution found:  112691.6500   Time:  12.37    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  1959223.8   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 2033 simplex iterations, 0.15s
#    Barrier: 16 barrier and 1545 simplex iterations, 0.55s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       1959223.814      P      0     0        .000000    13
# Barrier solved problem
#   16 barrier and 1545 simplex iterations in 0.95 seconds at time 13
#
# Final objective                       : 1.959223814135416e+06
#   Max primal violation      (abs/rel) : 1.819e-12 / 1.819e-12
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1864817.050  1959223.814      2                  4.82%       0     13
# R         1866905.050  1959198.166      3                  4.71%       0     14
# R         1867220.050  1959198.166      4                  4.69%       0     14
#    1  K   1867220.050  1959198.166      4      1      0    4.69%      13     14
#    2  K   1867220.050  1959126.568      4      2      0    4.69%      18     14
#    3  K   1867220.050  1959026.949      4      2      1    4.69%      23     14
#    4  K   1867220.050  1959013.174      4      1      2    4.69%      19     14
#    5  K   1867220.050  1959013.174      4      0      1    4.69%      23     14
# Heuristic search 'R' started
# R         1902991.100  1959013.174      5                  2.86%       0     14
# R         1903550.100  1959013.174      6                  2.83%       0     15
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 2
# Cut elements in the matrix : 1684
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3403MB (peak 5751MB, 165MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1903550.100  1958703.330      6      2      1    2.82%      23     15
#        2  1903550.100  1958702.300      6      2      2    2.82%      23     16
#        3  1903550.100  1958702.300      6      1      3    2.82%       8     16
#        4  1903550.100  1958679.946      6      2      4    2.81%      13     16
#        5  1903550.100  1958594.557      6      3      5    2.81%      13     16
#        6  1903550.100  1958513.202      6      4      6    2.81%       8     16
#        7  1903550.100  1958423.647      6      5      7    2.80%       8     16
#        8  1903550.100  1958311.344      6      6      5    2.80%      13     16
#        9  1903550.100  1958311.344      6      5      8    2.80%       8     16
#       10  1903550.100  1958311.344      6      6      9    2.80%       8     16
#       20  1903550.100  1951010.086      6      4      8    2.43%      10     17
#       31  1903550.100  1938740.238      6      1     14    1.82%      13     17
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      1 out of       309 (ratio: 0.0032)
# Uncrunching matrix
# Final MIP objective                   : 1.903550100000001e+06
# Final MIP bound                       : 1.903552059223816e+06
#   Solution time / primaldual integral :     17.92s/ 77.147090%
#   Number of solutions found / nodes   :         6 /        31
#   Max primal violation      (abs/rel) : 1.936e-12 / 1.422e-16
#   Max integer violation     (abs    ) : 5.226e-13
# 2965
# [60, 65, 189, 195, 318, 412, 416, 483, 533, 562, 798, 963, 968, 1024, 1089, 1155, 1189, 1324, 1395, 1420, 1581, 1647, 1658, 1685, 1693, 1710, 1714, 1787, 1867, 1923, 2017, 2059, 2060, 2082, 2088, 2159, 2161, 2212, 2235, 2238, 2260, 2286, 2301, 2338, 2507, 2575, 2627, 2820, 2921, 2965]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:45:13, Jul 28, 2023
# Heap usage: 2119MB (peak 2149MB, 98MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8803088 cols        24792 elements   8803088 entities
# Presolved problem has:
#       3777 rows         1325 cols        11317 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3194MB (peak 5739MB, 98MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.20e-01,  1.00e+09] / [ 3.05e-05,  2.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.20e+05] / [ 1.00e+00,  3.92e+04]
#   Objective      [min,max] : [ 1.00e+00,  2.24e+06] / [ 1.00e+00,  2.24e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.7GB
#  *** Solution found: -19014.20000   Time:  12.33    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  1919598.5   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1168 simplex iterations, 0.10s
#    Barrier: 15 barrier and 1516 simplex iterations, 0.54s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1168       1919598.494      P      0     0        .000000    13
# Dual solved problem
#   1168 simplex iterations in 0.80 seconds at time 13
#
# Final objective                       : 1.919598493870278e+06
#   Max primal violation      (abs/rel) : 1.819e-12 / 1.819e-12
#   Max dual violation        (abs/rel) : 6.638e-06 / 6.638e-06
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1782589.300  1919598.494      2                  7.14%       0     13
# R         1788181.300  1918776.897      3                  6.81%       0     13
#    1  K   1788181.300  1918776.897      3      1      0    6.81%       8     14
#    2  K   1788181.300  1917285.074      3      2      0    6.73%      11     14
#    3  K   1788181.300  1916985.182      3      3      1    6.72%      22     14
#    4  K   1788181.300  1916595.529      3      6      2    6.70%      26     15
#    5  K   1788181.300  1916293.990      3      7      5    6.69%      32     16
#    6  K   1788181.300  1916201.176      3      2      5    6.68%      26     17
#    7  K   1788181.300  1916194.996      3      1      3    6.68%      29     17
#    8  K   1788181.300  1915666.740      3      3      0    6.65%      30     17
#    9  K   1788181.300  1915457.119      3     12      4    6.64%      41     17
#   10  K   1788181.300  1915451.913      3      2     11    6.64%    1315     18
#   11  K   1788181.300  1915414.532      3      6      2    6.64%      46     18
#   12  K   1788181.300  1915371.677      3      5      6    6.64%    1315     18
#   13  K   1788181.300  1915357.216      3      5      4    6.64%    1314     18
#   14  K   1788181.300  1915322.594      3      1      5    6.64%    1315     18
#   15  K   1788181.300  1915310.034      3      5      4    6.64%    1315     18
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 9
# Cut elements in the matrix : 4250
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3270MB (peak 5739MB, 164MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1788181.300  1915250.848      3      2      1    6.63%      35     20
#        2  1788181.300  1915162.787      3      2      2    6.63%       8     20
#        3  1788181.300  1915162.787      3      1      3    6.63%      25     20
#        4  1788181.300  1912313.855      3      2      3    6.49%      48     21
#        5  1788181.300  1912313.855      3      1      4    6.49%      25     21
#        6  1788181.300  1911945.227      3      2      4    6.47%      25     21
#        7  1788181.300  1911945.227      3      1      5    6.47%      21     21
#        8  1788181.300  1910601.144      3      2      6    6.41%      18     21
#        9  1788181.300  1910184.709      3      3      7    6.39%      23     21
#       12  1788181.300  1909736.136      3      4      6    6.37%       8     21
# g     16  1879507.900  1908624.374      4      4      8    1.53%       0     21
#       22  1879507.900  1908438.289      4      2      8    1.52%       8     21
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 1.879507899999999e+06
# Final MIP bound                       : 1.879509819598493e+06
#   Solution time / primaldual integral :     22.20s/ 63.343940%
#   Number of solutions found / nodes   :         4 /        27
#   Max primal violation      (abs/rel) : 1.859e-11 / 3.561e-13
#   Max integer violation     (abs    ) : 3.561e-13
# 3000
# [50, 212, 230, 248, 249, 314, 348, 350, 407, 495, 538, 579, 591, 649, 690, 809, 909, 912, 965, 992, 1007, 1082, 1135, 1187, 1242, 1318, 1351, 1379, 1382, 1426, 1455, 1465, 1479, 1544, 1772, 1850, 1953, 2055, 2134, 2204, 2240, 2264, 2310, 2418, 2451, 2510, 2578, 2666, 2669, 3000]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:47:26, Jul 28, 2023
# Heap usage: 2222MB (peak 2222MB, 100MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      9012003 cols        24794 elements   9012003 entities
# Presolved problem has:
#       3777 rows         1325 cols        11319 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3376MB (peak 5835MB, 100MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 9.00e-01,  1.00e+09] / [ 3.05e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.26e+05] / [ 1.00e+00,  4.41e+04]
#   Objective      [min,max] : [ 2.00e+00,  2.29e+06] / [ 2.00e+00,  2.29e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.4GB
#  *** Solution found: -759927.0000   Time:  12.71    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  1968620.9   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1182 simplex iterations, 0.08s
#    Barrier: 15 barrier and 1162 simplex iterations, 0.52s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1182       1968620.922      P      0     0        .000000    13
# Dual solved problem
#   1182 simplex iterations in 0.85 seconds at time 13
#
# Final objective                       : 1.968620922466685e+06
#   Max primal violation      (abs/rel) : 4.547e-12 / 2.493e-12
#   Max dual violation        (abs/rel) : 5.821e-11 / 5.821e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a         35804.95000  1968620.922      2                 98.18%       0     13
# q         1615649.100  1968620.922      3                 17.93%       0     14
# R         1634363.100  1962423.965      4                 16.72%       0     14
# R         1730934.350  1962423.965      5                 11.80%       0     15
# R         1844984.400  1962423.965      6                  5.98%       0     15
#    1  K   1844984.400  1962423.965      6      1      0    5.98%      11     15
#    2  K   1844984.400  1961772.740      6      1      0    5.95%      11     15
#    3  K   1844984.400  1960372.499      6      3      0    5.89%      16     16
#    4  K   1844984.400  1960199.178      6      2      4    5.88%      13     16
#    5  K   1844984.400  1959572.596      6      9      1    5.85%      18     17
#    6  K   1844984.400  1959572.596      6      0      8    5.85%      15     17
# Heuristic search 'R' started
# R         1855162.250  1959572.596      7                  5.33%       0     18
# R         1856058.250  1959572.596      8                  5.28%       0     18
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 3
# Cut elements in the matrix : 2171
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3454MB (peak 5835MB, 167MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1856058.250  1959523.143      8      2      1    5.28%      15     18
#        2  1856058.250  1959497.774      8      2      3    5.28%      37     20
#        3  1856058.250  1958068.837      8      3      4    5.21%      42     20
#        4  1856058.250  1958068.837      8      3      4    5.21%       8     20
#        5  1856058.250  1958068.837      8      4      5    5.21%      15     21
#        6  1856058.250  1958068.837      8      5      4    5.21%       8     21
#        7  1856058.250  1958068.837      8      4      5    5.21%       8     21
#        8  1856058.250  1958068.837      8      3      6    5.21%       8     21
#        9  1856058.250  1958068.837      8      4      6    5.21%       8     21
#       10  1856058.250  1958068.837      8      3      6    5.21%      14     21
#       20  1856058.250  1956061.178      8     10     10    5.11%      20     21
# Will try to keep branch and bound tree memory usage below 48.4GB
#       32  1856058.250  1956061.178      8      4     10    5.11%      14     22
#       43  1856058.250  1948122.677      8      2      5    4.73%       8     23
#       53  1856058.250  1948122.677      8      5      6    4.73%       8     24
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      2 out of       434 (ratio: 0.0046)
# Uncrunching matrix
# Final MIP objective                   : 1.856058250000000e+06
# Final MIP bound                       : 1.856060218620923e+06
#   Solution time / primaldual integral :     26.07s/ 57.317363%
#   Number of solutions found / nodes   :         8 /        57
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2928
# [80, 144, 161, 199, 305, 337, 338, 358, 411, 425, 453, 513, 517, 637, 647, 666, 670, 708, 897, 1015, 1075, 1107, 1190, 1197, 1287, 1421, 1480, 1650, 1659, 1712, 1877, 1885, 1974, 2049, 2070, 2073, 2096, 2230, 2245, 2361, 2440, 2558, 2577, 2608, 2676, 2709, 2723, 2754, 2904, 2928]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:49:41, Jul 28, 2023
# Heap usage: 2072MB (peak 2102MB, 95MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8584899 cols        24788 elements   8584899 entities
# Presolved problem has:
#       3777 rows         1325 cols        11313 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 11 seconds
# Heap usage: 3127MB (peak 5618MB, 95MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.30e-01,  1.00e+09] / [ 3.05e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.10e+05] / [ 1.00e+00,  4.22e+04]
#   Objective      [min,max] : [ 1.00e+00,  2.19e+06] / [ 1.00e+00,  2.19e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.8GB
#  *** Solution found: -839224.3000   Time:  12.14    Heuristic: h ***
#  *** Solution found:  530829.1000   Time:  12.42    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  1935395.5   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 1648 simplex iterations, 0.13s
#    Barrier: 13 barrier and 1629 simplex iterations, 0.53s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       1935395.540      P      0     0        .000000    13
# Barrier solved problem
#   13 barrier and 1629 simplex iterations in 0.87 seconds at time 13
#
# Final objective                       : 1.935395539792232e+06
#   Max primal violation      (abs/rel) : 1.819e-12 / 1.597e-12
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         1904288.950  1933916.449      3                  1.53%       0     13
#    1  K   1904288.950  1933916.449      3      1      0    1.53%      10     13
#
# Cuts in the matrix         : 1
# Cut elements in the matrix : 572
#
# Performing root presolve...
#
# Reduced problem has:     546 rows     205 columns      1746 elements
# Presolve dropped   :    3232 rows    1120 columns     10139 elements
# Presolve tightened :        11 elements
# Will try to keep branch and bound tree memory usage below 51.4GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,  14s
#             Dual
#     objective   dual inf
#  D  1935395.5   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 233 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    233       1935395.540      D      0     0        .000000    14
# Dual solved problem
#   233 simplex iterations in 0.00 seconds at time 14
#
# Final objective                       : 1.935395539792214e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#
# Cuts in the matrix         : 1
# Cut elements in the matrix : 122
#
# Performing root presolve...
#
# Reduced problem has:      70 rows      31 columns       225 elements
# Presolve dropped   :     476 rows     174 columns      1521 elements
# Presolve tightened :        16 elements
# Will try to keep branch and bound tree memory usage below 51.6GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,  16s
#             Dual
#     objective   dual inf
#  D  1930417.4   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 331 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    331       1930417.391      D      0     0        .000000    16
# Dual solved problem
#   331 simplex iterations in 0.00 seconds at time 16
#
# Final objective                       : 1.930417391195837e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   1904288.950  1930043.188      3      8      1    1.33%       8     16
#    2  K   1904288.950  1929682.863      3      9      5    1.32%       8     16
#    3  K   1904288.950  1929661.673      3      6      7    1.31%      17     16
#    4  K   1904288.950  1929635.979      3      2      5    1.31%      14     16
#    5  K   1904288.950  1929551.401      3      6      2    1.31%      17     16
#    6  K   1904288.950  1929399.260      3      8      3    1.30%      20     16
#
# Cuts in the matrix         : 17
# Cut elements in the matrix : 67
#
# Performing root presolve...
#
# Reduced problem has:      46 rows      15 columns       130 elements
# Presolve dropped   :      40 rows      16 columns       137 elements
# Presolve tightened :        26 elements
# Will try to keep branch and bound tree memory usage below 51.6GB
# Starting concurrent solve with dual (1 thread)
#
#  Concurrent-Solve,  17s
#             Dual
#     objective   dual inf
#  D  1922421.1   .0000000
# ------- optimal --------
# Concurrent statistics:
#       Dual: 426 simplex iterations, 0.00s
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg   Sum Dual Inf  Time
#    426       1922421.075      D      0     0        .000000    17
# Dual solved problem
#   426 simplex iterations in 0.00 seconds at time 17
#
# Final objective                       : 1.922421074610245e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#  *** Search completed ***
# Final MIP objective                   : 1.904288950000000e+06
# Final MIP bound                       : 1.904290885395539e+06
#   Solution time / primaldual integral :     17.58s/ 78.424221%
#   Number of solutions found / nodes   :         3 /         0
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2975
# [46, 274, 418, 457, 490, 542, 554, 561, 577, 664, 695, 762, 775, 779, 927, 941, 1094, 1251, 1457, 1484, 1569, 1660, 1699, 1826, 1835, 1844, 1853, 1895, 2047, 2151, 2189, 2222, 2279, 2293, 2297, 2316, 2352, 2493, 2508, 2540, 2546, 2569, 2653, 2683, 2695, 2786, 2818, 2856, 2960, 2975]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:51:47, Jul 28, 2023
# Heap usage: 2190MB (peak 2190MB, 98MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8862528 cols        24773 elements   8862528 entities
# Presolved problem has:
#       3777 rows         1325 cols        11298 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3330MB (peak 5754MB, 98MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.60e-01,  1.00e+09] / [ 3.05e-05,  1.95e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.95e+05] / [ 1.00e+00,  3.80e+04]
#   Objective      [min,max] : [ 1.00e+00,  1.92e+06] / [ 1.00e+00,  1.92e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.5GB
#  *** Solution found: -165671.7000   Time:  12.68    Heuristic: e ***
#  *** Solution found:  321462.3000   Time:  12.96    Heuristic: k ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  1820980.2   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1711 simplex iterations, 0.09s
#    Barrier: 14 barrier and 1400 simplex iterations, 0.54s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1711       1820980.237      P      0     0        .000000    13
# Dual solved problem
#   1711 simplex iterations in 0.87 seconds at time 13
#
# Final objective                       : 1.820980236628215e+06
#   Max primal violation      (abs/rel) : 1.110e-16 / 9.574e-17
#   Max dual violation        (abs/rel) : 1.455e-11 / 1.455e-11
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1216766.350  1820980.237      3                 33.18%       0     14
#    1  K   1216766.350  1814744.019      3      3      0   32.95%       8     14
#    2  K   1216766.350  1814744.019      3      0      2   32.95%      14     14
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 1
# Cut elements in the matrix : 283
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3405MB (peak 5754MB, 165MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1216766.350  1812980.400      3      2      1   32.89%      14     14
#        2  1216766.350  1811700.778      3      2      3   32.84%      14     15
#        3  1216766.350  1811169.487      3      3      4   32.82%      14     15
#        4  1216766.350  1811060.501      3      4      5   32.81%      13     15
#        5  1216766.350  1809447.427      3      5      4   32.75%       8     15
#        6  1216766.350  1805533.461      3      6      6   32.61%       8     15
#        7  1216766.350  1805533.461      3      7      5   32.61%       8     16
#        8  1216766.350  1805533.461      3      8      5   32.61%       8     16
#        9  1216766.350  1805533.461      3      9      6   32.61%       8     16
#       10  1216766.350  1805533.461      3     10      6   32.61%      13     16
# k     18  1416550.750  1802660.531      4     16      6   21.42%       0     17
#       20  1416550.750  1802660.531      4     16      8   21.42%       8     17
#       30  1416550.750  1801510.131      4     25     10   21.37%       8     17
# k     41  1481339.350  1801510.131      5     31     15   17.77%       0     18
#       42  1481339.350  1801510.131      5     31     13   17.77%       8     18
#       52  1481339.350  1801510.131      5     37     17   17.77%      13     18
# *     55  1481401.350  1801510.131      6     38     22   17.77%       0     18
#       62  1481401.350  1801510.131      6     52     20   17.77%       8     18
# k     65  1664238.700  1801510.131      7     54      8    7.62%       0     19
# Will try to keep branch and bound tree memory usage below 48.8GB
# Elapsed time (sec): 19, estimated tree completion: 0.01514
# Heap usage: 5203MB (peak 5754MB, 165MB system)
# B&B tree size: 297k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# k     72  1665651.700  1801510.131      8     54     10    7.54%       0     19
#       73  1665651.700  1801510.131      8     54     10    7.54%       1     19
#       90  1665651.700  1801510.131      8     37      1    7.54%       1     19
#      100  1665651.700  1801510.131      8     36      7    7.54%       8     20
# Will try to keep branch and bound tree memory usage below 44.3GB
#      202  1665651.700  1798187.207      8     16     11    7.37%       8     22
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      5 out of      1261 (ratio: 0.0040)
# Uncrunching matrix
# Final MIP objective                   : 1.665651700000000e+06
# Final MIP bound                       : 1.665653520980237e+06
#   Solution time / primaldual integral :     25.09s/ 63.203830%
#   Number of solutions found / nodes   :         8 /       237
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2982
# [13, 75, 83, 173, 187, 231, 282, 283, 371, 571, 598, 623, 682, 733, 760, 896, 904, 905, 976, 1101, 1152, 1159, 1252, 1280, 1301, 1606, 1741, 1851, 1998, 2014, 2029, 2182, 2210, 2224, 2241, 2281, 2284, 2327, 2421, 2430, 2482, 2588, 2624, 2668, 2692, 2704, 2812, 2897, 2955, 2982]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 16:54:02, Jul 28, 2023
# Heap usage: 2199MB (peak 2199MB, 99MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8904255 cols        24785 elements   8904255 entities
# Presolved problem has:
#       3777 rows         1325 cols        11310 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3343MB (peak 5777MB, 99MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.70e-01,  1.00e+09] / [ 3.05e-05,  1.98e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.14e+05] / [ 1.00e+00,  4.28e+04]
#   Objective      [min,max] : [ 3.00e+00,  2.42e+06] / [ 3.00e+00,  2.42e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.4GB
#  *** Solution found: -1827980.000   Time:  12.51    Heuristic: e ***
#  *** Solution found: -254153.8000   Time:  12.80    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  2040418.0   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 880 simplex iterations, 0.05s
#    Barrier: 14 barrier and 473 simplex iterations, 0.52s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    880       2040418.026      P      0     0        .000000    13
# Dual solved problem
#   880 simplex iterations in 0.85 seconds at time 13
#
# Final objective                       : 2.040418025710875e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 2.328e-10 / 1.673e-10
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a        -21861.20000  2040418.026      3               2.06e+06       0     14
# R         -757.200000  2029987.280      4               2.03e+06       0     15
# R         1936130.000  2029987.280      5                  4.62%       0     15
#    1  K   1936130.000  2029987.280      5      3      0    4.62%      11     15
#    2  K   1936130.000  2029199.862      5      3      1    4.59%      23     15
#    3  K   1936130.000  2029188.745      5      1      1    4.59%      30     15
#    4  K   1936130.000  2027751.435      5      2      0    4.52%      30     15
#    5  K   1936130.000  2027538.009      5      3      5    4.51%      20     16
#    6  K   1936130.000  2027512.947      5      2      2    4.51%      22     16
#    7  K   1936130.000  2027495.079      5      1      1    4.51%      23     16
#    8  K   1936130.000  2027484.757      5      1      1    4.51%      23     16
#    9  K   1936130.000  2027484.757      5      0      1    4.51%      23     16
# Heuristic search 'R' started
# R         1942743.000  2027484.757      6                  4.18%       0     16
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 4
# Cut elements in the matrix : 1336
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3418MB (peak 5777MB, 166MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1942743.000  2026091.306      6      2      1    4.11%      23     17
#        2  1942743.000  2026091.306      6      2      3    4.11%       8     17
#        3  1942743.000  2026091.306      6      3      4    4.11%       8     17
#        4  1942743.000  2026091.306      6      4      4    4.11%       8     18
#        5  1942743.000  2026091.306      6      5      5    4.11%       8     18
#        6  1942743.000  2026091.306      6      6      5    4.11%       8     18
#        7  1942743.000  2026091.306      6      7      6    4.11%       8     18
#        8  1942743.000  2026091.306      6      8      6    4.11%       8     18
#        9  1942743.000  2026091.306      6      9      5    4.11%       8     18
#       10  1942743.000  2026091.306      6     10      7    4.11%       8     18
#       21  1942743.000  2026091.306      6     15      7    4.11%      22     18
# ...
# k         1506779.500  1925831.916      3                 21.76%       0     14
# k         1643160.400  1925698.798      4                 14.67%       0     14
# R         1697346.800  1925698.798      5                 11.86%       0     15
# R         1710179.300  1925698.798      6                 11.19%       0     15
#    1  K   1710179.300  1925698.798      6      1      0   11.19%       8     15
#    2  K   1710179.300  1924183.224      6      5      0   11.12%      13     16
#    3  K   1710179.300  1923712.976      6      7      2   11.10%      24     16
#    4  K   1710179.300  1923568.033      6     17      6   11.09%      19     16
#    5  K   1710179.300  1923568.033      6      0      8   11.09%       8     16
# Heuristic search 'R' started
# R         1740835.400  1923568.033      7                  9.50%       0     16
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 14
# Cut elements in the matrix : 3415
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3213MB (peak 5641MB, 160MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1740835.400  1923557.294      7      2      1    9.50%       8     17
#        2  1740835.400  1923557.294      7      2      3    9.50%       8     17
#        3  1740835.400  1923557.294      7      3      4    9.50%       8     17
#        4  1740835.400  1923557.294      7      4      3    9.50%      23     18
#        5  1740835.400  1922836.665      7      5      5    9.47%       8     18
#        6  1740835.400  1922836.665      7      6      5    9.47%       8     18
#        7  1740835.400  1922836.665      7      7      4    9.47%      22     18
#        8  1740835.400  1922594.821      7      8      6    9.45%       8     18
#        9  1740835.400  1922594.821      7      9      4    9.45%       8     18
#       10  1740835.400  1922594.821      7     10      4    9.45%       8     18
# k     18  1786293.200  1921355.798      8     15      6    7.03%       0     18
#       20  1786293.200  1921355.798      8     15      7    7.03%      13     18
#       30  1786293.200  1920342.709      8     22      9    6.98%      19     19
#       41  1786293.200  1920203.015      8     27     11    6.97%      13     19
# Will try to keep branch and bound tree memory usage below 49.0GB
#       52  1786293.200  1920181.431      8     32     12    6.97%      22     20
#       65  1786293.200  1915358.913      8     36     12    6.74%      14     20
#       76  1786293.200  1915358.913      8     37     13    6.74%       8     20
#       87  1786293.200  1911939.308      8     35     10    6.57%      18     21
#       97  1786293.200  1911939.308      8     37     12    6.57%       8     21
# Will try to keep branch and bound tree memory usage below 45.8GB
# Elapsed time (sec): 21, estimated tree completion: 0.16399
# Heap usage: 7240MB (peak 7240MB, 161MB system)
# B&B tree size: 0.6MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      108  1786293.200  1911939.308      8     35     19    6.57%       8     21
#      208  1786293.200  1911458.425      8     36     11    6.55%      18     22
#      308  1786293.200  1910778.507      8     12      9    6.51%      14     23
# k    322  1789753.200  1910778.507      9     13      7    6.33%       0     23
#      408  1789753.200  1910173.084      9     15     15    6.30%      14     24
# k    429  1791489.200  1910173.084     10     11     18    6.21%       0     25
# k    446  1813835.800  1910173.084     11     11     21    5.04%       0     25
# E    448  1814055.800  1910173.084     12     11     22    5.03%       0     25
#      510  1814055.800  1904761.284     12      2      9    4.76%       8     26
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      4 out of      2214 (ratio: 0.0018)
# Uncrunching matrix
# Final MIP objective                   : 1.814055799999999e+06
# Final MIP bound                       : 1.814057725831916e+06
#   Solution time / primaldual integral :     28.05s/ 55.200662%
#   Number of solutions found / nodes   :        12 /       513
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2922
# [51, 74, 85, 132, 290, 325, 430, 438, 480, 486, 659, 696, 788, 806, 818, 843, 915, 1050, 1091, 1239, 1272, 1306, 1413, 1416, 1447, 1506, 1572, 1611, 1667, 1744, 1805, 1927, 1949, 1999, 2016, 2050, 2074, 2116, 2194, 2291, 2347, 2461, 2520, 2613, 2660, 2741, 2775, 2861, 2867, 2922]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 17:17:56, Jul 28, 2023
# Heap usage: 2065MB (peak 2094MB, 95MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8549775 cols        24790 elements   8549775 entities
# Presolved problem has:
#       3777 rows         1325 cols        11315 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3116MB (peak 5599MB, 95MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 5.70e-01,  1.00e+09] / [ 3.05e-05,  2.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.11e+05] / [ 1.00e+00,  4.15e+04]
#   Objective      [min,max] : [ 3.00e+00,  2.16e+06] / [ 3.00e+00,  2.16e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.8GB
#  *** Solution found: -345075.5000   Time:  12.37    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  2057219.8   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 624 simplex iterations, 0.03s
#    Barrier: 13 barrier and 0 simplex iterations, 0.48s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    624       2057219.754      P      0     0        .000000    13
# Dual solved problem
#   624 simplex iterations in 0.76 seconds at time 13
#
# Final objective                       : 2.057219754261271e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 4.657e-10 / 4.657e-10
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1653322.000  2057219.754      2                 19.63%       0     13
# k         1656086.000  2052066.472      3                 19.30%       0     13
#    1  K   1656086.000  2052066.472      3      1      0   19.30%       8     14
#    2  K   1656086.000  2049034.570      3      3      0   19.18%      13     15
#    3  K   1656086.000  2045385.177      3      9      1   19.03%      21     16
#    4  K   1656086.000  2045170.424      3     13      6   19.02%      39     16
#    5  K   1656086.000  2045087.764      3      8     12   19.02%      44     16
#    6  K   1656086.000  2045083.519      3      5      8   19.02%      51     16
#    7  K   1656086.000  2045082.821      3      1      4   19.02%      62     16
#    8  K   1656086.000  2045082.821      3      0      0   19.02%      61     16
# Heuristic search 'R' started
# R         1745380.200  2045082.821      4                 14.65%       0     17
# R         1781175.400  2045082.821      5                 12.90%       0     17
# R         1839299.000  2045082.821      6                 10.06%       0     17
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 9
# Cut elements in the matrix : 4281
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3190MB (peak 5599MB, 159MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1839299.000  2045019.638      6      2      1   10.06%      61     18
#        2  1839299.000  2045019.638      6      2      2   10.06%      61     19
#        3  1839299.000  2045019.638      6      1      3   10.06%      44     19
#        4  1839299.000  2043367.065      6      2      4    9.99%      36     19
#        5  1839299.000  2042506.300      6      3      4    9.95%       6     19
#        6  1839299.000  2042506.300      6      4      5    9.95%       8     20
#        7  1839299.000  2042506.300      6      5      4    9.95%       6     20
#        8  1839299.000  2042506.300      6      4      6    9.95%       8     20
#        9  1839299.000  2042506.300      6      5      5    9.95%      36     20
#       10  1839299.000  2040662.112      6      6      7    9.87%       8     20
#       20  1839299.000  2040599.252      6     12      8    9.86%      14     20
#       31  1839299.000  2036413.113      6     16      9    9.68%       3     21
# b     31  1845436.400  2036413.113      7     17      9    9.38%       0     21
# Will try to keep branch and bound tree memory usage below 49.1GB
#       42  1845436.400  2036371.305      7     17     14    9.38%       8     22
#       52  1845436.400  2036371.305      7     16      8    9.38%      14     22
#       62  1845436.400  2036371.305      7     12      7    9.38%       8     23
#       72  1845436.400  2036371.305      7      8      8    9.38%       8     23
# Will try to keep branch and bound tree memory usage below 46.6GB
#       82  1845436.400  2036371.305      7      7     11    9.38%      14     23
#       92  1845436.400  2036371.305      7      9      6    9.38%      11     23
# Elapsed time (sec): 23, estimated tree completion: 0.78670
# Heap usage: 6723MB (peak 6723MB, 159MB system)
# B&B tree size: 218k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      102  1845436.400  2036371.305      7     10     14    9.38%       8     23
# E    127  1855082.350  2026499.313      8     10     11    8.46%       0     24
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      4 out of       904 (ratio: 0.0044)
# Uncrunching matrix
# Final MIP objective                   : 1.855082350000000e+06
# Final MIP bound                       : 1.855084407219754e+06
#   Solution time / primaldual integral :     26.45s/ 56.627500%
#   Number of solutions found / nodes   :         8 /       143
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2902
# [106, 184, 369, 388, 414, 443, 456, 625, 635, 693, 740, 858, 875, 902, 946, 1062, 1181, 1269, 1290, 1323, 1326, 1530, 1538, 1587, 1631, 1648, 1654, 1692, 1760, 1838, 1946, 1994, 2164, 2200, 2228, 2231, 2325, 2462, 2479, 2487, 2498, 2545, 2773, 2807, 2834, 2843, 2846, 2853, 2899, 2902]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 17:20:09, Jul 28, 2023
# Heap usage: 2040MB (peak 2069MB, 94MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8433215 cols        24795 elements   8433215 entities
# Presolved problem has:
#       3777 rows         1325 cols        11320 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3080MB (peak 5534MB, 94MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 4.10e-01,  1.00e+09] / [ 3.05e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.21e+05] / [ 1.00e+00,  4.36e+04]
#   Objective      [min,max] : [ 4.00e+00,  2.37e+06] / [ 4.00e+00,  2.37e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.9GB
#  *** Solution found: -75264.40000   Time:  12.59    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  2154560.2   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 1359 simplex iterations, 0.16s
#    Barrier: 13 barrier and 1604 simplex iterations, 0.55s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       2154560.178      P      0     0        .000000    13
# Barrier solved problem
#   13 barrier and 1604 simplex iterations in 0.90 seconds at time 13
#
# Final objective                       : 2.154560178298354e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1702896.150  2154560.178      2                 20.96%       0     13
#    1  K   1702896.150  2154560.178      2      0      0   20.96%       8     13
# Heuristic search 'R' started
# R         1702902.150  2154560.178      3                 20.96%       0     14
# R         1934040.500  2154560.178      4                 10.24%       0     14
# R         2042645.200  2154560.178      5                  5.19%       0     14
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3151MB (peak 5534MB, 157MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  2042645.200  2150209.069      5      2      1    5.00%       8     15
#        2  2042645.200  2149909.724      5      2      3    4.99%      14     15
#        3  2042645.200  2149135.275      5      3      3    4.96%      11     15
#        4  2042645.200  2149135.275      5      4      4    4.96%       8     16
#        5  2042645.200  2149135.275      5      5      4    4.96%       8     16
#        6  2042645.200  2146763.759      5      6      4    4.85%      11     16
#        7  2042645.200  2146150.403      5      7      4    4.82%       8     16
#        8  2042645.200  2146150.403      5      8      5    4.82%       8     16
#        9  2042645.200  2146150.403      5      9      5    4.82%       8     16
#       10  2042645.200  2146150.403      5      9      5    4.82%       8     16
#       20  2042645.200  2145739.511      5     16      8    4.80%       8     16
#       30  2042645.200  2145739.511      5     21      6    4.80%       8     16
#       40  2042645.200  2145739.511      5     27      8    4.80%       8     16
#       51  2042645.200  2141735.368      5     30      9    4.63%       8     17
# Will try to keep branch and bound tree memory usage below 46.6GB
#       61  2042645.200  2141735.368      5     22      7    4.63%       8     18
# *     61  2064179.500  2141735.368      6     21      7    3.62%       0     18
#       71  2064179.500  2141735.368      6     12      6    3.62%       8     18
#       81  2064179.500  2138479.505      6      5      9    3.47%       8     18
#       91  2064179.500  2123347.753      6      1      5    2.79%      11     19
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      1 out of       496 (ratio: 0.0020)
# Uncrunching matrix
# Final MIP objective                   : 2.064179499999935e+06
# Final MIP bound                       : 2.064181654560113e+06
#   Solution time / primaldual integral :     20.89s/ 68.280433%
#   Number of solutions found / nodes   :         6 /        91
#   Max primal violation      (abs/rel) : 1.817e-12 / 1.817e-12
#   Max integer violation     (abs    ) : 1.819e-12

# %% [markdown]
# # Merged lists: 10 instances each one of 4 sets of 50 elements

# %%
merged_sets_50 = []
for ele in Sets_50_sorted:
    midi = []
    hp1 = []
    hp2 = []
    hp3 = []
    hp4 = []
    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][0][r], **ele[1][0][r]}
            index_merg = list(a.keys())
            hp1.append(a)
        else: 
            a = {}
            for ind_i in index_merg:
                for ind_j in index_merg:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)] 
            hp1.append(a)
    midi.append(hp1)
    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][0][r], **ele[1][1][r]}
            index_merg = list(a.keys())
            hp2.append(a)
        else: 
            a = {}
            for ind_i in index_merg:
                for ind_j in index_merg:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)] 
            hp2.append(a)
    midi.append(hp2)
    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][1][r], **ele[1][0][r]}
            index_merg = list(a.keys())
            hp3.append(a)
        else: 
            a = {}
            for ind_i in index_merg:
                for ind_j in index_merg:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)] 
            hp3.append(a)
    midi.append(hp3)
    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][1][r], **ele[1][1][r]}
            index_merg = list(a.keys())
            hp4.append(a)
        else: 
            a = {}
            for ind_i in index_merg:
                for ind_j in index_merg:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)] 
            hp4.append(a)
    midi.append(hp4)

    merged_sets_50.append(midi)

# %% [markdown]
# # 4 sets to enter to the model (refer to the report for the implementation explanation)

# %%
before_model_50 = []
for ele in Sets_50_sorted:
    midib = []
    hlpb1 = []
    hlpb2 = []
    hlpb3 = []
    hlpb4 = []
    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][0][r], **ele[1][0][r]}
            index_bef = list(a.keys())
            hlpb1.append(a)
        else: 
            a = {}
            for ind_i in index_bef:
                for ind_j in index_bef:
                    a[(ind_i,ind_j)] = set_items[3][(ind_i, ind_j)]
            hlpb1.append(a)

    midib.append(hlpb1)

    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][0][r], **ele[1][1][r]}
            index_bef = list(a.keys())
            hlpb2.append(a)
        else: 
            a = {}
            for ind_i in index_bef:
                for ind_j in index_bef:
                    a[(ind_i,ind_j)] = set_items[3][(ind_i, ind_j)]
            hlpb2.append(a)

    midib.append(hlpb2)

    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][1][r], **ele[1][0][r]}
            index_bef = list(a.keys())
            hlpb3.append(a)
        else: 
            a = {}
            for ind_i in index_bef:
                for ind_j in index_bef:
                    a[(ind_i,ind_j)] = set_items[3][(ind_i, ind_j)]
            hlpb3.append(a)

    midib.append(hlpb3)


    for r in range(len(Sets_50_sorted[0][0][0])):
        if r != 3:
            a = {**ele[0][1][r], **ele[1][1][r]}
            index_bef = list(a.keys())
            hlpb4.append(a)
        else: 
            a = {}
            for ind_i in index_bef:
                for ind_j in index_bef:
                    a[(ind_i,ind_j)] = set_items[3][(ind_i, ind_j)]
            hlpb4.append(a)

    midib.append(hlpb4)

        
    before_model_50.append(midib)

# %%
scored_50_4 = []
for ele in merged_sets_50:
    score_4 = []
    for st in ele:
        sc = calculate_score(st)
        score_4.append(sc)
    scored_50_4.append(score_4)
# Out:
# 2644
# [5, 8, 35, 47, 53, 71, 100, 136, 181, 186, 238, 334, 341, 347, 421, 428, 440, 451, 473, 485, 525, 585, 586, 589, 610, 734, 756, 766, 782, 868, 898, 899, 919, 1030, 1058, 1100, 1122, 1124, 1150, 1161, 1278, 1288, 1300, 1362, 1440, 1469, 2372, 2513, 2596, 2644]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:18:16, Jul 28, 2023
# Heap usage: 1687MB (peak 1710MB, 77MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      7001315 cols        24792 elements   7001315 entities
# Presolved problem has:
#       3777 rows         1325 cols        11317 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 9 seconds
# Heap usage: 2543MB (peak 4669MB, 77MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.40e-01,  1.00e+09] / [ 3.05e-05,  1.94e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.81e+05] / [ 1.00e+00,  3.84e+04]
#   Objective      [min,max] : [ 2.00e+00,  1.98e+06] / [ 2.00e+00,  1.98e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 53.4GB
#  *** Solution found: -575658.9000   Time:  10.00    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  10s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  1861585.1   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 2407 simplex iterations, 0.19s
#    Barrier: 12 barrier and 1683 simplex iterations, 0.46s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       1861585.056      P      0     0        .000000    10
# Barrier solved problem
#   12 barrier and 1683 simplex iterations in 0.74 seconds at time 10
#
# Final objective                       : 1.861585055977888e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1152819.300  1861585.056      2                 38.07%       0     11
#    1  K   1152819.300  1861585.056      2      0      0   38.07%       8     11
# Heuristic search 'R' started
# R         1157692.300  1861585.056      3                 37.81%       0     11
# R         1189902.450  1861585.056      4                 36.08%       0     11
# R         1196688.500  1861585.056      5                 35.72%       0     11
# R         1297395.300  1861585.056      6                 30.31%       0     12
# R         1386132.200  1861585.056      7                 25.54%       0     12
# R         1442975.050  1861585.056      8                 22.49%       0     12
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 2604MB (peak 4669MB, 130MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1442975.050  1856065.679      8      2      1   22.26%       8     13
#        2  1442975.050  1856065.679      8      2      3   22.26%       8     13
#        3  1442975.050  1856065.679      8      3      4   22.26%       8     13
#        4  1442975.050  1856065.679      8      4      4   22.26%       8     13
#        5  1442975.050  1856065.679      8      5      5   22.26%       8     13
#        6  1442975.050  1856060.943      8      6      5   22.26%      13     13
#        7  1442975.050  1856060.943      8      7      6   22.26%       8     13
#        8  1442975.050  1856060.943      8      8      5   22.26%       8     13
#        9  1442975.050  1856060.943      8      8      3   22.26%       8     13
#       10  1442975.050  1855136.397      8     10      5   22.22%      13     13
#       20  1442975.050  1839475.806      8     18      6   21.56%       8     14
#       30  1442975.050  1839475.806      8     28     11   21.56%      13     14
#       40  1442975.050  1832941.875      8     31     15   21.28%       8     15
#       50  1442975.050  1832941.875      8     42      8   21.28%      18     15
#       61  1442975.050  1832941.875      8     44     27   21.28%       8     15
#       71  1442975.050  1830696.460      8     54     10   21.18%      18     15
#       81  1442975.050  1830148.356      8     57     21   21.16%       8     16
#       91  1442975.050  1830148.356      8     63      9   21.16%       8     16
# Will try to keep branch and bound tree memory usage below 50.4GB
#      102  1442975.050  1830148.356      8     61     29   21.16%      13     16
# Elapsed time (sec): 17, estimated tree completion: 0.11373
# Heap usage: 5253MB (peak 5253MB, 130MB system)
# B&B tree size: 0.5MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# k    121  1534332.600  1830148.356      9     66      8   16.16%       0     17
#      202  1534332.600  1828747.557      9     96     11   16.10%      13     19
#      302  1534332.600  1828747.557      9    122     29   16.10%       8     20
#      402  1534332.600  1825405.931      9    174     21   15.95%       8     21
# k    421  1535946.200  1825405.931     10    189     10   15.86%       0     21
#      503  1535946.200  1824968.851     10    207     13   15.84%       8     23
# *    518  1551604.200  1824968.851     11    218     24   14.98%       0     23
#      603  1551604.200  1824968.851     11    237     22   14.98%      13     24
#      703  1551604.200  1824968.851     11    247     24   14.98%      18     25
#      805  1551604.200  1824968.851     11    287     22   14.98%       8     26
# k    833  1713493.100  1824968.851     12    300     20    6.11%       0     27
#      937  1713493.100  1824968.851     12    199      1    6.11%       1     27
# k    950  1717437.100  1824968.851     13    201     23    5.89%       0     27
#     1037  1717437.100  1824968.851     13    177     17    5.89%       8     27
#     1137  1717437.100  1823713.966     13    117     31    5.83%       8     28
#     1237  1717437.100  1817767.116     13     53     15    5.52%       8     29
#     1337  1717437.100  1786961.780     13      9      8    3.89%       8     30
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     10 out of      4803 (ratio: 0.0021)
# Uncrunching matrix
# Final MIP objective                   : 1.717437099999999e+06
# Final MIP bound                       : 1.717438961585055e+06
#   Solution time / primaldual integral :     31.72s/ 45.221334%
#   Number of solutions found / nodes   :        13 /      1347
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2958
# [5, 35, 53, 238, 341, 347, 451, 473, 485, 586, 734, 756, 766, 782, 868, 898, 919, 1030, 1058, 1150, 1278, 1300, 1495, 1694, 1718, 1761, 1883, 2122, 2156, 2196, 2234, 2244, 2288, 2289, 2339, 2372, 2513, 2522, 2525, 2576, 2644, 2694, 2757, 2790, 2830, 2865, 2871, 2875, 2948, 2958]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:20:26, Jul 28, 2023
# Heap usage: 2110MB (peak 2140MB, 97MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8761599 cols        24787 elements   8761599 entities
# Presolved problem has:
#       3777 rows         1325 cols        11312 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3181MB (peak 5716MB, 97MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 2.50e-01,  1.00e+09] / [ 3.05e-05,  2.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.42e+05] / [ 1.00e+00,  4.73e+04]
#   Objective      [min,max] : [ 2.00e+00,  2.20e+06] / [ 2.00e+00,  2.20e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.6GB
#  *** Solution found: -661574.2500   Time:  12.67    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  2176384.0   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 1738 simplex iterations, 0.21s
#    Barrier: 14 barrier and 1722 simplex iterations, 0.56s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       2176384.035      P      0     0        .000000    13
# Barrier solved problem
#   14 barrier and 1722 simplex iterations in 0.91 seconds at time 13
#
# Final objective                       : 2.176384034595202e+06
#   Max primal violation      (abs/rel) : 1.110e-16 / 6.553e-17
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1282287.050  2176384.035      2                 41.08%       0     13
# R         1282293.050  2168382.999      3                 40.86%       0     14
# R         1301097.400  2168382.999      4                 40.00%       0     14
# R         1301191.400  2168382.999      5                 39.99%       0     15
# R         1439115.950  2168382.999      6                 33.63%       0     15
# R         1496042.950  2168382.999      7                 31.01%       0     16
#    1  K   1496042.950  2168382.999      7      1      0   31.01%       8     16
#    2  K   1496042.950  2166349.905      7      2      0   30.94%      15     16
#    3  K   1496042.950  2166224.083      7      1      0   30.94%      19     16
#    4  K   1496042.950  2166129.466      7      1      1   30.93%      17     16
#    5  K   1496042.950  2166129.466      7      0      1   30.93%      21     16
# Heuristic search 'R' started
# R         1613008.750  2166129.466      8                 25.53%       0     16
# R         1613184.750  2166129.466      9                 25.53%       0     16
# R         1613188.750  2166129.466     10                 25.53%       0     17
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 3
# Cut elements in the matrix : 1539
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3256MB (peak 5716MB, 163MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1613188.750  2166103.530     10      2      1   25.53%      21     17
#        2  1613188.750  2166070.257     10      2      3   25.52%      16     18
#        3  1613188.750  2165841.337     10      3      4   25.52%      20     18
#        4  1613188.750  2165781.676     10      4      5   25.51%      19     18
#        5  1613188.750  2165781.676     10      5      6   25.51%      18     18
#        6  1613188.750  2165781.676     10      6      3   25.51%      14     18
#        7  1613188.750  2165179.205     10      6      7   25.49%      18     18
#        8  1613188.750  2165179.205     10      8      6   25.49%      18     19
#        9  1613188.750  2160412.839     10      9      4   25.33%      14     19
#       10  1613188.750  2160412.839     10      9      4   25.33%       8     19
#       20  1613188.750  2145011.937     10     16      5   24.79%      16     19
#       30  1613188.750  2141721.925     10     23      8   24.68%       8     20
#       40  1613188.750  2140140.525     10     29      6   24.62%      21     20
#       50  1613188.750  2140140.525     10     37     17   24.62%      13     20
#       60  1613188.750  2134693.382     10     45     25   24.43%       8     21
#       70  1613188.750  2134693.382     10     55     30   24.43%       8     21
# Will try to keep branch and bound tree memory usage below 48.9GB
#       80  1613188.750  2134693.382     10     59     33   24.43%       8     21
# k     89  1620977.950  2134693.382     11     66     23   24.07%       0     21
#       90  1620977.950  2134693.382     11     66     39   24.07%       8     21
# Elapsed time (sec): 21, estimated tree completion: 0.13192
# Heap usage: 5546MB (peak 5716MB, 163MB system)
# B&B tree size: 349k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      100  1620977.950  2134693.382     11     69     26   24.07%       8     22
# a    126  1624685.950  2132755.449     12     80     37   23.82%       0     22
# *    152  1747767.950  2131754.664     13     78     36   18.01%       0     23
# *    159  1770546.150  2131754.664     14    101     17   16.94%       0     24
# Will try to keep branch and bound tree memory usage below 45.7GB
#      202  1770546.150  2131754.664     14    113     17   16.94%       8     25
# k    259  1857267.400  2131754.664     15    136     32   12.88%       0     26
# *    259  1857319.400  2131754.664     16    136     32   12.87%       0     26
#      304  1857319.400  2131754.664     16    129     27   12.87%       8     27
#      404  1857319.400  2131640.050     16    112     17   12.87%      14     28
# a    456  1976594.100  2124470.133     17    103     23    6.96%       0     29
#      504  1976594.100  2124470.133     17     65      8    6.96%      13     29
#      606  1976594.100  2123447.190     17     39     17    6.92%      28     29
#      706  1976594.100  2081894.919     17      7      9    5.06%      14     31
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      4 out of      2889 (ratio: 0.0014)
# Uncrunching matrix
# Final MIP objective                   : 1.976594100000002e+06
# Final MIP bound                       : 1.976596276384037e+06
#   Solution time / primaldual integral :     33.92s/ 52.181741%
#   Number of solutions found / nodes   :        17 /       717
#   Max primal violation      (abs/rel) : 6.097e-11 / 3.638e-12
#   Max integer violation     (abs    ) : 3.638e-12
# 2992
# [8, 47, 71, 100, 136, 181, 186, 334, 421, 428, 440, 525, 585, 589, 610, 899, 1100, 1122, 1124, 1161, 1288, 1362, 1440, 1469, 1642, 1652, 1725, 1807, 1813, 1896, 1911, 1961, 2004, 2125, 2249, 2290, 2458, 2472, 2496, 2552, 2596, 2621, 2629, 2675, 2700, 2736, 2788, 2791, 2827, 2992]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:22:51, Jul 28, 2023
# Heap usage: 2212MB (peak 2212MB, 100MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8964035 cols        24790 elements   8964035 entities
# Presolved problem has:
#       3777 rows         1325 cols        11315 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3361MB (peak 5809MB, 100MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.40e-01,  1.00e+09] / [ 3.05e-05,  1.98e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.92e+05] / [ 1.00e+00,  3.82e+04]
#   Objective      [min,max] : [ 2.00e+00,  2.17e+06] / [ 2.00e+00,  2.17e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.3GB
#  *** Solution found:  201700.4000   Time:  13.09    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  1863629.1   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 2173 simplex iterations, 0.17s
#    Barrier: 14 barrier and 1647 simplex iterations, 0.56s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       1863629.080      P      0     0        .000000    14
# Barrier solved problem
#   14 barrier and 1647 simplex iterations in 0.98 seconds at time 14
#
# Final objective                       : 1.863629079949128e+06
#   Max primal violation      (abs/rel) : 6.939e-17 / 6.797e-17
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1383577.700  1857945.473      2                 25.53%       0     14
# R         1510380.900  1857945.473      3                 18.71%       0     15
#    1  K   1510380.900  1857945.473      3      1      0   18.71%      13     15
#    2  K   1510380.900  1857945.473      3      0      0   18.71%      15     15
# Heuristic search 'R' started
# R         1578586.350  1857945.473      4                 15.04%       0     15
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 1
# Cut elements in the matrix : 313
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3437MB (peak 5809MB, 167MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1578586.350  1855517.539      4      2      1   14.92%      15     16
#        2  1578586.350  1853256.710      4      2      3   14.82%      17     16
#        3  1578586.350  1853256.710      4      3      3   14.82%      17     17
#        4  1578586.350  1853256.710      4      2      4   14.82%      16     17
#        5  1578586.350  1853256.710      4      3      5   14.82%      18     17
#        6  1578586.350  1853256.710      4      4      3   14.82%      14     17
#        7  1578586.350  1853256.710      4      4      6   14.82%      18     17
#        8  1578586.350  1853256.710      4      5      6   14.82%      13     17
#        9  1578586.350  1853256.710      4      6      5   14.82%      22     17
#       10  1578586.350  1846838.601      4      8      7   14.52%       8     18
# k     17  1798368.100  1846838.601      5     11      4    2.62%       0     18
#       22  1798368.100  1846381.151      5      8      1    2.60%       1     18
# E     26  1800890.100  1844286.753      6     13      7    2.35%       0     19
#       32  1800890.100  1844286.753      6     10      6    2.35%      22     19
# Will try to keep branch and bound tree memory usage below 47.4GB
#       42  1800890.100  1841359.196      6      4      8    2.20%      18     20
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 1.800890100000001e+06
# Final MIP bound                       : 1.800891963629081e+06
#   Solution time / primaldual integral :     21.36s/ 71.453128%
#   Number of solutions found / nodes   :         6 /        51
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2992
# [1495, 1642, 1652, 1694, 1718, 1725, 1761, 1807, 1813, 1883, 1896, 1911, 1961, 2004, 2122, 2125, 2156, 2196, 2234, 2244, 2249, 2288, 2289, 2290, 2339, 2458, 2472, 2496, 2522, 2525, 2552, 2576, 2621, 2629, 2675, 2694, 2700, 2736, 2757, 2788, 2790, 2791, 2827, 2830, 2865, 2871, 2875, 2948, 2958, 2992]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:25:03, Jul 28, 2023
# Heap usage: 2212MB (peak 2212MB, 100MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8964035 cols        24792 elements   8964035 entities
# Presolved problem has:
#       3777 rows         1325 cols        11317 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3361MB (peak 5809MB, 100MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 2.20e-01,  1.00e+09] / [ 3.05e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.53e+05] / [ 1.00e+00,  4.43e+04]
#   Objective      [min,max] : [ 2.00e+00,  2.20e+06] / [ 2.00e+00,  2.20e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.3GB
#  *** Solution found: -1217892.000   Time:  13.11    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  2166247.9   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 1379 simplex iterations, 0.16s
#    Barrier: 16 barrier and 1551 simplex iterations, 0.55s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       2166247.868      P      0     0        .000000    14
# Barrier solved problem
#   16 barrier and 1551 simplex iterations in 0.96 seconds at time 14
#
# Final objective                       : 2.166247868427519e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1276721.700  2166247.868      2                 41.06%       0     14
# k         1277100.700  2163258.017      3                 40.96%       0     14
# R         1398272.650  2163258.017      4                 35.36%       0     15
#    1  K   1398272.650  2163258.017      4      2      0   35.36%      13     15
#    2  K   1398272.650  2161545.255      4      4      0   35.31%      25     15
#    3  K   1398272.650  2160625.538      4      2      3   35.28%      32     15
#    4  K   1398272.650  2157221.755      4      6      0   35.18%      42     15
#    5  K   1398272.650  2156938.732      4      2      5   35.17%      38     15
#    6  K   1398272.650  2156637.918      4      2      4   35.16%      32     15
#    7  K   1398272.650  2156635.577      4      1      2   35.16%      32     15
#    8  K   1398272.650  2156635.577      4      0      0   35.16%      35     15
# Heuristic search 'R' started
# R         1548857.850  2156635.577      5                 28.18%       0     15
# R         1563886.850  2156635.577      6                 27.48%       0     16
# R         1607097.600  2156635.577      7                 25.48%       0     16
# R         1734796.700  2156635.577      8                 19.56%       0     16
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 5
# Cut elements in the matrix : 5047
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3439MB (peak 5809MB, 167MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1734796.700  2156301.097      8      2      1   19.55%      35     17
#        2  1734796.700  2155726.825      8      2      3   19.53%      18     18
#        3  1734796.700  2154397.251      8      3      4   19.48%      13     18
#        4  1734796.700  2152539.070      8      4      4   19.41%      11     19
#        5  1734796.700  2152539.070      8      4      5   19.41%      20     19
#        6  1734796.700  2152539.070      8      4      3   19.41%      11     19
#        7  1734796.700  2144436.370      8      6      6   19.10%      19     19
#        8  1734796.700  2144436.370      8      6      4   19.10%      11     19
#        9  1734796.700  2144436.370      8      7      5   19.10%      16     19
#       10  1734796.700  2144436.370      8      9      5   19.10%      11     20
#       20  1734796.700  2140593.704      8     19      7   18.96%      21     21
#       35  1734796.700  2135334.134      8     24     17   18.76%       8     21
#       47  1734796.700  2135334.134      8     38     27   18.76%      11     21
#       57  1734796.700  2135334.134      8     46     17   18.76%      18     22
#       67  1734796.700  2127920.250      8     49     16   18.47%       8     22
#       77  1734796.700  2127920.250      8     54      8   18.47%      13     22
# k     87  1790913.850  2127920.250      9     57     25   15.84%       0     23
#       88  1790913.850  2127920.250      9     57     25   15.84%       1     23
#       99  1790913.850  2127920.250      9     61     19   15.84%       8     23
# Elapsed time (sec): 24, estimated tree completion: 0.10624
# Heap usage: 6266MB (peak 6266MB, 167MB system)
# B&B tree size: 458k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      110  1790913.850  2127920.250      9     66     10   15.84%      13     24
# Will try to keep branch and bound tree memory usage below 45.8GB
#      212  1790913.850  2122138.773      9    109     12   15.61%       8     26
# *    222  1831007.200  2122138.773     10    108     16   13.72%       0     26
# k    278  1986739.000  2121951.432     11    134     24    6.37%       0     27
#      331  1986739.000  2121951.432     11     88      1    6.37%       1     27
#      431  1986739.000  2121951.432     11     80     12    6.37%       8     28
#      534  1986739.000  2120191.207     11     13     10    6.29%      14     29
# E    548  1995999.600  2117434.389     12     11     14    5.73%       0     29
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      5 out of      2544 (ratio: 0.0020)
# Uncrunching matrix
# Final MIP objective                   : 1.995999600009156e+06
# Final MIP bound                       : 1.996001766257024e+06
#   Solution time / primaldual integral :     32.30s/ 53.517444%
#   Number of solutions found / nodes   :        12 /       563
#   Max primal violation      (abs/rel) : 8.487e-08 / 1.908e-10
#   Max integer violation     (abs    ) : 3.311e-10
# 2705
# [28, 56, 60, 65, 78, 90, 94, 118, 135, 189, 195, 318, 320, 354, 412, 416, 483, 533, 562, 594, 671, 768, 798, 825, 827, 852, 932, 954, 959, 963, 968, 1004, 1024, 1089, 1155, 1189, 1225, 1259, 1324, 1325, 1395, 1420, 1581, 1647, 2260, 2286, 2465, 2575, 2617, 2705]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:27:17, Jul 28, 2023
# Heap usage: 1804MB (peak 1804MB, 81MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      7327848 cols        24787 elements   7327848 entities
# Presolved problem has:
#       3777 rows         1325 cols        11312 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 10 seconds
# Heap usage: 2738MB (peak 4757MB, 81MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.20e-01,  1.00e+09] / [ 3.05e-05,  1.98e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.95e+05] / [ 1.00e+00,  3.83e+04]
#   Objective      [min,max] : [ 1.00e+00,  2.23e+06] / [ 1.00e+00,  2.23e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 52.9GB
#  *** Solution found: -2234276.600   Time:  10.43    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  11s
#             Dual                      Barrier
#     objective   sum inf
#  P  1899331.2   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1266 simplex iterations, 0.09s
#    Barrier: 13 barrier and 1571 simplex iterations, 0.47s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1266       1899331.238      P      0     0        .000000    11
# Dual solved problem
#   1266 simplex iterations in 0.73 seconds at time 11
#
# Final objective                       : 1.899331238042382e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 1.281e-05 / 1.281e-05
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a        -1854875.000  1899331.238      2               3.75e+06       0     11
# k         365725.0000  1899331.238      3                 80.74%       0     11
#    1  K   365725.0000  1899331.238      3      0      0   80.74%       6     11
# Heuristic search 'R' started
# R         1656963.500  1899331.238      4                 12.76%       0     12
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 2801MB (peak 4757MB, 136MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1656963.500  1899293.050      4      2      1   12.76%       6     12
#        2  1656963.500  1899293.050      4      2      3   12.76%       6     12
#        3  1656963.500  1899293.050      4      3      4   12.76%       8     13
#        4  1656963.500  1899293.050      4      4      4   12.76%       6     14
#        5  1656963.500  1899293.050      4      4      5   12.76%      14     14
#        6  1656963.500  1895910.540      4      6      3   12.60%       6     14
#        7  1656963.500  1892545.398      4      7      4   12.45%       6     14
#        8  1656963.500  1892545.398      4      6      6   12.45%      14     14
#        9  1656963.500  1892545.398      4      7      3   12.45%       6     14
#       10  1656963.500  1874684.302      4      6      7   11.61%       8     14
#       20  1656963.500  1871412.415      4     13      7   11.46%       6     15
#       30  1656963.500  1863524.077      4     18     17   11.08%       8     16
# k     40  1704153.000  1863524.077      5     24     14    8.55%       0     16
#       40  1704153.000  1863524.077      5     24      9    8.55%       9     16
# k     43  1716913.000  1863524.077      6     28     17    7.87%       0     17
#       50  1716913.000  1863524.077      6     25     18    7.87%       8     17
#       60  1716913.000  1863524.077      6     25     19    7.87%       8     18
#       70  1716913.000  1863524.077      6     26     12    7.87%       8     19
# k     80  1759046.350  1863524.077      7     28     14    5.61%       0     19
# Will try to keep branch and bound tree memory usage below 47.0GB
# Elapsed time (sec): 19, estimated tree completion: 0.69294
# Heap usage: 6791MB (peak 6791MB, 137MB system)
# B&B tree size: 305k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#       81  1759046.350  1863524.077      7     28     14    5.61%       1     19
#       91  1759046.350  1863524.077      7     20     12    5.61%      13     20
#      101  1759046.350  1863524.077      7     16      8    5.61%       8     20
# k    196  1783006.700  1858412.635      8      7     13    4.06%       0     21
#      201  1783006.700  1858412.635      8      5     11    4.06%      14     21
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      1 out of      1093 (ratio: 0.0009)
# Uncrunching matrix
# Final MIP objective                   : 1.783006700000020e+06
# Final MIP bound                       : 1.783008599331258e+06
#   Solution time / primaldual integral :     23.35s/ 55.597840%
#   Number of solutions found / nodes   :         8 /       205
#   Max primal violation      (abs/rel) : 3.471e-12 / 2.755e-12
#   Max integer violation     (abs    ) : 3.471e-12
# 2965
# [28, 56, 78, 90, 94, 118, 135, 320, 354, 594, 671, 768, 825, 827, 852, 932, 954, 959, 1004, 1225, 1259, 1325, 1658, 1685, 1693, 1710, 1714, 1787, 1867, 1923, 2017, 2059, 2060, 2082, 2088, 2159, 2161, 2212, 2235, 2238, 2301, 2338, 2465, 2507, 2617, 2627, 2705, 2820, 2921, 2965]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:29:19, Jul 28, 2023
# Heap usage: 2119MB (peak 2149MB, 98MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8803088 cols        24783 elements   8803088 entities
# Presolved problem has:
#       3777 rows         1325 cols        11308 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3194MB (peak 5739MB, 98MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 2.10e-01,  1.00e+09] / [ 3.05e-05,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.98e+05] / [ 1.00e+00,  3.99e+04]
#   Objective      [min,max] : [ 2.00e+00,  2.11e+06] / [ 2.00e+00,  2.11e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.5GB
#  *** Solution found: -950812.8000   Time:  13.00    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  1971839.8   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 2174 simplex iterations, 0.12s
#    Barrier: 14 barrier and 1610 simplex iterations, 0.54s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   2174       1971839.831      P      0     0        .000000    13
# Dual solved problem
#   2174 simplex iterations in 0.82 seconds at time 13
#
# Final objective                       : 1.971839831003265e+06
#   Max primal violation      (abs/rel) : 2.274e-13 / 2.274e-13
#   Max dual violation        (abs/rel) : 9.095e-13 / 9.095e-13
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1876458.300  1971839.831      2                  4.84%       0     14
#    1  K   1876458.300  1971839.831      2      0      0    4.84%       8     14
# Heuristic search 'R' started
# R         1878423.300  1971839.831      3                  4.74%       0     14
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3268MB (peak 5739MB, 164MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1878423.300  1970853.332      3      2      1    4.69%       8     15
#        2  1878423.300  1970853.332      3      2      3    4.69%       8     15
#        3  1878423.300  1970186.902      3      3      4    4.66%       8     15
#        4  1878423.300  1970099.017      3      4      5    4.65%       8     15
#        5  1878423.300  1968745.550      3      5      6    4.59%       8     15
#        6  1878423.300  1968202.319      3      6      7    4.56%       8     15
#        7  1878423.300  1968202.319      3      7      8    4.56%       8     15
#        8  1878423.300  1968202.319      3      8      9    4.56%       8     15
#        9  1878423.300  1968202.319      3      9     10    4.56%       8     15
#       10  1878423.300  1968202.319      3     10     11    4.56%       8     15
#       20  1878423.300  1964774.927      3     11      8    4.39%       8     16
#       30  1878423.300  1964774.927      3      5      3    4.39%      14     16
#       40  1878423.300  1956838.544      3      3      6    4.01%       8     16
# Will try to keep branch and bound tree memory usage below 48.5GB
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 1.878423300000000e+06
# Final MIP bound                       : 1.878425271839831e+06
#   Solution time / primaldual integral :     17.73s/ 80.879490%
#   Number of solutions found / nodes   :         3 /        43
#   Max primal violation      (abs/rel) : 9.992e-07 / 1.388e-15
#   Max integer violation     (abs    ) : 2.665e-14
# 2974
# [60, 65, 189, 195, 318, 412, 416, 483, 533, 562, 798, 963, 968, 1024, 1089, 1155, 1189, 1324, 1395, 1420, 1493, 1513, 1518, 1540, 1542, 1581, 1647, 1732, 1777, 1783, 1864, 2020, 2108, 2205, 2208, 2260, 2286, 2318, 2364, 2373, 2514, 2563, 2575, 2579, 2686, 2712, 2765, 2844, 2850, 2974]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:31:26, Jul 28, 2023
# Heap usage: 2189MB (peak 2189MB, 98MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8856575 cols        24787 elements   8856575 entities
# Presolved problem has:
#       3777 rows         1325 cols        11312 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3328MB (peak 5751MB, 98MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+09] / [ 3.05e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.14e+05] / [ 1.00e+00,  4.18e+04]
#   Objective      [min,max] : [ 1.00e+00,  2.04e+06] / [ 1.00e+00,  2.04e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.3GB
#  *** Solution found: -22560.25000   Time:  12.74    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  1904293.8   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1338 simplex iterations, 0.12s
#    Barrier: 14 barrier and 1625 simplex iterations, 0.56s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1338       1904293.840      P      0     0        .000000    13
# Dual solved problem
#   1338 simplex iterations in 0.90 seconds at time 13
#
# Final objective                       : 1.904293840186660e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1635763.700  1904293.840      2                 14.10%       0     14
#    1  K   1635763.700  1904293.840      2      0      0   14.10%       8     14
# Heuristic search 'R' started
# R         1653457.700  1904293.840      3                 13.17%       0     14
# R         1836364.400  1904293.840      4                  3.57%       0     14
# Heuristic search 'R' stopped
#
# Performing root presolve...
#
# Reduced problem has:     262 rows     104 columns       780 elements
# Presolve dropped   :    3515 rows    1221 columns     10532 elements
# Presolve tightened :        30 elements
# Will try to keep branch and bound tree memory usage below 50.7GB
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1534       1904293.840      P      0     0        .000000    16
# Optimal solution found
# Dual solved problem
#   1534 simplex iterations in 0.00 seconds at time 16
#
# Final objective                       : 1.904293840186650e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
#    1  K   1836364.400  1904293.840      4      0      0    3.57%       8     17
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3402MB (peak 5751MB, 165MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1836364.400  1904281.112      4      2      1    3.57%       8     17
#        2  1836364.400  1904281.112      4      2      3    3.57%       8     17
#        3  1836364.400  1904281.112      4      2      3    3.57%       8     17
#        4  1836364.400  1904281.112      4      2      4    3.57%       8     17
#        5  1836364.400  1904281.112      4      2      4    3.57%       8     17
#        6  1836364.400  1904281.112      4      2      5    3.57%      13     17
#        7  1836364.400  1903653.666      4      5      4    3.53%      15     17
#        8  1836364.400  1903486.035      4      6      6    3.53%       8     17
#        9  1836364.400  1903486.035      4      6      4    3.53%       8     17
#       10  1836364.400  1903486.035      4      6      7    3.53%      14     17
#       20  1836364.400  1903486.035      4      3      6    3.53%       8     18
#       30  1836364.400  1900345.352      4      4      6    3.37%      14     18
# Will try to keep branch and bound tree memory usage below 47.8GB
# *     36  1843748.900  1900345.352      5      2      7    2.98%       0     18
#       46  1843748.900  1900345.352      5      1      9    2.98%       8     18
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      2 out of       326 (ratio: 0.0061)
# Uncrunching matrix
# Final MIP objective                   : 1.843748899999994e+06
# Final MIP bound                       : 1.843750804293835e+06
#   Solution time / primaldual integral :     19.59s/ 72.905819%
#   Number of solutions found / nodes   :         5 /        49
#   Max primal violation      (abs/rel) : 4.026e-06 / 6.178e-11
#   Max integer violation     (abs    ) : 6.178e-11
# 2974
# [1493, 1513, 1518, 1540, 1542, 1658, 1685, 1693, 1710, 1714, 1732, 1777, 1783, 1787, 1864, 1867, 1923, 2017, 2020, 2059, 2060, 2082, 2088, 2108, 2159, 2161, 2205, 2208, 2212, 2235, 2238, 2301, 2318, 2338, 2364, 2373, 2507, 2514, 2563, 2579, 2627, 2686, 2712, 2765, 2820, 2844, 2850, 2921, 2965, 2974]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 20:33:36, Jul 28, 2023
# Heap usage: 2189MB (peak 2189MB, 98MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8856575 cols        24786 elements   8856575 entities
# Presolved problem has:
#       3777 rows         1325 cols        11311 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3328MB (peak 5751MB, 98MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+09] / [ 3.05e-05,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.18e+05] / [ 1.00e+00,  4.25e+04]
#   Objective      [min,max] : [ 5.00e+00,  2.00e+06] / [ 5.00e+00,  2.00e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.3GB
#  *** Solution found: -113555.5000   Time:  12.73    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   sum inf
#  P  1938039.4   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1489 simplex iterations, 0.12s
#    Barrier: 14 barrier and 1540 simplex iterations, 0.56s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1489       1938039.418      P      0     0        .000000    13
# Dual solved problem
#   1489 simplex iterations in 0.90 seconds at time 13
#
# Final objective                       : 1.938039418452997e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# g         1367700.400  1938039.418      2                 29.43%       0     14
# q         1368144.400  1938039.418      3                 29.41%       0     14
# R         1370076.400  1933712.032      4                 29.15%       0     14
# R         1451132.350  1933712.032      5                 24.96%       0     15
#    1  K   1451132.350  1933712.032      5      2      0   24.96%      11     15
#    2  K   1451132.350  1932689.816      5      3      1   24.92%      23     15
#    3  K   1451132.350  1930925.539      5      4      2   24.85%      22     15
#    4  K   1451132.350  1930461.528      5      3      3   24.83%      23     16
#    5  K   1451132.350  1930461.522      5      1      3   24.83%      21     16
#    6  K   1451132.350  1930461.462      5      1      0   24.83%      21     16
#    7  K   1451132.350  1930461.462      5      0      0   24.83%      21     16
# Heuristic search 'R' started
# R         1690875.700  1930461.462      6                 12.41%       0     16
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 5
# Cut elements in the matrix : 2993
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3403MB (peak 5751MB, 165MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1690875.700  1930449.882      6      2      1   12.41%      21     17
#        2  1690875.700  1930357.363      6      2      3   12.41%      16     18
#        3  1690875.700  1930121.301      6      3      4   12.40%      11     18
#        4  1690875.700  1930121.301      6      4      5   12.40%      11     18
#        5  1690875.700  1930121.301      6      5      6   12.40%       8     18
#        6  1690875.700  1930121.301      6      6      5   12.40%      16     18
#        7  1690875.700  1930121.301      6      6      3   12.40%      13     18
#        8  1690875.700  1930121.301      6      7      4   12.40%       8     19
#        9  1690875.700  1930121.301      6      8      5   12.40%       8     19
#       10  1690875.700  1930121.301      6      9      6   12.40%       8     19
# k     11  1734543.200  1930121.301      7     11      7   10.13%       0     19
#       20  1734543.200  1925061.441      7     15      5    9.90%      16     20
#       30  1734543.200  1924979.179      7     20      9    9.89%      13     20
#       40  1734543.200  1920499.337      7     24     17    9.68%       8     21
# Will try to keep branch and bound tree memory usage below 48.4GB
#       50  1734543.200  1920499.337      7     27     15    9.68%       8     22
#       60  1734543.200  1920499.337      7     30      8    9.68%       8     22
#       70  1734543.200  1920499.337      7     32      8    9.68%       8     22
#       80  1734543.200  1909608.526      7     36     14    9.17%      15     23
# ...
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.7GB
#  *** Solution found: -2582750.000   Time:  12.07    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  12s
#             Dual                      Barrier
#     objective   sum inf
#  P  2272114.5   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 770 simplex iterations, 0.05s
#    Barrier: 14 barrier and 284 simplex iterations, 0.47s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#    770       2272114.508      P      0     0        .000000    12
# Dual solved problem
#   770 simplex iterations in 0.74 seconds at time 12
#
# Final objective                       : 2.272114508339440e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 2.328e-10 / 2.328e-10
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# a        -2316785.000  2272114.508      2               4.59e+06       0     13
# q         1215397.600  2272114.508      3                 46.51%       0     13
# k         1835230.000  2272114.508      4                 19.23%       0     13
#    1  K   1835230.000  2266765.960      4      1      0   19.04%      13     14
#    2  K   1835230.000  2266765.960      4      0      0   19.04%      13     14
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 1
# Cut elements in the matrix : 331
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3146MB (peak 5525MB, 157MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1835230.000  2266701.261      4      2      1   19.04%      13     14
#        2  1835230.000  2266084.371      4      2      3   19.01%      20     15
#        3  1835230.000  2266084.371      4      2      3   19.01%       8     15
#        4  1835230.000  2266084.371      4      3      4   19.01%      19     15
#        5  1835230.000  2266084.371      4      4      4   19.01%       8     15
#        6  1835230.000  2262317.764      4      6      4   18.88%       8     16
#        7  1835230.000  2261649.431      4      7      5   18.85%      14     16
#        8  1835230.000  2261649.431      4      7      5   18.85%      11     16
#        9  1835230.000  2261649.431      4      7      5   18.85%      13     16
#       10  1835230.000  2261649.431      4      7      5   18.85%      35     16
# k     18  2128712.100  2260009.977      5     14      5    5.81%       0     17
#       20  2128712.100  2260009.977      5     14      5    5.81%       8     17
# k     28  2130466.100  2257904.919      6     16      8    5.64%       0     17
#       30  2130466.100  2257904.919      6     15      7    5.64%       8     18
# Will try to keep branch and bound tree memory usage below 48.9GB
#       40  2130466.100  2253539.951      6     19      6    5.46%       8     18
# k     42  2140217.900  2253539.951      7     19      9    5.03%       0     18
# k     44  2140373.900  2253539.951      8     19     10    5.02%       0     19
#       50  2140373.900  2253539.951      8     15      7    5.02%       8     19
# *     50  2210059.400  2239906.786      9     16      4    1.33%       0     19
# Elapsed time (sec): 20, estimated tree completion: 0.50570
# Heap usage: 6357MB (peak 6357MB, 157MB system)
# B&B tree size: 0.5MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#       60  2210059.400  2239906.786      9     11      7    1.33%       8     20
#       70  2210059.400  2239906.786      9      6      5    1.33%       8     20
#       80  2210059.400  2239906.786      9      4      6    1.33%       8     20
#  *** Search completed ***
# Uncrunching matrix
# Final MIP objective                   : 2.210059399999999e+06
# Final MIP bound                       : 2.210061672114507e+06
#   Solution time / primaldual integral :     21.76s/ 66.115538%
#   Number of solutions found / nodes   :         9 /        87
#   Max primal violation      (abs/rel) : 3.638e-12 / 3.638e-12
#   Max integer violation     (abs    ) : 3.638e-12
# 2922
# [106, 184, 369, 388, 414, 443, 456, 625, 635, 693, 740, 858, 875, 902, 946, 1062, 1181, 1269, 1290, 1323, 1326, 1506, 1530, 1572, 1611, 1654, 1667, 1744, 1805, 1927, 1949, 1999, 2016, 2050, 2074, 2116, 2194, 2291, 2347, 2461, 2520, 2613, 2660, 2741, 2775, 2834, 2861, 2867, 2902, 2922]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 21:38:40, Jul 28, 2023
# Heap usage: 2065MB (peak 2094MB, 95MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8549775 cols        24792 elements   8549775 entities
# Presolved problem has:
#       3777 rows         1325 cols        11317 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 11 seconds
# Heap usage: 3116MB (peak 5599MB, 95MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 6.00e-01,  1.00e+09] / [ 3.05e-05,  1.98e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.94e+05] / [ 1.00e+00,  3.96e+04]
#   Objective      [min,max] : [ 3.00e+00,  2.05e+06] / [ 3.00e+00,  2.05e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.6GB
#  *** Solution found: -151553.4000   Time:  12.27    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  12s
#             Dual                      Barrier
#     objective   sum inf
#  P  1896927.6   .0000000 |
# ------- optimal -------- | ----- interrupted ------
# Concurrent statistics:
#       Dual: 1174 simplex iterations, 0.12s
#    Barrier: 14 barrier and 1629 simplex iterations, 0.54s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#   1174       1896927.596      P      0     0        .000000    13
# Dual solved problem
#   1174 simplex iterations in 0.81 seconds at time 13
#
# Final objective                       : 1.896927595519705e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         1754055.550  1896927.596      2                  7.53%       0     13
#    1  K   1754055.550  1896927.596      2      0      0    7.53%       8     13
# Heuristic search 'R' started
# R         1759110.550  1896927.596      3                  7.27%       0     13
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3188MB (peak 5599MB, 159MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1759110.550  1896866.951      3      2      1    7.26%       8     14
#        2  1759110.550  1896866.951      3      2      3    7.26%       8     14
#        3  1759110.550  1896055.092      3      3      4    7.22%       8     14
#        4  1759110.550  1895651.120      3      4      4    7.20%       8     14
#        5  1759110.550  1895651.120      3      5      5    7.20%       8     14
#        6  1759110.550  1895651.120      3      6      5    7.20%      13     14
#        7  1759110.550  1893564.280      3      7      6    7.10%      14     14
#        8  1759110.550  1893564.280      3      8      7    7.10%      14     14
#        9  1759110.550  1893564.280      3      9      8    7.10%      14     14
#       10  1759110.550  1893564.280      3     10      6    7.10%       8     15
#       20  1759110.550  1892280.057      3     12     13    7.04%      14     16
# Will try to keep branch and bound tree memory usage below 49.0GB
#       30  1759110.550  1892280.057      3      8      6    7.04%       8     16
#       40  1759110.550  1892280.057      3     10     12    7.04%       8     16
#       50  1759110.550  1873530.448      3      7      7    6.11%       8     17
#       61  1759110.550  1873530.448      3      9     12    6.11%       8     17
#       72  1759110.550  1873530.448      3     14      8    6.11%       8     18
#       82  1759110.550  1873530.448      3     13     16    6.11%      18     18
# Will try to keep branch and bound tree memory usage below 46.1GB
#       92  1759110.550  1873530.448      3      7      7    6.11%      18     18
#      102  1759110.550  1864748.512      3      5      4    5.66%       8     18
# Elapsed time (sec): 19, estimated tree completion: 0.90309
# Heap usage: 6944MB (peak 6944MB, 160MB system)
# B&B tree size: 144k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# k    104  1776419.400  1841287.468      4      4      8    3.52%       0     19
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      2 out of       645 (ratio: 0.0031)
# Uncrunching matrix
# Final MIP objective                   : 1.776419399999944e+06
# Final MIP bound                       : 1.776421296927539e+06
#   Solution time / primaldual integral :     21.73s/ 63.814473%
#   Number of solutions found / nodes   :         4 /       117
#   Max primal violation      (abs/rel) : 4.177e-10 / 5.894e-12
#   Max integer violation     (abs    ) : 5.894e-12
# 2922
# [1506, 1538, 1572, 1587, 1611, 1631, 1648, 1667, 1692, 1744, 1760, 1805, 1838, 1927, 1946, 1949, 1994, 1999, 2016, 2050, 2074, 2116, 2164, 2194, 2200, 2228, 2231, 2291, 2325, 2347, 2461, 2462, 2479, 2487, 2498, 2520, 2545, 2613, 2660, 2741, 2773, 2775, 2807, 2843, 2846, 2853, 2861, 2867, 2899, 2922]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 21:40:48, Jul 28, 2023
# Heap usage: 2065MB (peak 2094MB, 95MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#       9902 rows      8549775 cols        24794 elements   8549775 entities
# Presolved problem has:
#       3777 rows         1325 cols        11319 elements      1325 entities
# LP relaxation tightened
# Presolve finished in 11 seconds
# Heap usage: 3116MB (peak 5599MB, 95MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 4.10e-01,  1.00e+09] / [ 3.05e-05,  1.93e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  2.06e+05] / [ 1.00e+00,  3.98e+04]
#   Objective      [min,max] : [ 3.00e+00,  2.29e+06] / [ 3.00e+00,  2.29e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.6GB
#  *** Solution found: -782164.5000   Time:  12.21    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  12s
#             Dual                      Barrier
#                                objective   sum inf
#                          |  P  1940989.1   .0000000
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 1246 simplex iterations, 0.14s
#    Barrier: 12 barrier and 1639 simplex iterations, 0.53s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       1940989.149      P      0     0        .000000    13
# Barrier solved problem
#   12 barrier and 1639 simplex iterations in 0.88 seconds at time 13
#
# Final objective                       : 1.940989148790994e+06
#   Max primal violation      (abs/rel) : 1.819e-12 / 1.819e-12
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         184698.0000  1940989.149      2                 90.48%       0     13
#    1  K   184698.0000  1940989.149      2      0      0   90.48%       6     13
# Heuristic search 'R' started
# R         191880.0000  1940989.149      3                 90.11%       0     13
# R         477055.3000  1940989.149      4                 75.42%       0     14
# R         499261.1000  1940989.149      5                 74.28%       0     14
# R         1373992.100  1940989.149      6                 29.21%       0     14
# R         1573740.300  1940989.149      7                 18.92%       0     15
# R         1699885.800  1940989.149      8                 12.42%       0     15
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3188MB (peak 5599MB, 159MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  1699885.800  1937860.277      8      2      1   12.28%       6     15
#        2  1699885.800  1937811.432      8      2      3   12.28%       6     16
#        3  1699885.800  1936335.322      8      3      4   12.21%      10     16
#        4  1699885.800  1936335.322      8      4      3   12.21%      10     16
#        5  1699885.800  1936335.322      8      5      5   12.21%      10     16
#        6  1699885.800  1936335.322      8      6      5   12.21%       6     16
#        7  1699885.800  1936335.322      8      7      4   12.21%       6     16
#        8  1699885.800  1936335.322      8      7      4   12.21%      10     16
#       10  1699885.800  1936335.322      8      7      6   12.21%       8     16
#       20  1699885.800  1895666.779      8     11      6   10.33%       8     17
#       30  1699885.800  1889102.360      8     19      9   10.02%      27     17
#       40  1699885.800  1889102.360      8     23     12   10.02%      20     17
#       50  1699885.800  1884766.462      8     26      7    9.81%      13     18
# Will try to keep branch and bound tree memory usage below 46.4GB
#       60  1699885.800  1884332.371      8     22     11    9.79%      28     19
# k     60  1755781.300  1884332.371      9     21     11    6.82%       0     19
#       70  1755781.300  1884332.371      9     25     14    6.82%       8     19
# *     74  1757577.300  1884332.371     10     27     14    6.73%       0     20
#       80  1757577.300  1879946.557     10     24     13    6.51%      13     20
#       91  1757577.300  1877039.224     10     22      9    6.36%      13     20
# Elapsed time (sec): 20, estimated tree completion: 0.82582
# Heap usage: 7270MB (peak 7270MB, 160MB system)
# B&B tree size: 504k total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      101  1757577.300  1877039.224     10     20      7    6.36%       8     20
# k    120  1786275.700  1876787.911     11     15      9    4.82%       0     20
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      2 out of       868 (ratio: 0.0023)
# Uncrunching matrix
# Final MIP objective                   : 1.786275699999906e+06
# Final MIP bound                       : 1.786277640989054e+06
#   Solution time / primaldual integral :     23.03s/ 66.309908%
#   Number of solutions found / nodes   :        11 /       177
#   Max primal violation      (abs/rel) : 3.201e-10 / 3.201e-10
#   Max integer violation     (abs    ) : 3.201e-10

# %%
scores_fi = []
for ele in scores_f:
    scores_fi.append({**ele[0], **ele[1]})

# %% [markdown]
# # the total 50 scores

# %%
scores_finaux = []
sigma_w = []
indices = []
for i in random_index:
    scores_i = []
    sigma_wi = 0
    for ele in Sets_50_sorted:
        if i in ele[0][0][0].keys() or i in ele[1][0][0].keys():
            scores_i.append(scores_fi[Sets_50_sorted.index(ele)][i])
            sigma_wi += 1 
            if i in before_model_50[Sets_50_sorted.index(ele)][0][0].keys():
                scores_i.append(2*scored_50_4[Sets_50_sorted.index(ele)][0][i])
                sigma_wi += 2 
            if i in before_model_50[Sets_50_sorted.index(ele)][1][0].keys():
                scores_i.append(scored_50_4[Sets_50_sorted.index(ele)][1][i])
                sigma_wi += 1 
            if i in before_model_50[Sets_50_sorted.index(ele)][2][0].keys():
                scores_i.append(scored_50_4[Sets_50_sorted.index(ele)][2][i])
                sigma_wi += 1 

        if i in ele[0][1][0].keys() or i in ele[1][1][0].keys():
            scores_i.append(2*scores_fi[Sets_50_sorted.index(ele)][i])
            sigma_wi += 2 
            if i in before_model_50[Sets_50_sorted.index(ele)][1][0].keys():
                scores_i.append(2*scored_50_4[Sets_50_sorted.index(ele)][1][i])
                sigma_wi += 2 
            if i in before_model_50[Sets_50_sorted.index(ele)][2][0].keys():
                scores_i.append(2*scored_50_4[Sets_50_sorted.index(ele)][2][i])
                sigma_wi += 2 
            if i in before_model_50[Sets_50_sorted.index(ele)][3][0].keys():
                scores_i.append(scored_50_4[Sets_50_sorted.index(ele)][3][i]) 
                sigma_wi += 1
    sigma_w.append(sigma_wi)
    indices.append(i)            
    scores_finaux.append((i,scores_i))

# %%
scores_dict = {}
sum_scores = [sum(ele[1]) for ele in scores_finaux]
scores_step_9 = list(np.array(sum_scores)/np.array(sigma_w))
scores_dict = {key: value for key, value in zip(indices, scores_step_9)}

# %% [markdown]
# # Part II: on sets 100

# %%
for st in Set_100:
    index_st = list(st[0].keys())
    vals_st = {}
    for i in index_st:
        vals_st[i] = scores_dict[i]
    st.append(vals_st)

# %% [markdown]
# # Ordering the sets

# %%
for st in Set_100:
    sorted_items = sorted(st[5].items(), key=lambda item: item[1], reverse=True)
    st[5] = dict(sorted_items)  

for st in Set_100:
    index_by_order = st[5].keys()
    a = {}
    b = {}
    c = {}
    d = {}
    e = {}
    for id in index_by_order:
        a[id] = st[0][id]
        b[id] = st[1][id]
        c[id] = st[2][id]
        for id_j in index_by_order:
            d[(id, id_j)] = st[3][(id, id_j)]
        e[id] = st[4][id]
    st[0] = a
    st[1] = b
    st[2] = c
    st[3] = d
    st[4] = e

# %% [markdown]
# # dividing into low/high performing

# %%
high_low_Set_100 = []
for st in Set_100: 
    high_low_Set_100.append(divide_set_by_scores(st, 50))

# %% [markdown]
# # 10-cycle instances

# %%
instance2 = []
instance3 = []
instance4 = []
instance5 = []
high_performing = []
low_performing = []
for st in high_low_Set_100:
    high_performing.append(st[0])
    low_performing.append(st[1])

# %%
high_perfo_indices = []
low_perfo_indices = []

for ele in high_performing:
    key = list(ele[0].keys())
    for i in key:
        high_perfo_indices.append(i)

for ele in low_performing:
    key = list(ele[0].keys())
    for i in key:
        low_perfo_indices.append(i)

# %% [markdown]
# # forming instances

# %%
for i in range(len(high_performing)):
    if i != len(high_performing)-1:
        instance2.append([high_performing[i], high_performing[i+1]])
    else:
        instance2.append([high_performing[len(high_performing)-1], high_performing[0]])

# %%
for i in range(len(low_performing)):
    if i != len(low_performing)-1:
        instance3.append([low_performing[i], low_performing[i+1]])
    else:
        instance3.append([low_performing[len(low_performing)-1], low_performing[0]])

# %%
for i in range(len(high_performing)):
    if i != len(high_performing)-1:
        instance4.append([high_performing[i],low_performing[i+1]])
    else:
        instance4.append([high_performing[len(high_performing)-1], low_performing[0]])

# %%
for i in range(len(high_performing)):
    if i != len(high_performing)-1:
        instance5.append([low_performing[i],high_performing[i+1]])
    else:
        instance5.append([low_performing[len(high_performing)-1], high_performing[0]])

# %% [markdown]
# ## Making instances ready for the model

# %%
instance2_set = []
instance3_set = []
instance4_set = []
instance5_set = []

for ens in instance2:
    two_lis = []
    two_merged = []
    for lis in ens:
        l = lis.copy()
        l.pop()
        two_lis.append(l)
    for i in range(len(two_lis[0])):
        if i != 3:
            a = {**two_lis[0][i],**two_lis[1][i]}
            indices_2 = list(a.keys())
            two_merged.append(a)
        else:
            a = {}
            for ind_i in indices_2:
                for ind_j in indices_2:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)]
            two_merged.append(a)
    instance2_set.append(two_merged)

for ens in instance3:
    two_lis = []
    two_merged = []
    for lis in ens:
        l = lis.copy()
        l.pop()
        two_lis.append(l)
    for i in range(len(two_lis[0])):
        if i != 3:
            a = {**two_lis[0][i],**two_lis[1][i]}
            indices_3 = list(a.keys())
            two_merged.append(a)
        else:
            a = {}
            for ind_i in indices_3:
                for ind_j in indices_3:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)]
            two_merged.append(a)
    instance3_set.append(two_merged)

for ens in instance4:
    two_lis = []
    two_merged = []
    for lis in ens:
        l = lis.copy()
        l.pop()
        two_lis.append(l)
    for i in range(len(two_lis[0])):
        if i != 3:
            a = {**two_lis[0][i],**two_lis[1][i]}
            indices_4 = list(a.keys())
            two_merged.append(a)
        else:
            a = {}
            for ind_i in indices_4:
                for ind_j in indices_4:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)]
            two_merged.append(a)
    instance4_set.append(two_merged)

for ens in instance5:
    two_lis = []
    two_merged = []
    for lis in ens:
        l = lis.copy()
        l.pop()
        two_lis.append(l)
    for i in range(len(two_lis[0])):
        if i != 3:
            a = {**two_lis[0][i],**two_lis[1][i]}
            indices_5 = list(a.keys())
            two_merged.append(a)
        else:
            a = {}
            for ind_i in indices_5:
                for ind_j in indices_5:
                    a[(ind_i, ind_j)] = set_items[3][(ind_i, ind_j)]
            two_merged.append(a)
    instance5_set.append(two_merged)

# %% [markdown]
# ## Entering the model

# %%
scores_instance2 = []
scores_instance3 = []
scores_instance4 = []
scores_instance5 = []

for i in range(len(instance2_set)):
    scores_instance2.append(calculate_score(instance2_set[i]))
    scores_instance3.append(calculate_score(instance3_set[i]))
    scores_instance4.append(calculate_score(instance4_set[i]))
    scores_instance5.append(calculate_score(instance5_set[i]))
# Out:
# 2992
# [28, 35, 53, 56, 78, 90, 94, 118, 135, 238, 320, 341, 347, 354, 451, 473, 485, 533, 586, 594, 756, 766, 768, 782, 825, 827, 852, 868, 898, 919, 932, 954, 959, 1004, 1030, 1100, 1122, 1150, 1225, 1259, 1278, 1300, 1325, 1362, 1493, 1513, 1540, 1542, 1642, 1652, 1725, 1732, 1777, 1783, 1807, 1813, 1961, 2004, 2020, 2108, 2125, 2205, 2208, 2212, 2249, 2260, 2286, 2290, 2318, 2372, 2373, 2458, 2465, 2472, 2496, 2513, 2514, 2552, 2563, 2575, 2579, 2596, 2617, 2621, 2629, 2644, 2675, 2686, 2700, 2705, 2712, 2736, 2765, 2788, 2790, 2791, 2827, 2850, 2974, 2992]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 22:20:57, Jul 28, 2023
# Heap usage: 2221MB (peak 2221MB, 106MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      8964035 cols        99539 elements   8964035 entities
# Presolved problem has:
#      15052 rows         5150 cols        45089 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 13 seconds
# Heap usage: 3372MB (peak 5830MB, 106MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.20e-01,  1.00e+09] / [ 1.53e-05,  1.94e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.01e+05] / [ 1.00e+00,  8.36e+04]
#   Objective      [min,max] : [ 2.00e+00,  4.46e+06] / [ 2.00e+00,  4.46e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.0GB
#  *** Solution found: -544319.7500   Time:  14.17    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  14s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4541793.5   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 4663 simplex iterations, 1.04s
#    Barrier: 13 barrier and 6742 simplex iterations, 1.04s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       4180000.000      P      0     0        .000000    15
# Barrier solved problem
#   13 barrier and 6742 simplex iterations in 1.47 seconds at time 15
#
# Final objective                       : 4.179999999999996e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) : 7.276e-12 / 7.276e-12
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# R         3783520.000  4180000.000      2                  9.49%       0     16
# R         3991060.000  4180000.000      3                  4.52%       0     16
# R         4081949.200  4180000.000      4                  2.35%       0     17
# R         4082177.650  4180000.000      5                  2.34%       0     17
#    1  K   4082177.650  4180000.000      5      4      0    2.34%      16     17
#    2  K   4082177.650  4180000.000      5      0      0    2.34%      16     17
#    3  G   4082177.650  4180000.000      5      0      0    2.34%      16     17
# Heuristic search 'R' started
# R         4086325.250  4180000.000      6                  2.24%       0     18
# R         4152422.300  4180000.000      7                  0.66%       0     18
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 4
# Cut elements in the matrix : 24
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3463MB (peak 5830MB, 174MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  4152422.300  4180000.000      7      2      1    0.66%      16     19
#        2  4152422.300  4180000.000      7      2      3    0.66%       8     20
#        3  4152422.300  4180000.000      7      3      4    0.66%       8     20
#        4  4152422.300  4180000.000      7      4      3    0.66%      11     20
#        5  4152422.300  4180000.000      7      5      4    0.66%       6     20
#        6  4152422.300  4180000.000      7      6      4    0.66%       8     20
#        7  4152422.300  4180000.000      7      6      5    0.66%       8     20
#        8  4152422.300  4180000.000      7      7      5    0.66%       6     20
#        9  4152422.300  4180000.000      7      7      6    0.66%       8     20
#       10  4152422.300  4180000.000      7      8      5    0.66%       8     20
#       20  4152422.300  4179775.000      7     12      4    0.65%       8     22
#       30  4152422.300  4179775.000      7     16      5    0.65%       8     23
#       40  4152422.300  4179775.000      7      8      6    0.65%       8     24
# Will try to keep branch and bound tree memory usage below 45.6GB
#       50  4152422.300  4179775.000      7      6     12    0.65%       8     25
#       60  4152422.300  4179775.000      7      2      6    0.65%       8     25
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      6 out of       418 (ratio: 0.0144)
# Uncrunching matrix
# Final MIP objective                   : 4.152422300000410e+06
# Final MIP bound                       : 4.152426480000410e+06
#   Solution time / primaldual integral :     27.27s/ 60.449827%
#   Number of solutions found / nodes   :         7 /        63
#   Max primal violation      (abs/rel) : 1.892e-09 / 1.691e-12
#   Max integer violation     (abs    ) : 2.650e-12
# 2965
# [5, 8, 47, 60, 65, 71, 100, 136, 181, 186, 189, 195, 318, 334, 412, 416, 421, 428, 440, 483, 525, 562, 585, 589, 610, 671, 734, 798, 899, 963, 968, 1024, 1058, 1089, 1124, 1155, 1161, 1189, 1288, 1324, 1395, 1420, 1440, 1469, 1495, 1518, 1581, 1647, 1658, 1685, 1693, 1694, 1710, 1714, 1718, 1761, 1787, 1864, 1867, 1883, 1896, 1911, 1923, 2017, 2059, 2060, 2082, 2088, 2122, 2156, 2159, 2161, 2196, 2234, 2235, 2238, 2244, 2288, 2289, 2301, 2338, 2339, 2364, 2507, 2522, 2525, 2576, 2627, 2694, 2757, 2820, 2830, 2844, 2865, 2871, 2875, 2921, 2948, 2958, 2965]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 22:24:13, Jul 28, 2023
# Heap usage: 2128MB (peak 2149MB, 104MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      8803088 cols        99553 elements   8803088 entities
# Presolved problem has:
#      15052 rows         5150 cols        45103 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3205MB (peak 5760MB, 104MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+09] / [ 1.53e-05,  1.98e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.46e+05] / [ 1.00e+00,  7.87e+04]
#   Objective      [min,max] : [ 1.00e+00,  3.65e+06] / [ 1.00e+00,  3.65e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 51.2GB
#  *** Solution found: -1095936.750   Time:  13.23    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4353805.2   .0000000 |           crossover
#  D  3833196.7   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 5142 simplex iterations, 1.28s
#    Barrier: 16 barrier and 6858 simplex iterations, 1.27s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       3619824.591      P      0     0        .000000    14
# Barrier solved problem
#   16 barrier and 6858 simplex iterations in 1.64 seconds at time 14
#
# Final objective                       : 3.619824591173801e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         2306224.800  3619824.591      2                 36.29%       0     15
#    1  K   2306224.800  3619824.591      2      0      0   36.29%      11     15
# Heuristic search 'R' started
# R         2708125.450  3619824.591      3                 25.19%       0     15
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3295MB (peak 5760MB, 171MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  2708125.450  3608239.279      3      2      1   24.95%      11     20
#        2  2708125.450  3606722.455      3      2      3   24.91%       8     21
#        3  2708125.450  3595211.088      3      3      4   24.67%       8     21
#        4  2708125.450  3595211.088      3      3      4   24.67%       8     21
#        5  2708125.450  3595211.088      3      3      3   24.67%      13     21
#        6  2708125.450  3593221.499      3      5      5   24.63%       8     22
#        7  2708125.450  3593221.499      3      6      4   24.63%      13     22
#        8  2708125.450  3593221.499      3      6      5   24.63%       8     22
#        9  2708125.450  3593221.499      3      7      5   24.63%       8     22
#       10  2708125.450  3593221.499      3      8      4   24.63%      11     22
#       20  2708125.450  3583780.690      3     17      6   24.43%       8     25
#       30  2708125.450  3582597.054      3     27     10   24.41%       8     29
#       40  2708125.450  3573501.504      3     36      8   24.22%       8     35
#       50  2708125.450  3573501.504      3     43     24   24.22%       8     38
#       60  2708125.450  3573501.504      3     53     33   24.22%       8     46
#       70  2708125.450  3573501.504      3     63     43   24.22%       8     46
#       80  2708125.450  3573501.504      3     73     52   24.22%       8     47
#       90  2708125.450  3573501.504      3     83     62   24.22%       8     47
#      100  2708125.450  3573501.504      3     93     71   24.22%       8     48
# Elapsed time (sec): 56, estimated tree completion: 0.00000
# Heap usage: 4726MB (peak 5760MB, 171MB system)
# B&B tree size: 1.0MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
# k    114  2986078.800  3573501.504      4    104      9   16.44%       0     56
# k    160  2986088.800  3573501.504      5    131     36   16.44%       0     65
#      200  2986088.800  3573501.504      5    155     27   16.44%       8     79
# Will try to keep branch and bound tree memory usage below 48.2GB
#      300  2986088.800  3573501.504      5    213     34   16.44%       8     97
#      400  2986088.800  3568690.263      5    288     16   16.33%       8    115
# k    400  3255443.500  3568690.263      6    288     16    8.78%       0    115
#      500  3255443.500  3568690.263      6    227     12    8.78%       8    123
# Will try to keep branch and bound tree memory usage below 44.8GB
#      600  3255443.500  3560011.214      6    193     27    8.56%      13    139
#      700  3255443.500  3558459.644      6    122     37    8.52%       8    160
#      800  3255443.500  3558459.644      6     67      9    8.52%       8    194
#      900  3255443.500  3557808.222      6     30      9    8.50%       8    250
#     1000  3255443.500  3551616.480      6     51     12    8.34%      14    297
#     1101  3255443.500  3544200.043      6     14     15    8.15%      14    331
#     1201  3255443.500  3523952.161      6     13     15    7.62%       8    394
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     35 out of      4785 (ratio: 0.0073)
# Uncrunching matrix
# Final MIP objective                   : 3.255443499999997e+06
# Final MIP bound                       : 3.255447119824588e+06
#   Solution time / primaldual integral :    426.97s/ 14.137922%
#   Number of solutions found / nodes   :         6 /      1263
#   Max primal violation      (abs/rel) : 3.553e-15 / 1.355e-19
#   Max integer violation     (abs    ) :       0.0
# 2992
# [35, 53, 60, 65, 189, 195, 238, 318, 341, 347, 412, 416, 451, 473, 483, 485, 562, 586, 671, 756, 766, 782, 798, 868, 898, 919, 963, 968, 1024, 1030, 1089, 1100, 1122, 1150, 1155, 1189, 1278, 1300, 1324, 1362, 1395, 1420, 1518, 1581, 1642, 1647, 1652, 1658, 1685, 1693, 1710, 1714, 1725, 1787, 1807, 1813, 1864, 1867, 1923, 1961, 2004, 2017, 2059, 2060, 2082, 2088, 2125, 2159, 2161, 2235, 2238, 2249, 2290, 2301, 2338, 2364, 2372, 2458, 2472, 2496, 2507, 2513, 2552, 2596, 2621, 2627, 2629, 2644, 2675, 2700, 2736, 2788, 2790, 2791, 2820, 2827, 2844, 2921, 2965, 2992]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 22:34:09, Jul 28, 2023
# Heap usage: 2221MB (peak 2221MB, 106MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      8964035 cols        99551 elements   8964035 entities
# Presolved problem has:
#      15052 rows         5150 cols        45101 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 13 seconds
# Heap usage: 3372MB (peak 5830MB, 106MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+09] / [ 1.53e-05,  2.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.42e+05] / [ 1.00e+00,  8.10e+04]
#   Objective      [min,max] : [ 1.00e+00,  4.08e+06] / [ 1.00e+00,  4.08e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.7GB
#  *** Solution found: -3228459.300   Time:  13.40    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4287907.0   .0000000 |           crossover
#  D  4058362.1   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 4681 simplex iterations, 1.19s
#    Barrier: 14 barrier and 7038 simplex iterations, 1.18s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       4026017.865      P      0     0        .000000    15
# Barrier solved problem
#   14 barrier and 7038 simplex iterations in 1.61 seconds at time 15
#
# Final objective                       : 4.026017864506525e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k        -611775.0000  4026017.865      2               4.64e+06       0     15
#    1  K  -611775.0000  4026017.865      2      0      0 4.64e+06      11     15
# Heuristic search 'R' started
# R         3034617.000  4026017.865      3                 24.62%       0     16
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3463MB (peak 5830MB, 174MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3034617.000  4023006.701      3      2      1   24.57%      11     18
#        2  3034617.000  4022144.382      3      2      3   24.55%       8     18
#        3  3034617.000  4022144.382      3      3      4   24.55%       8     19
#        4  3034617.000  4022144.382      3      3      4   24.55%      11     19
#        5  3034617.000  4022144.382      3      3      3   24.55%      11     19
#        6  3034617.000  4022144.382      3      4      5   24.55%      11     19
#        7  3034617.000  4022144.382      3      6      5   24.55%       8     20
#        8  3034617.000  4022144.382      3      6      5   24.55%       8     20
#        9  3034617.000  4022144.382      3      7      6   24.55%       8     20
#       10  3034617.000  4022144.382      3      9      6   24.55%       8     21
# k     16  3261292.050  4022144.382      4     12      6   18.92%       0     24
#       20  3261292.050  4022144.382      4     13      9   18.92%       8     25
#       30  3261292.050  4000943.175      4     18      8   18.49%       8     36
#       40  3261292.050  4000943.175      4     24      7   18.49%      11     43
#       50  3261292.050  4000943.175      4     26     14   18.49%       8     47
#       60  3261292.050  4000943.175      4     31     16   18.49%      13     50
# Will try to keep branch and bound tree memory usage below 48.1GB
# k     68  3311890.350  4000943.175      5     34     15   17.22%       0     53
#       70  3311890.350  4000943.175      5     34     15   17.22%       8     53
#       80  3311890.350  4000943.175      5     43     13   17.22%       8     55
# Elapsed time (sec): 57, estimated tree completion: 0.33452
# Heap usage: 5193MB (peak 5830MB, 174MB system)
# B&B tree size: 0.7MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#       90  3311890.350  4000943.175      5     46     16   17.22%      13     57
#      100  3311890.350  4000943.175      5     48     27   17.22%       8     62
# k    160  3335698.350  4000943.175      6    100     29   16.63%       0     80
# k    194  3371188.350  3991090.133      7    115     12   15.53%       0     93
#      200  3371188.350  3991090.133      7    115     23   15.53%       8     94
# *    300  3379580.350  3991090.133      8    210     37   15.32%       0    105
#      302  3379580.350  3991090.133      8    210     37   15.32%       8    105
# Will try to keep branch and bound tree memory usage below 43.5GB
#      402  3379580.350  3991090.133      8    212     20   15.32%      13    134
#      503  3379580.350  3991090.133      8    252     29   15.32%       8    153
#      604  3379580.350  3991090.133      8    342     20   15.32%       8    173
#      706  3379580.350  3991090.133      8    374     45   15.32%       8    193
#      807  3379580.350  3991090.133      8    440     32   15.32%       8    209
#      907  3379580.350  3991090.133      8    496     26   15.32%       8    228
#     1007  3379580.350  3991090.133      8    503     45   15.32%       8    245
#     1109  3379580.350  3991090.133      8    533     36   15.32%       8    268
#     1210  3379580.350  3985000.544      8    609     50   15.19%       8    283
# k   1289  3525788.550  3985000.544      9    626     19   11.52%       0    301
#     1310  3525788.550  3985000.544      9    644     13   11.52%       8    304
#     1410  3525788.550  3985000.544      9    627     15   11.52%      13    344
# k   1492  3558021.750  3985000.544     10    625     10   10.71%       0    364
# Elapsed time (sec): 370, estimated tree completion: 0.45043
# Heap usage: 8872MB (peak 8872MB, 175MB system)
# B&B tree size: 10MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     1510  3558021.750  3985000.544     10    619     20   10.71%       8    370
# *   1528  3571719.750  3985000.544     11    622     21   10.37%       0    376
# R   1577  3776943.650  3984988.884     12    656      8    5.22%       0    395
#     1789  3776943.650  3984988.884     12    445      1    5.22%       1    396
#     1889  3776943.650  3984988.884     12    388     33    5.22%       8    405
#     1989  3776943.650  3984988.884     12    310     16    5.22%      18    413
#     2089  3776943.650  3984988.884     12    231     16    5.22%       8    428
#     2189  3776943.650  3984988.884     12    137     29    5.22%       8    436
#     2289  3776943.650  3984988.884     12     53     15    5.22%       8    448
#     2389  3776943.650  3973965.742     12     34     13    4.96%       8    474
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     81 out of      8096 (ratio: 0.0100)
# Uncrunching matrix
# Final MIP objective                   : 3.776943649999972e+06
# Final MIP bound                       : 3.776947676017836e+06
#   Solution time / primaldual integral :    558.83s/ 14.360481%
#   Number of solutions found / nodes   :        12 /      2479
#   Max primal violation      (abs/rel) : 2.146e-10 / 2.146e-10
#   Max integer violation     (abs    ) : 2.292e-10
# 2974
# [5, 8, 28, 47, 56, 71, 78, 90, 94, 100, 118, 135, 136, 181, 186, 320, 334, 354, 421, 428, 440, 525, 533, 585, 589, 594, 610, 734, 768, 825, 827, 852, 899, 932, 954, 959, 1004, 1058, 1124, 1161, 1225, 1259, 1288, 1325, 1440, 1469, 1493, 1495, 1513, 1540, 1542, 1694, 1718, 1732, 1761, 1777, 1783, 1883, 1896, 1911, 2020, 2108, 2122, 2156, 2196, 2205, 2208, 2212, 2234, 2244, 2260, 2286, 2288, 2289, 2318, 2339, 2373, 2465, 2514, 2522, 2525, 2563, 2575, 2576, 2579, 2617, 2686, 2694, 2705, 2712, 2757, 2765, 2830, 2850, 2865, 2871, 2875, 2948, 2958, 2974]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 22:46:17, Jul 28, 2023
# Heap usage: 2198MB (peak 2198MB, 105MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      8856575 cols        99536 elements   8856575 entities
# Presolved problem has:
#      15052 rows         5150 cols        45086 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3339MB (peak 5772MB, 105MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.20e-01,  1.00e+09] / [ 1.53e-05,  1.96e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.05e+05] / [ 1.00e+00,  8.13e+04]
#   Objective      [min,max] : [ 2.00e+00,  4.17e+06] / [ 2.00e+00,  4.17e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.7GB
#  *** Solution found: -1174755.150   Time:  13.08    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4142773.9   .0000000 |           crossover
#  D  4079539.8   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 3528 simplex iterations, 1.21s
#    Barrier: 15 barrier and 6832 simplex iterations, 1.20s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       4063451.760      P      0     0        .000000    14
# Barrier solved problem
#   15 barrier and 6832 simplex iterations in 1.63 seconds at time 14
#
# Final objective                       : 4.063451760390314e+06
#   Max primal violation      (abs/rel) : 1.665e-16 / 1.597e-16
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         3633825.000  4063451.760      2                 10.57%       0     15
#    1  K   3633825.000  4063451.760      2      0      0   10.57%       8     15
# Heuristic search 'R' started
# R         3730246.800  4063451.760      3                  8.20%       0     16
# R         3841961.500  4063451.760      4                  5.45%       0     16
# R         3847761.500  4063451.760      5                  5.31%       0     16
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3429MB (peak 5772MB, 172MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3847761.500  4062304.723      5      2      1    5.28%       8     18
#        2  3847761.500  4062304.723      5      2      3    5.28%       8     19
#        3  3847761.500  4062304.723      5      3      4    5.28%       8     19
#        4  3847761.500  4060591.509      5      4      5    5.24%       8     19
#        5  3847761.500  4060591.509      5      4      3    5.24%       8     19
#        6  3847761.500  4060591.509      5      4      4    5.24%       8     19
#        7  3847761.500  4060591.509      5      5      5    5.24%       8     20
#        8  3847761.500  4060591.509      5      5      5    5.24%       8     20
#        9  3847761.500  4060591.509      5      4      6    5.24%       8     20
#       10  3847761.500  4059180.074      5      8      6    5.21%       8     22
#       20  3847761.500  4055961.139      5     13      9    5.13%       8     28
#       30  3847761.500  4055377.510      5     22      9    5.12%      14     34
#       40  3847761.500  4055377.510      5     29     18    5.12%      18     36
# *     42  3856318.800  4055377.510      6     32     20    4.91%       0     37
# Will try to keep branch and bound tree memory usage below 48.1GB
#       50  3856318.800  4055377.510      6     29     12    4.91%      16     42
#       61  3856318.800  4055377.510      6     30     18    4.91%      14     44
#       71  3856318.800  4055377.510      6     35      8    4.91%      14     45
#       81  3856318.800  4055377.510      6     40      8    4.91%       8     47
#       92  3856318.800  4054905.339      6     39     10    4.90%      14     50
# Elapsed time (sec): 51, estimated tree completion: 0.23406
# Heap usage: 8802MB (peak 8802MB, 172MB system)
# B&B tree size: 1.2MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      102  3856318.800  4054905.339      6     35     10    4.90%      18     51
# Will try to keep branch and bound tree memory usage below 43.1GB
#      203  3856318.800  4054905.339      6     19     32    4.90%       8     54
# k    218  3880182.900  4054905.339      7     19     12    4.31%       0     55
#      303  3880182.900  4026419.005      7     10      8    3.63%      14     75
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     14 out of      1516 (ratio: 0.0092)
# Uncrunching matrix
# Final MIP objective                   : 3.880182900000057e+06
# Final MIP bound                       : 3.880186963451817e+06
#   Solution time / primaldual integral :     87.59s/ 20.951238%
#   Number of solutions found / nodes   :         7 /       325
#   Max primal violation      (abs/rel) : 3.735e-09 / 4.326e-11
#   Max integer violation     (abs    ) : 1.287e-10
# 3000
# [28, 50, 56, 78, 90, 94, 118, 135, 212, 230, 249, 314, 320, 348, 350, 354, 495, 533, 538, 579, 591, 594, 637, 649, 666, 670, 690, 768, 825, 827, 852, 909, 912, 932, 954, 959, 965, 992, 1004, 1007, 1082, 1135, 1187, 1225, 1242, 1259, 1318, 1325, 1351, 1379, 1382, 1426, 1455, 1465, 1479, 1480, 1493, 1513, 1540, 1542, 1544, 1650, 1732, 1772, 1777, 1783, 1850, 1953, 2020, 2055, 2108, 2134, 2204, 2205, 2208, 2212, 2240, 2260, 2264, 2286, 2310, 2318, 2373, 2418, 2465, 2510, 2514, 2563, 2575, 2579, 2617, 2666, 2676, 2686, 2705, 2712, 2765, 2850, 2974, 3000]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 22:50:33, Jul 28, 2023
# Heap usage: 2231MB (peak 2231MB, 107MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      9012003 cols        99552 elements   9012003 entities
# Presolved problem has:
#      15052 rows         5150 cols        45102 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 13 seconds
# Heap usage: 3387MB (peak 5856MB, 107MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.20e-01,  1.00e+09] / [ 1.53e-05,  1.92e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  3.98e+05] / [ 1.00e+00,  8.07e+04]
#   Objective      [min,max] : [ 2.00e+00,  4.12e+06] / [ 2.00e+00,  4.12e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.6GB
#  *** Solution found: -1567170.000   Time:  13.52    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  14s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4183409.6   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 3775 simplex iterations, 1.03s
#    Barrier: 14 barrier and 6990 simplex iterations, 1.02s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       4035000.000      P      0     0        .000000    15
# Barrier solved problem
#   14 barrier and 6990 simplex iterations in 1.47 seconds at time 15
#
# Final objective                       : 4.035000000000000e+06
#   Max primal violation      (abs/rel) : 3.638e-12 / 2.191e-12
#   Max dual violation        (abs/rel) : 1.863e-09 / 1.863e-09
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         3793365.000  4035000.000      2                  5.99%       0     15
#    1  K   3793365.000  4035000.000      2      0      0    5.99%       8     15
# Heuristic search 'R' started
# R         3793395.000  4035000.000      3                  5.99%       0     16
# R         3915816.000  4035000.000      4                  2.95%       0     16
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3479MB (peak 5856MB, 174MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3915816.000  4035000.000      4      2      1    2.95%       8     17
#        2  3915816.000  4035000.000      4      2      3    2.95%      11     18
#        3  3915816.000  4035000.000      4      3      4    2.95%       8     18
#        4  3915816.000  4035000.000      4      4      3    2.95%       8     19
#        5  3915816.000  4035000.000      4      5      4    2.95%       8     20
#        6  3915816.000  4035000.000      4      5      4    2.95%       8     20
#        7  3915816.000  4035000.000      4      6      5    2.95%      13     20
#        8  3915816.000  4032475.430      4      7      5    2.89%       8     20
#        9  3915816.000  4032475.430      4      7      6    2.89%       8     20
#       10  3915816.000  4032475.430      4      7      5    2.89%       8     20
#       20  3915816.000  4031975.957      4     15      9    2.88%       8     30
# Will try to keep branch and bound tree memory usage below 47.7GB
#       30  3915816.000  4031862.548      4     20      7    2.88%       8     32
#       40  3915816.000  4031862.548      4     25      8    2.88%       8     33
#       51  3915816.000  4031862.548      4     33     28    2.88%       8     33
#       61  3915816.000  4031862.548      4     37     13    2.88%       8     34
#       71  3915816.000  4029944.702      4     37     10    2.83%      14     35
#       81  3915816.000  4029944.702      4     28     23    2.83%       8     36
#       91  3915816.000  4029944.702      4     23     27    2.83%      13     36
# Will try to keep branch and bound tree memory usage below 43.1GB
#      102  3915816.000  4029944.702      4     19     12    2.83%       8     37
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     10 out of       966 (ratio: 0.0104)
# Uncrunching matrix
# Final MIP objective                   : 3.915816000000065e+06
# Final MIP bound                       : 3.915820035000065e+06
#   Solution time / primaldual integral :     54.56s/ 30.371568%
#   Number of solutions found / nodes   :         4 /       183
#   Max primal violation      (abs/rel) : 5.539e-07 / 1.455e-11
#   Max integer violation     (abs    ) : 1.393e-11
# 2965
# [60, 65, 80, 144, 161, 189, 195, 199, 248, 305, 318, 337, 338, 358, 407, 411, 412, 416, 425, 453, 483, 513, 517, 562, 647, 671, 708, 798, 809, 897, 963, 968, 1015, 1024, 1075, 1089, 1107, 1155, 1189, 1190, 1197, 1287, 1324, 1395, 1420, 1421, 1518, 1581, 1647, 1658, 1659, 1685, 1693, 1710, 1712, 1714, 1787, 1864, 1867, 1877, 1885, 1923, 1974, 2017, 2049, 2059, 2060, 2070, 2073, 2082, 2088, 2096, 2159, 2161, 2230, 2235, 2238, 2245, 2301, 2338, 2361, 2364, 2440, 2451, 2507, 2558, 2577, 2578, 2608, 2627, 2669, 2709, 2723, 2754, 2820, 2844, 2904, 2921, 2928, 2965]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 22:54:16, Jul 28, 2023
# Heap usage: 2128MB (peak 2149MB, 104MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      8803088 cols        99560 elements   8803088 entities
# Presolved problem has:
#      15052 rows         5150 cols        45110 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3205MB (peak 5760MB, 104MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+09] / [ 1.53e-05,  2.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.50e+05] / [ 1.00e+00,  8.79e+04]
#   Objective      [min,max] : [ 1.00e+00,  3.46e+06] / [ 1.00e+00,  3.46e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.9GB
#  *** Solution found: -496149.0000   Time:  13.07    Heuristic: e ***
#  *** Solution found: -332436.3000   Time:  13.36    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  3557938.4   .0000000 |           crossover
#  D  3492508.8   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 5059 simplex iterations, 1.11s
#    Barrier: 16 barrier and 6951 simplex iterations, 1.31s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       3482950.032      P      0     0        .000000    15
# Barrier solved problem
#   16 barrier and 6951 simplex iterations in 1.66 seconds at time 15
#
# Final objective                       : 3.482950031777868e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         2879020.200  3482950.032      3                 17.34%       0     15
#    1  K   2879020.200  3482950.032      3      0      0   17.34%       8     15
# Heuristic search 'R' started
# R         2883239.450  3482950.032      4                 17.22%       0     16
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3294MB (peak 5760MB, 171MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  2883239.450  3482305.092      4      2      1   17.20%       8     17
#        2  2883239.450  3481326.109      4      2      3   17.18%      14     18
#        3  2883239.450  3481326.109      4      3      4   17.18%       8     19
#        4  2883239.450  3475914.352      4      3      4   17.05%       8     19
#        5  2883239.450  3475914.352      4      4      3   17.05%       8     19
#        6  2883239.450  3475914.352      4      4      5   17.05%       8     19
#        7  2883239.450  3474156.667      4      5      5   17.01%       8     19
#        8  2883239.450  3473127.644      4      7      5   16.98%      14     21
#        9  2883239.450  3473127.644      4      8      4   16.98%       8     21
#       10  2883239.450  3473127.644      4      9      6   16.98%       8     21
#       20  2883239.450  3468118.486      4     14      8   16.86%       8     26
# k     25  2947336.250  3468118.486      5     21     11   15.02%       0     28
#       30  2947336.250  3468118.486      5     25     11   15.02%       8     33
#       40  2947336.250  3468118.486      5     34     16   15.02%       8     39
# k     46  3100499.200  3468118.486      6     41     21   10.60%       0     40
#       50  3100499.200  3468118.486      6     44     25   10.60%       8     41
#       60  3100499.200  3468118.486      6     55     24   10.60%       8     43
# k     67  3258601.450  3468118.486      7     61     32    6.04%       0     44
#       70  3258601.450  3468118.486      7     59      1    6.04%       1     44
# Elapsed time (sec): 50, estimated tree completion: 0.05338
# Heap usage: 4928MB (peak 5760MB, 171MB system)
# B&B tree size: 0.8MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#       80  3258601.450  3468118.486      7     63     14    6.04%       8     50
#       91  3258601.450  3468118.486      7     70     11    6.04%       8     54
#      101  3258601.450  3468118.486      7     69     16    6.04%       8     58
# Will try to keep branch and bound tree memory usage below 47.4GB
# Will try to keep branch and bound tree memory usage below 44.8GB
#      201  3258601.450  3468118.486      7     88      9    6.04%      13     84
#      301  3258601.450  3468118.486      7     56     17    6.04%       8    131
#      401  3258601.450  3432547.987      7      1     13    5.07%      13    214
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     15 out of      1864 (ratio: 0.0080)
# Uncrunching matrix
# Final MIP objective                   : 3.258601450000002e+06
# Final MIP bound                       : 3.258604932950033e+06
#   Solution time / primaldual integral :    221.85s/ 13.670026%
#   Number of solutions found / nodes   :         7 /       415
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max integer violation     (abs    ) :       0.0
# 2974
# [28, 56, 78, 80, 90, 94, 118, 135, 144, 161, 199, 248, 305, 320, 337, 338, 354, 358, 407, 411, 425, 453, 513, 517, 533, 594, 647, 708, 768, 809, 825, 827, 852, 897, 932, 954, 959, 1004, 1015, 1075, 1107, 1190, 1197, 1225, 1259, 1287, 1325, 1421, 1493, 1513, 1540, 1542, 1659, 1712, 1732, 1777, 1783, 1877, 1885, 1974, 2020, 2049, 2070, 2073, 2096, 2108, 2205, 2208, 2212, 2230, 2245, 2260, 2286, 2318, 2361, 2373, 2440, 2451, 2465, 2514, 2558, 2563, 2575, 2577, 2578, 2579, 2608, 2617, 2669, 2686, 2705, 2709, 2712, 2723, 2754, 2765, 2850, 2904, 2928, 2974]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 23:00:45, Jul 28, 2023
# Heap usage: 2198MB (peak 2198MB, 105MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      8856575 cols        99548 elements   8856575 entities
# Presolved problem has:
#      15052 rows         5150 cols        45098 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3339MB (peak 5772MB, 105MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.20e-01,  1.00e+09] / [ 1.53e-05,  1.97e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.09e+05] / [ 1.00e+00,  8.44e+04]
#   Objective      [min,max] : [ 1.00e+00,  4.18e+06] / [ 1.00e+00,  4.18e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.7GB
#  *** Solution found:  4500.100000   Time:  13.27    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4294870.4   .0000000 |           crossover
#  D  4271337.1   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 3361 simplex iterations, 1.15s
#    Barrier: 14 barrier and 6925 simplex iterations, 1.15s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       4214835.173      P      0     0        .000000    14
# Barrier solved problem
#   14 barrier and 6925 simplex iterations in 1.57 seconds at time 14
#
# Final objective                       : 4.214835173209459e+06
#   Max primal violation      (abs/rel) : 3.331e-16 / 1.723e-16
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         3714950.000  4214835.173      2                 11.86%       0     15
#    1  K   3714950.000  4214835.173      2      0      0   11.86%       8     15
# Heuristic search 'R' started
# R         3746969.300  4214835.173      3                 11.10%       0     15
# R         3757671.250  4214835.173      4                 10.85%       0     16
# R         3861898.400  4214835.173      5                  8.37%       0     16
# R         4071478.000  4214835.173      6                  3.40%       0     17
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3429MB (peak 5772MB, 172MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  4071478.000  4212811.801      6      2      1    3.35%       8     19
#        2  4071478.000  4212811.801      6      2      3    3.35%       8     19
#        3  4071478.000  4212811.801      6      3      4    3.35%       8     20
#        4  4071478.000  4212811.801      6      3      4    3.35%       8     20
#        5  4071478.000  4209830.832      6      4      5    3.29%       8     20
#        6  4071478.000  4209830.832      6      5      3    3.29%       8     20
#        7  4071478.000  4209723.868      6      6      6    3.28%       8     20
#        8  4071478.000  4209723.868      6      7      4    3.28%       8     21
#        9  4071478.000  4209559.521      6      9      5    3.28%       8     21
#       10  4071478.000  4209559.521      6     10      5    3.28%       8     21
#       20  4071478.000  4209555.720      6     13     11    3.28%       8     26
#       30  4071478.000  4204146.050      6     19      7    3.16%       8     27
#       40  4071478.000  4203003.890      6     23     10    3.13%       8     28
#       50  4071478.000  4203003.890      6     16     15    3.13%       8     29
#       60  4071478.000  4198558.238      6      6      6    3.03%       8     30
# Will try to keep branch and bound tree memory usage below 44.1GB
#       70  4071478.000  4172786.087      6      6      7    2.43%      14     31
#       80  4071478.000  4172786.087      6      7     10    2.43%       8     32
#       90  4071478.000  4166833.605      6      1      9    2.29%      18     36
#      101  4071478.000  4079504.028      6      1     14    0.20%      14     36
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :      7 out of       492 (ratio: 0.0142)
# Uncrunching matrix
# Final MIP objective                   : 4.071478000000002e+06
# Final MIP bound                       : 4.071482214835175e+06
#   Solution time / primaldual integral :     38.51s/ 41.794765%
#   Number of solutions found / nodes   :         6 /       101
#   Max primal violation      (abs/rel) : 6.329e-12 / 2.201e-16
#   Max integer violation     (abs    ) : 2.201e-16
# 3000
# [50, 60, 65, 189, 195, 212, 230, 249, 314, 318, 348, 350, 412, 416, 483, 495, 538, 562, 579, 591, 637, 649, 666, 670, 671, 690, 798, 909, 912, 963, 965, 968, 992, 1007, 1024, 1082, 1089, 1135, 1155, 1187, 1189, 1242, 1318, 1324, 1351, 1379, 1382, 1395, 1420, 1426, 1455, 1465, 1479, 1480, 1518, 1544, 1581, 1647, 1650, 1658, 1685, 1693, 1710, 1714, 1772, 1787, 1850, 1864, 1867, 1923, 1953, 2017, 2055, 2059, 2060, 2082, 2088, 2134, 2159, 2161, 2204, 2235, 2238, 2240, 2264, 2301, 2310, 2338, 2364, 2418, 2507, 2510, 2627, 2666, 2676, 2820, 2844, 2921, 2965, 3000]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 23:04:13, Jul 28, 2023
# Heap usage: 2231MB (peak 2231MB, 107MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      9012003 cols        99559 elements   9012003 entities
# Presolved problem has:
#      15052 rows         5150 cols        45109 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 13 seconds
# Heap usage: 3387MB (peak 5856MB, 107MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e-01,  1.00e+09] / [ 1.53e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.39e+05] / [ 1.00e+00,  8.58e+04]
#   Objective      [min,max] : [ 1.00e+00,  3.99e+06] / [ 1.00e+00,  3.99e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.6GB
#  *** Solution found: -297114.9000   Time:  13.49    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  14s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  3910378.4   .0000000 |           crossover
#  D  3878431.8   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 4641 simplex iterations, 1.26s
#    Barrier: 15 barrier and 6951 simplex iterations, 1.25s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       3789028.087      P      0     0        .000000    15
# Barrier solved problem
#   15 barrier and 6951 simplex iterations in 1.68 seconds at time 15
#
# Final objective                       : 3.789028087124772e+06
#   Max primal violation      (abs/rel) : 1.819e-12 / 9.762e-13
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# g         3763338.200  3789028.087      2                  0.68%       0     15
# R         3764076.200  3788651.192      3                  0.65%       0     16
#    1  K   3764076.200  3788651.192      3      1      0    0.65%      11     16
#    2  K   3764076.200  3788651.192      3      0      0    0.65%       8     16
# Heuristic search 'R' started
# Heuristic search 'R' stopped
#
# Cuts in the matrix         : 1
# Cut elements in the matrix : 1566
#
# Starting tree search.
# ...
#      15052 rows         5150 cols        45109 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3192MB (peak 5737MB, 104MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.40e-01,  1.00e+09] / [ 1.53e-05,  2.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.59e+05] / [ 1.00e+00,  8.40e+04]
#   Objective      [min,max] : [ 2.00e+00,  4.19e+06] / [ 2.00e+00,  4.19e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.9GB
#  *** Solution found: -1219787.100   Time:  13.28    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4533450.3   .0000000 |           crossover
#  D  4195583.9   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 3545 simplex iterations, 1.20s
#    Barrier: 15 barrier and 6757 simplex iterations, 1.20s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       4195558.343      P      0     0        .000000    14
# Barrier solved problem
#   15 barrier and 6757 simplex iterations in 1.56 seconds at time 14
#
# Final objective                       : 4.195558343422530e+06
#   Max primal violation      (abs/rel) :       0.0 /       0.0
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         2879490.000  4195558.343      2                 31.37%       0     15
#    1  K   2879490.000  4195558.343      2      0      0   31.37%       8     15
# Heuristic search 'R' started
# R         3231951.900  4195558.343      3                 22.97%       0     15
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3281MB (peak 5737MB, 170MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3231951.900  4195391.155      3      2      1   22.96%       8     18
#        2  3231951.900  4195391.155      3      2      3   22.96%       8     19
#        3  3231951.900  4195315.186      3      3      3   22.96%       8     19
#        4  3231951.900  4195315.186      3      4      4   22.96%       8     19
#        5  3231951.900  4195315.186      3      5      4   22.96%       8     19
#        6  3231951.900  4195315.186      3      6      4   22.96%      11     19
#        7  3231951.900  4195315.186      3      6      4   22.96%       8     19
#        8  3231951.900  4190843.015      3      7      5   22.88%       8     19
#        9  3231951.900  4190843.015      3      7      5   22.88%       8     19
#       10  3231951.900  4190843.015      3     10      5   22.88%       8     19
#       20  3231951.900  4186314.030      3     17      8   22.80%       8     20
#       30  3231951.900  4182865.560      3     27     11   22.73%       8     24
# k     36  3404062.200  4181462.882      4     29      6   18.59%       0     30
#       40  3404062.200  4181462.882      4     31      6   18.59%      14     32
#       50  3404062.200  4181462.882      4     34     17   18.59%       8     34
# k     55  3668885.800  4181462.882      5     36     15   12.26%       0     36
#       60  3668885.800  4180650.640      5     35      5   12.24%       8     37
#       70  3668885.800  4180610.004      5     38     17   12.24%       8     39
#       80  3668885.800  4180610.004      5     41     27   12.24%      13     42
# Elapsed time (sec): 44, estimated tree completion: 0.13950
# Heap usage: 4989MB (peak 5737MB, 170MB system)
# B&B tree size: 0.8MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#       90  3668885.800  4180610.004      5     42      9   12.24%      13     44
#      100  3668885.800  4180345.384      5     51     15   12.23%      13     48
# Will try to keep branch and bound tree memory usage below 47.6GB
# k    154  3668893.800  4178905.461      6     93     44   12.20%       0     70
#      200  3668893.800  4178361.149      6    140     28   12.19%      13     82
# Will try to keep branch and bound tree memory usage below 44.6GB
#      300  3668893.800  4178339.651      6    184     18   12.19%       8     98
#      400  3668893.800  4178336.999      6    235     48   12.19%       8    113
# k    446  3748917.450  4177173.451      7    273     11   10.25%       0    122
#      500  3748917.450  4177173.451      7    271     14   10.25%       8    129
#      600  3748917.450  4177173.451      7    306     26   10.25%       8    149
#      700  3748917.450  4177173.451      7    362     17   10.25%       8    168
#      803  3748917.450  4176771.724      7    407     26   10.24%      14    183
#      903  3748917.450  4176771.724      7    451     21   10.24%       8    200
#     1003  3748917.450  4176771.724      7    473     36   10.24%       9    224
#     1103  3748917.450  4174249.703      7    493     18   10.19%      19    244
#     1203  3748917.450  4174249.703      7    522     18   10.19%       8    268
#     1304  3748917.450  4174239.306      7    540     11   10.19%      15    293
#     1404  3748917.450  4174239.306      7    543     22   10.19%       8    318
#     1504  3748917.450  4173214.526      7    540     21   10.17%      13    350
#     1604  3748917.450  4173016.080      7    540     16   10.16%       8    366
#     1704  3748917.450  4172323.589      7    542     14   10.15%       8    397
# Elapsed time (sec): 430, estimated tree completion: 0.57384
# Heap usage: 7685MB (peak 7685MB, 171MB system)
# B&B tree size: 10MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     1804  3748917.450  4172323.589      7    519     36   10.15%       8    430
#     1904  3748917.450  4172323.589      7    479     21   10.15%      14    462
#     2004  3748917.450  4172323.589      7    439     21   10.15%       8    489
#     2105  3748917.450  4172323.589      7    414     17   10.15%      13    519
#     2206  3748917.450  4172323.589      7    398     17   10.15%       8    537
#     2306  3748917.450  4172323.589      7    378     13   10.15%       8    564
#     2406  3748917.450  4170879.647      7    392     11   10.12%       8    593
#     2506  3748917.450  4168731.678      7    400     22   10.07%       8    607
#     2606  3748917.450  4168731.678      7    427     13   10.07%       8    626
#     2709  3748917.450  4168731.678      7    390     32   10.07%      18    655
#     2810  3748917.450  4168731.678      7    386     27   10.07%       8    678
#     2910  3748917.450  4167703.630      7    401     32   10.05%       8    699
#     3010  3748917.450  4167703.630      7    448     23   10.05%       8    710
#     3110  3748917.450  4165992.982      7    467     20   10.01%      14    731
#     3210  3748917.450  4165992.982      7    483     11   10.01%       8    745
# k   3260  3765906.050  4165992.982      8    480     27    9.60%       0    756
#     3310  3765906.050  4165992.982      8    490     25    9.60%       8    768
# a   3327  3819735.950  4165992.982      9    482     19    8.31%       0    774
# k   3389  3919851.500  4160086.010     10    492     21    5.77%       0    785
#     3453  3919851.500  4160086.010     10    428      1    5.77%       1    785
# Elapsed time (sec): 812, estimated tree completion: 0.82963
# Heap usage: 7696MB (peak 7696MB, 171MB system)
# B&B tree size: 12MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#     3553  3919851.500  4150575.404     10    379     28    5.56%       8    812
#     3653  3919851.500  4149337.186     10    355     19    5.53%      13    831
#     3753  3919851.500  4143947.369     10    273     19    5.41%       8    856
#     3853  3919851.500  4143947.369     10    173     17    5.41%       8    884
#     3953  3919851.500  4143334.346     10     75     25    5.39%      22    892
#     4053  3919851.500  4012113.091     10      3     22    2.30%       8    927
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :    137 out of      9488 (ratio: 0.0144)
# Uncrunching matrix
# Final MIP objective                   : 3.919851499999889e+06
# Final MIP bound                       : 3.919855695558232e+06
#   Solution time / primaldual integral :    929.94s/ 11.306430%
#   Number of solutions found / nodes   :        10 /      4083
#   Max primal violation      (abs/rel) : 5.094e-05 / 8.768e-12
#   Max integer violation     (abs    ) : 8.768e-12
# 2992
# [35, 53, 106, 184, 238, 341, 347, 369, 388, 443, 451, 456, 473, 480, 485, 586, 625, 635, 693, 740, 756, 766, 782, 788, 858, 868, 898, 902, 919, 946, 1030, 1050, 1062, 1100, 1122, 1150, 1269, 1272, 1278, 1300, 1323, 1326, 1362, 1530, 1538, 1587, 1631, 1642, 1652, 1725, 1760, 1807, 1813, 1838, 1946, 1961, 1994, 1999, 2004, 2016, 2125, 2164, 2194, 2200, 2228, 2231, 2249, 2290, 2325, 2347, 2372, 2458, 2461, 2462, 2472, 2479, 2487, 2496, 2498, 2513, 2545, 2552, 2596, 2621, 2629, 2644, 2660, 2675, 2700, 2736, 2773, 2788, 2790, 2791, 2807, 2827, 2846, 2853, 2899, 2992]
# passed
# FICO Xpress v9.0.0, Hyper, solve started 3:54:12, Jul 29, 2023
# Heap usage: 2221MB (peak 2221MB, 106MB system)
# Maximizing MILP noname using up to 8 threads and up to 63GB memory, with these control settings:
# OUTPUTLOG = 1
# Original problem has:
#      39802 rows      8964035 cols        99557 elements   8964035 entities
# Presolved problem has:
#      15052 rows         5150 cols        45107 elements      5150 entities
# LP relaxation tightened
# Presolve finished in 12 seconds
# Heap usage: 3372MB (peak 5830MB, 106MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 2.20e-01,  1.00e+09] / [ 1.53e-05,  1.99e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.07e+05] / [ 1.00e+00,  8.38e+04]
#   Objective      [min,max] : [ 3.00e+00,  4.26e+06] / [ 3.00e+00,  4.26e+06]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 50.5GB
#  *** Solution found: -3268955.000   Time:  13.25    Heuristic: h ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve,  13s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  4689158.8   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#       Dual: 4223 simplex iterations, 1.16s
#    Barrier: 14 barrier and 7026 simplex iterations, 1.15s
#             Barrier used 7 threads 7 cores, L1\L2 cache: 32K\28160K
#             Barrier used AVX support, crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0       4162873.357      P      0     0        .000000    14
# Barrier solved problem
#   14 barrier and 7026 simplex iterations in 1.58 seconds at time 14
#
# Final objective                       : 4.162873357412944e+06
#   Max primal violation      (abs/rel) : 7.731e-12 / 6.396e-12
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time
# k         2908126.200  4162873.357      2                 30.14%       0     15
#    1  K   2908126.200  4162873.357      2      0      0   30.14%      11     15
# Heuristic search 'R' started
# R         3206713.000  4162873.357      3                 22.97%       0     15
# R         3245697.000  4162873.357      4                 22.03%       0     16
# R         3284139.000  4162873.357      5                 21.11%       0     16
# R         3352822.750  4162873.357      6                 19.46%       0     17
# R         3500425.700  4162873.357      7                 15.91%       0     17
# R         3833101.800  4162873.357      8                  7.92%       0     17
# Heuristic search 'R' stopped
#
# Starting tree search.
# Deterministic mode with up to 8 running threads and up to 16 tasks.
# Heap usage: 3463MB (peak 5830MB, 173MB system)
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#        1  3833101.800  4158682.803      8      2      1    7.83%      11     20
#        2  3833101.800  4154363.971      8      2      3    7.73%       8     20
#        3  3833101.800  4153989.095      8      3      4    7.72%       8     21
#        4  3833101.800  4151878.435      8      4      4    7.68%      11     22
#        5  3833101.800  4151878.435      8      4      5    7.68%       8     22
#        6  3833101.800  4151878.435      8      5      2    7.68%      11     22
#        7  3833101.800  4151878.435      8      5      5    7.68%      11     22
#        8  3833101.800  4151878.435      8      6      6    7.68%      11     24
#        9  3833101.800  4151878.435      8      6      5    7.68%      26     25
#       10  3833101.800  4151878.435      8      7      6    7.68%      24     26
#       20  3833101.800  4139787.809      8     13      9    7.41%       8     31
#       30  3833101.800  4130873.844      8     24     15    7.21%       8     39
#       40  3833101.800  4130005.186      8     28      8    7.19%       8     46
#       50  3833101.800  4125531.512      8     31     12    7.09%       8     53
#       60  3833101.800  4124770.276      8     37     13    7.07%       8     57
# Will try to keep branch and bound tree memory usage below 47.6GB
#       70  3833101.800  4124770.276      8     42     18    7.07%       8     62
#       80  3833101.800  4124770.276      8     41     14    7.07%       8     66
#       90  3833101.800  4124770.276      8     45     17    7.07%       8     69
# Will try to keep branch and bound tree memory usage below 44.8GB
#      101  3833101.800  4124770.276      8     49     16    7.07%      13     72
# Elapsed time (sec): 97, estimated tree completion: 0.07089
# Heap usage: 8765MB (peak 8765MB, 174MB system)
# B&B tree size: 1.3MB total
#
#     Node     BestSoln    BestBound   Sols Active  Depth     Gap     GInf   Time
#      201  3833101.800  4124770.276      8     75     13    7.07%       8     97
#      301  3833101.800  4123990.921      8    126     21    7.05%       8    118
#      402  3833101.800  4110303.077      8    137     23    6.74%      22    139
#      502  3833101.800  4106397.960      8    135     30    6.66%      20    166
#      603  3833101.800  4106397.960      8    168     29    6.66%      15    181
#      703  3833101.800  4098069.088      8    168     16    6.47%       8    207
#      803  3833101.800  4098069.088      8    177     16    6.47%      13    223
#      903  3833101.800  4098069.088      8    124     21    6.47%       8    228
#     1004  3833101.800  4095974.032      8     72     26    6.42%       8    234
#     1104  3833101.800  4095974.032      8     70     21    6.42%       8    237
#     1205  3833101.800  4095759.679      8     58     21    6.41%      17    267
# a   1260  3879419.300  4095759.679      9     27     20    5.28%       0    302
#  *** Search completed ***
# Numerical issues encountered:
#    Dual failures    :     38 out of      4239 (ratio: 0.0090)
# Uncrunching matrix
# Final MIP objective                   : 3.879419300057287e+06
# Final MIP bound                       : 3.879423462930644e+06
#   Solution time / primaldual integral :    406.44s/  9.914606%
#   Number of solutions found / nodes   :         9 /      1293
#   Max primal violation      (abs/rel) : 5.978e-07 / 1.078e-08
#   Max integer violation     (abs    ) : 5.998e-08

# %% [markdown]
# ## Average score per instance

# %%
average_scores2 = {}
average_scores3 = {}
average_scores4 = {}
average_scores5 = {}

for i in random_index:
    scores2_i = []
    for ele in scores_instance2:
        if i in list(ele.keys()):
            scores2_i.append(ele[i])
    if len(scores2_i)>0:
        avg_score_i = sum(scores2_i)/len(scores2_i)
        average_scores2[i] = avg_score_i


for i in random_index:
    scores3_i = []
    for ele in scores_instance3:
        if i in list(ele.keys()):
            scores3_i.append(ele[i])
    if len(scores3_i)>0:
        avg_score_i = sum(scores3_i)/len(scores3_i)
        average_scores3[i] = avg_score_i



for i in random_index:
    scores4_i = []
    for ele in scores_instance4:
        if i in list(ele.keys()):
            scores4_i.append(ele[i])
    if len(scores4_i)>0:
        avg_score_i = sum(scores4_i)/len(scores4_i)
        average_scores4[i] = avg_score_i



for i in random_index:
    scores5_i = []
    for ele in scores_instance5:
        if i in list(ele.keys()):
            scores5_i.append(ele[i])
    if len(scores5_i)>0:
        avg_score_i = sum(scores5_i)/len(scores5_i)
        average_scores5[i] = avg_score_i

# %% [markdown]
# ## final score per instance

# %%
sf_2 = {}
sf_3 = {}
sf_4 = {}
sf_5 = {}

for i in random_index:
    sf_i = []
    for ele in scores_instance2:
        if i in list(ele.keys()):
            items_list = list(ele.items())
            elements_after_i = dict(items_list[i+1:])
            indices_after_i = list(elements_after_i.keys())
            sc_to_max = [average_scores2[j] for j in indices_after_i]
            sc_to_max.append(average_scores2[i])
            max_sc_i = max(sc_to_max)
            sf_i.append(max_sc_i)
    if len(sf_i)>0:
        sf_2[i] = max(sf_i)



for i in random_index:
    sf_i = []
    for ele in scores_instance3:
        if i in list(ele.keys()):
            items_list = list(ele.items())
            elements_after_i = dict(items_list[i+1:])
            indices_after_i = list(elements_after_i.keys())
            sc_to_max = [average_scores3[j] for j in indices_after_i]
            sc_to_max.append(average_scores3[i])
            max_sc_i = max(sc_to_max)
            sf_i.append(max_sc_i)
    if len(sf_i)>0:
        sf_3[i] = max(sf_i)



for i in random_index:
    sf_i = []
    for ele in scores_instance4:
        if i in list(ele.keys()):
            items_list = list(ele.items())
            elements_after_i = dict(items_list[i+1:])
            indices_after_i = list(elements_after_i.keys())
            sc_to_max = [average_scores4[j] for j in indices_after_i]
            sc_to_max.append(average_scores4[i])
            max_sc_i = max(sc_to_max)
            sf_i.append(max_sc_i)
    if len(sf_i)>0:
        sf_4[i] = max(sf_i)



for i in random_index:
    sf_i = []
    for ele in scores_instance5:
        if i in list(ele.keys()):
            items_list = list(ele.items())
            elements_after_i = dict(items_list[i+1:])
            indices_after_i = list(elements_after_i.keys())
            sc_to_max = [average_scores5[j] for j in indices_after_i]
            sc_to_max.append(average_scores5[i])
            max_sc_i = max(sc_to_max)
            sf_i.append(max_sc_i)
    if len(sf_i)>0:
        sf_5[i] = max(sf_i)

# %% [markdown]
# # Final scores

# %%
scores_final_1000 = []
only_scores = []
for i in random_index:
    scores_i = []
    w_i = []
    if i in high_perfo_indices:
        scores_i.append(2*sf_2[i])
        w_i.append(2)
        scores_i.append(sf_4[i])
        w_i.append(1)       
        scores_i.append(sf_5[i])
        w_i.append(1) 
        scores_i.append(scores_dict[i])
        w_i.append(1)
    if i in low_perfo_indices:
        scores_i.append(sf_3[i])
        w_i.append(1)
        scores_i.append(2*sf_4[i])
        w_i.append(2)       
        scores_i.append(2*sf_5[i])
        w_i.append(2) 
        scores_i.append(2*scores_dict[i])
        w_i.append(2)
    sumi_scores = sum(scores_i)
    sumi_w = sum(w_i)
    if sumi_w > 0:
        sc_fin_100_i = sumi_scores/sumi_w
        scores_final_1000.append((i,sc_fin_100_i))
        only_scores.append(sc_fin_100_i)

# %% [markdown]
# # Saving scored data for the ML model

# %%
# Define an empty DataFrame with column names
df_scoring = pd.DataFrame(columns=['Product_scoring', 'Volumes_scoring', 'Demand_scoring', 'Costs_scoring', 'Alphas_scoring', 'Price_scoring'])
ind = list(range(1, 1001))

df_scoring['Product_scoring'] = random_index
df_scoring['Volumes_scoring'] = volumes_selec
df_scoring['Demand_scoring'] = demand_selec
df_scoring['Costs_scoring'] = costs_selec
df_scoring['Price_scoring'] = price_selec
df_scoring['Scores'] = only_scores

alpha_li = []
for i in range(1, len(volumes_selec)+1):
    alpha_i = []
    for j in range(1, len(volumes_selec)+1):
        alpha_i.append(alpha[(i,j)])
    alpha_li.append(alpha_i)
df_scoring['Alphas'] = alpha_li
df_scoring.to_csv('data_scoring_1000.csv', index=False)

# %%
from IPython.display import FileLink
FileLink('data_scoring_initial.csv')
# Out:
# C:\Users\Abir.HARRASSE\data_scoring_initial.csv
